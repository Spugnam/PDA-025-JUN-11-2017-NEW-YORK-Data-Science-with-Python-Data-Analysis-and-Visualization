# %% [markdown]
# # Matplotlib & Seaborn

# %% [markdown]
# ## Overview
#
# matplotlib is a python 2D plotting library built on the top of the basic Python language and Numpy.
# More about matplotlib can be found in its [documentation](http://matplotlib.org/contents.html).
#
# Seaborn is a Python visualization library based on matplotlib. It provides a high-level interface for drawing attractive statistical graphics. Here is the [documentation](http://seaborn.pydata.org/index.html).

# %% [markdown]
# To display the graph inside IPython notebook, run the following code.

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# Begin by making a simple plot matplotlib.  Create a set of x-coordinates and y-coordinates.  Then plot them, as follows:

# %%
x=[7,8,9,11]
y=[9,4,6,7]
plt.plot(x,y)

# %%
#for information on plot function
# ?plt.plot

# %% [markdown]
# The style of the plot can be set in several ways.  The line style, color, marker size, line width and opacity may be set using additional parameters.  Multiple series can also be plotted in the the same graph.

# %%
plt.plot(x,y,'.-',color='green',markersize=20,alpha=0.4)
y2=[1,8,3,5]
plt.plot(x,y2,'.--',color='red',markersize=10,alpha=0.7)

# %% [markdown]
# The plot can also be given a legend, title and labels on the x and y axis.  The range and tick marks can also be set for the axes.  Text can be added to the plot as well.  These are all sown in the following graph.

# %%
plt.plot(x,y,'.-',color='green',markersize=20,
         linewidth=4,alpha=0.4,label='data1')
plt.plot(x,y2,'.--',color='red',markersize=10,alpha=0.7,
         linewidth=0.3,label='data2')
plt.legend(loc=1)
plt.title('Example Plot $x^2\lambda$')
plt.xlabel('horizontal axis')
plt.ylabel('vertical axis')
plt.xlim(6,12)
plt.ylim(0,10)
plt.xticks([6,9,12])
plt.yticks([0,4,8])
plt.text(10,2,'random text',color='blue',size=14)

# %% [markdown]
# One-dimensional numpy arrays may also be used as data series.  Below a sin function is plotted.
#
# The resulting plot may be saved as an image.

# %%
X=np.linspace(0,4*3.14,101)
Y=np.sin(X)
plt.plot(X,Y,'.')

### save file
plt.savefig('myplot.png')

# %%
#the resulting image
from IPython.display import Image
Image('myplot.png')

# %% [markdown]
# Bar plots are another type of graph which can be redered.

# %%
t=np.linspace(0,5*3.14,51)
s=(9*np.sin(t)/((t+1)))+0.5*t+3*(np.random.randn(51)/(2+t/2.5))**2
plt.bar(t,s,edgecolor='black', width=0.2)
# Out:
# <Container object of 51 artists>

# %%
#horizontal bar plot
plt.barh(t[:10],s[:10], height=0.3)
# Out:
# <Container object of 10 artists>

# %% [markdown]
# Scatter plots are also useful.
#
# Below are four 2-D standard normal distributions centered at (2,2),(2,-2),(-2,2),(-2,-2)

# %%
N=400
D=2

X=np.random.randn(N,D)

X[:200,:] = X[:200,:] - 2*np.ones((200,D))
X[200:,:] = X[200:,:] + 2*np.ones((200,D))
X[100:300,0]=-X[100:300,0]

#note how colors are assigned with a list
T=np.array([0]*100 + [1]*100 + [2]*100 + [3]*100)
 
plt.scatter(X[:,0],X[:,1],c=T,s=100, alpha=0.3)

# %% [markdown]
# **Exercise 0**
#
# The code below creates a pandas data frame from the file 'gold_hist.txt'.  It contains historical gold prices (end of year) from 1792 to 2015.
#
# - Plot the data with time on the horizontal axis and gold price on the vertical.  Provide a title and labels for the horizontal and vertical axes.
# - Plot the the data again using a log vertical scale.
# Use `plt.yscale('log')`
#
# - The US dollar was removed from a gold standard in 1973.  Plot the data again, on a linear scale (normal scale), from 1972 and after.  Label the point representing peak price.

# %%
f = open('gold_hist.txt', 'r')
lines = f.readlines()
f.close()
lines=list(map(lambda x: x.strip() ,lines))
prices=[[int(lines[2*i]),float(lines[2*i+1][1:].replace(',',''))]\
        for i in range(int(len(lines)/2)) ]
prices.sort()
gold=pd.DataFrame(prices,columns=['year','price'])
gold.head(2)
# Out:
#    year  price
# 0  1792  19.39
# 1  1793  19.39

# %%
#your code here
P=gold['price']
T=gold['year']
plt.plot(T,P,'.')
plt.xlabel('Year')
plt.ylabel('Price in Dollars')
plt.title('Historical Gold Price')

# %%
P=gold['price']
T=gold['year']
plt.plot(T,P,'.')
plt.xlabel('Year')
plt.ylabel('Price in Dollars')
plt.yscale('log')
plt.title('Historical Gold Price')

# %%
high=gold.price.max()
high
# Out:
# 1664.0

# %%
int(gold.loc[gold.price==high].iloc[0,0])
# Out:
# 2012

# %%
#gold.loc[gold.year>1971]

# %%
peak_year=gold.loc[gold.price==peak_price,'year'].tolist()[0]
peak_year
# Out:
# 2012

# %%
peak_price=gold['price'].max()
#peak_year=gold.loc[gold.price==peak_price,'year'].tolist()[0]
peak_year=int(gold.loc[gold.price==high].iloc[0,0])

gold72=gold[gold['year']>=1972]
P=gold72['price']
T=gold72['year']
plt.plot(T,P,'.')
plt.xlabel('Year')
plt.ylabel('Price in Dollars')
plt.title('Historical Gold Price')
plt.text(peak_year,peak_price,'$%i '%(peak_price),color='black',size=10,
          fontweight='bold',verticalalignment='center',horizontalalignment='right')

# %% [markdown]
# # Case Study

# %% [markdown]
# For this case study use the IMDB dataset.  It was scraped and uploaded to Kaggle by Sun Chuan (graduate of Bootcamp 6). Check it out [here](https://www.kaggle.com/deepmatrix/imdb-5000-movie-dataset).
#
# Load the data first.

# %%
df = pd.read_csv('movie_metadata.csv')

# %%
df.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# 1                 40000.0  309404152.0         Action|Adventure|Fantasy
# 2                 11000.0  200074175.0        Action|Adventure|Thriller
# 3                 27000.0  448130642.0                  Action|Thriller
# 4                   131.0          NaN                      Documentary
#
#           ...          num_user_for_reviews language  country  content_rating  \
# 0         ...                        3054.0  English      USA           PG-13
# 1         ...                        1238.0  English      USA           PG-13
# 2         ...                         994.0  English       UK           PG-13
# 3         ...                        2701.0  English      USA           PG-13
# 4         ...                           NaN      NaN      NaN             NaN
#
#         budget  title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 0  237000000.0      2009.0                  936.0        7.9          1.78
# 1  300000000.0      2007.0                 5000.0        7.1          2.35
# 2  245000000.0      2015.0                  393.0        6.8          2.35
# 3  250000000.0      2012.0                23000.0        8.5          2.35
# 4          NaN         NaN                   12.0        7.1           NaN
#
#   movie_facebook_likes
# 0                33000
# 1                    0
# 2                85000
# 3               164000
# 4                    0
#
# [5 rows x 28 columns]

# %%
df.shape
# Out:
# (5043, 28)

# %% [markdown]
# To display the full data frame set the maximum number of columns shown, as follows:

# %%
pd.set_option('display.max_columns', df.shape[1])

# %%
df.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# 1                 40000.0  309404152.0         Action|Adventure|Fantasy
# 2                 11000.0  200074175.0        Action|Adventure|Thriller
# 3                 27000.0  448130642.0                  Action|Thriller
# 4                   131.0          NaN                      Documentary
#
#       actor_1_name                                        movie_title  \
# 0      CCH Pounder                                            Avatar
# 1      Johnny Depp          Pirates of the Caribbean: At World's End
# 2  Christoph Waltz                                           Spectre
# 3        Tom Hardy                             The Dark Knight Rises
# 4      Doug Walker  Star Wars: Episode VII - The Force Awakens    ...
#
#    num_voted_users  cast_total_facebook_likes          actor_3_name  \
# 0           886204                       4834             Wes Studi
# 1           471220                      48350        Jack Davenport
# 2           275868                      11700      Stephanie Sigman
# 3          1144337                     106759  Joseph Gordon-Levitt
# 4                8                        143                   NaN
#
#    facenumber_in_poster                                      plot_keywords  \
# 0                   0.0             avatar|future|marine|native|paraplegic
# 1                   0.0  goddess|marriage ceremony|marriage proposal|pi...
# 2                   1.0                bomb|espionage|sequel|spy|terrorist
# 3                   0.0  deception|imprisonment|lawlessness|police offi...
# 4                   0.0                                                NaN
#
#                                      movie_imdb_link  num_user_for_reviews  \
# 0  http://www.imdb.com/title/tt0499549/?ref_=fn_t...                3054.0
# 1  http://www.imdb.com/title/tt0449088/?ref_=fn_t...                1238.0
# 2  http://www.imdb.com/title/tt2379713/?ref_=fn_t...                 994.0
# 3  http://www.imdb.com/title/tt1345836/?ref_=fn_t...                2701.0
# 4  http://www.imdb.com/title/tt5289954/?ref_=fn_t...                   NaN
#
#   language country content_rating       budget  title_year  \
# 0  English     USA          PG-13  237000000.0      2009.0
# 1  English     USA          PG-13  300000000.0      2007.0
# 2  English      UK          PG-13  245000000.0      2015.0
# 3  English     USA          PG-13  250000000.0      2012.0
# 4      NaN     NaN            NaN          NaN         NaN
#
#    actor_2_facebook_likes  imdb_score  aspect_ratio  movie_facebook_likes
# 0                   936.0         7.9          1.78                 33000
# 1                  5000.0         7.1          2.35                     0
# 2                   393.0         6.8          2.35                 85000
# 3                 23000.0         8.5          2.35                164000
# 4                    12.0         7.1           NaN                     0

# %% [markdown]
# Describe will exclude the missing value by default.

# %%
#df.describe()
df.dropna().describe()
# Out:
#        num_critic_for_reviews     duration  director_facebook_likes  \
# count             3756.000000  3756.000000              3756.000000
# mean               167.378328   110.257987               807.336528
# std                123.452040    22.646717              3068.171683
# min                  2.000000    37.000000                 0.000000
# 25%                 77.000000    96.000000                11.000000
# 50%                138.500000   106.000000                64.000000
# 75%                224.000000   120.000000               235.000000
# max                813.000000   330.000000             23000.000000
#
#        actor_3_facebook_likes  actor_1_facebook_likes         gross  \
# count             3756.000000             3756.000000  3.756000e+03
# mean               771.279553             7751.338658  5.261282e+07
# std               1894.249869            15519.339621  7.031787e+07
# min                  0.000000                0.000000  1.620000e+02
# 25%                194.000000              745.000000  8.270233e+06
# 50%                436.000000             1000.000000  3.009311e+07
# 75%                691.000000            13000.000000  6.688194e+07
# max              23000.000000           640000.000000  7.605058e+08
#
#        num_voted_users  cast_total_facebook_likes  facenumber_in_poster  \
# count     3.756000e+03                3756.000000           3756.000000
# mean      1.058267e+05               11527.101970              1.377263
# std       1.520354e+05               19122.176905              2.041541
# min       9.100000e+01                   0.000000              0.000000
# 25%       1.966700e+04                1919.750000              0.000000
# 50%       5.397350e+04                4059.500000              1.000000
# 75%       1.286020e+05               16240.000000              2.000000
# max       1.689764e+06              656730.000000             43.000000
#
#        num_user_for_reviews        budget   title_year  \
# count           3756.000000  3.756000e+03  3756.000000
# mean             336.843184  4.623685e+07  2002.976571
# std              411.227368  2.260103e+08     9.888108
# min                4.000000  2.180000e+02  1927.000000
# 25%              110.000000  1.000000e+07  1999.000000
# 50%              210.000000  2.500000e+07  2004.000000
# 75%              398.250000  5.000000e+07  2010.000000
# max             5060.000000  1.221550e+10  2016.000000
#
#        actor_2_facebook_likes   imdb_score  aspect_ratio  movie_facebook_likes
# count             3756.000000  3756.000000   3756.000000           3756.000000
# mean              2021.775825     6.465282      2.111014           9353.829340
# std               4544.908236     1.056247      0.353068          21462.889123
# min                  0.000000     1.600000      1.180000              0.000000
# 25%                384.750000     5.900000      1.850000              0.000000
# 50%                685.500000     6.600000      2.350000            227.000000
# 75%                976.000000     7.200000      2.350000          11000.000000
# max             137000.000000     9.300000     16.000000         349000.000000

# %% [markdown]
# `value_counts()` will return a frequency count for every value in a column.

# %%
df['language'].value_counts()
# Out:
# English       4704
# French          73
# Spanish         40
# Hindi           28
# Mandarin        26
# German          19
# Japanese        18
# Russian         11
# Cantonese       11
# Italian         11
# Korean           8
# Portuguese       8
# Swedish          5
# Hebrew           5
# Danish           5
# Arabic           5
# Persian          4
# Norwegian        4
# Polish           4
# Dutch            4
# Chinese          3
# Thai             3
# Romanian         2
# None             2
# Zulu             2
# Dari             2
# Aboriginal       2
# Icelandic        2
# Indonesian       2
# Czech            1
# Maya             1
# Kannada          1
# Kazakh           1
# Greek            1
# Filipino         1
# Mongolian        1
# Telugu           1
# Slovenian        1
# Aramaic          1
# Tamil            1
# Bosnian          1
# Dzongkha         1
# Vietnamese       1
# Urdu             1
# Swahili          1
# Hungarian        1
# Panjabi          1
# Name: language, dtype: int64

# %%
df['director_name'].value_counts()
# Out:
# Steven Spielberg        26
# Woody Allen             22
# Martin Scorsese         20
# Clint Eastwood          20
# Ridley Scott            17
# Spike Lee               16
# Steven Soderbergh       16
# Tim Burton              16
# Renny Harlin            15
# Oliver Stone            14
# Robert Zemeckis         13
# Sam Raimi               13
# Joel Schumacher         13
# Ron Howard              13
# John Carpenter          13
# Michael Bay             13
# Barry Levinson          13
# Robert Rodriguez        13
# Richard Donner          12
# Peter Jackson           12
# Tony Scott              12
# Kevin Smith             12
# Shawn Levy              12
# Wes Craven              12
# Brian De Palma          12
# Stephen Frears          11
# Francis Ford Coppola    11
# Chris Columbus          11
# Rob Reiner              11
# Rob Cohen               11
#                         ..
# Conor McPherson          1
# Kate Connor              1
# David Winning            1
# James Ponsoldt           1
# Gnana Rajasekaran        1
# Noam Murro               1
# Alex Gibney              1
# Julio DePietro           1
# Travis Cluff             1
# Jim Sonzero              1
# David Hayter             1
# Sam Levinson             1
# Dewey Nicks              1
# Wilson Yip               1
# Reed Cowan               1
# Mona Fastvold            1
# Randall Rubin            1
# Frank LaLoggia           1
# J Blakeson               1
# Andy Garcia              1
# John Cromwell            1
# Richard Wallace          1
# Kaige Chen               1
# Ken Del Conte            1
# Bryan Barber             1
# John Ottman              1
# James Manera             1
# Piyush Dinker Pandya     1
# Stevan Mena              1
# Romesh Sharma            1
# Name: director_name, dtype: int64

# %% [markdown]
# # Histogram

# %%
plt.hist(df['imdb_score'],edgecolor='k')
# Out:
# (array([   16.,    38.,   102.,   222.,   579.,  1158.,  1515.,  1085.,
#           307.,    21.]),
#  array([ 1.6 ,  2.39,  3.18,  3.97,  4.76,  5.55,  6.34,  7.13,  7.92,
#          8.71,  9.5 ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# Explore some of the available parameters by placing the cursor inside the function parentheses and pressing **shift+tab**
#
# It is possible to set the color and the number of bins. For color, type `"blue"` or `"b"` for short. Color accepts hex color code, pick a color from this [website](http://www.color-hex.com/) and paste the hexadecimal code.

# %%
import seaborn as sns
sns.distplot(df['imdb_score'])
# Out:
# //anaconda/lib/python3.6/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
plt.hist(df['imdb_score'], bins=20, color="#666699", orientation="horizontal")
# Out:
# (array([   5.,   11.,   12.,   26.,   51.,   51.,   95.,  127.,  217.,
#          362.,  497.,  661.,  795.,  720.,  666.,  419.,  226.,   81.,
#           18.,    3.]),
#  array([ 1.6  ,  1.995,  2.39 ,  2.785,  3.18 ,  3.575,  3.97 ,  4.365,
#          4.76 ,  5.155,  5.55 ,  5.945,  6.34 ,  6.735,  7.13 ,  7.525,
#          7.92 ,  8.315,  8.71 ,  9.105,  9.5  ]),
#  <a list of 20 Patch objects>)

# %% [markdown]
# ### Exercise 1
#
# - Create a histogram of the budget column. Does Python raise an error? Fix it by following this [Stack Overflow Link](http://stackoverflow.com/q/20656663)
#
# - How does the graph look? Is there anyway to improve this? What does the x-axis stand for?
# - All the code in the same cell will contribute to the same plot.
# - Type `plt.` and press tab to get a hint.

# %%
#### Your code here
plt.hist(df.budget.dropna())
# Out:
# (array([  4.54600000e+03,   2.00000000e+00,   1.00000000e+00,
#           1.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           1.00000000e+00]),
#  array([  2.18000000e+02,   1.22155020e+09,   2.44310017e+09,
#           3.66465015e+09,   4.88620013e+09,   6.10775011e+09,
#           7.32930009e+09,   8.55085007e+09,   9.77240004e+09,
#           1.09939500e+10,   1.22155000e+10]),
#  <a list of 10 Patch objects>)

# %%
df.sort_values('budget',ascending=False)
# Out:
#                  color        director_name  num_critic_for_reviews  duration  \
# 2988             Color         Joon-ho Bong                   363.0     110.0
# 3859             Color       Chan-wook Park                   202.0     112.0
# 3005             Color         Lajos Koltai                    73.0     134.0
# 2323             Color       Hayao Miyazaki                   174.0     134.0
# 2334             Color      Katsuhiro Ôtomo                   105.0     103.0
# 3423             Color      Katsuhiro Ôtomo                   150.0     124.0
# 4542             Color        Takao Okawara                   107.0      99.0
# 3075             Color          Karan Johar                    20.0     193.0
# 3851             Color         Carlos Saura                    35.0     115.0
# 3273             Color          Anurag Basu                    41.0      90.0
# 1338             Color             John Woo                   160.0     150.0
# 3311             Color  Chatrichalerm Yukol                    31.0     300.0
# 1016             Color           Luc Besson                   111.0     158.0
# 2740             Color             Tony Jaa                   110.0     110.0
# 1                Color       Gore Verbinski                   302.0     169.0
# 5                Color       Andrew Stanton                   462.0     132.0
# 7                Color         Nathan Greno                   324.0     100.0
# 6                Color            Sam Raimi                   392.0     156.0
# 3461             Color            Sam Raimi                   392.0     156.0
# 10               Color          Zack Snyder                   673.0     183.0
# 9                Color          David Yates                   375.0     153.0
# 8                Color          Joss Whedon                   635.0     141.0
# 18               Color         Rob Marshall                   448.0     136.0
# 20               Color        Peter Jackson                   422.0     164.0
# 3                Color    Christopher Nolan                   813.0     164.0
# 27               Color        Anthony Russo                   516.0     147.0
# 2                Color           Sam Mendes                   602.0     148.0
# 0                Color        James Cameron                   723.0     178.0
# 21               Color            Marc Webb                   599.0     153.0
# 15               Color          Zack Snyder                   733.0     143.0
# ...                ...                  ...                     ...       ...
# 4902             Color           Tom Tykwer                    76.0     119.0
# 4909             Color          Jay Duplass                    93.0      84.0
# 4910             Color      Livingston Oden                     1.0      89.0
# 4912   Black and White  Carl Theodor Dreyer                    54.0     126.0
# 4913             Color       Marianna Palka                    38.0      86.0
# 4919             Color         Rania Attieh                    18.0      93.0
# 4927             Color          Jason Stone                    48.0     108.0
# 4934             Color           Pat Holden                    44.0      86.0
# 4935             Color          Eric Bugbee                     2.0      98.0
# 4944             Color       Zal Batmanglij                   136.0      85.0
# 4960             Color        Peter Chelsom                    57.0     100.0
# 4967   Black and White       John Reinhardt                     1.0      68.0
# 4969             Color        Laslo Benedek                    14.0     106.0
# 4974             Color          Julie Davis                     5.0      86.0
# 4982             Color     Daniel Schechter                    15.0      87.0
# 4985             Color         Matt Johnson                    73.0      83.0
# 4986             Color        Bruno Barreto                     1.0      99.0
# 4989             Color       Daniel Mellitz                     NaN       NaN
# 5001             Color      Martin Scorsese                    71.0     117.0
# 5003             Color    Bradley Rust Gray                    61.0      79.0
# 5005   Black and White      Andrew Bujalski                    52.0     109.0
# 5007             Color         Ben Wheatley                    53.0      93.0
# 5010             Color      Andrew Bujalski                    43.0      85.0
# 5014             Color             Uwe Boll                    58.0      80.0
# 5019             Color        Marcus Nispel                    43.0      91.0
# 5030             Color         Tadeo Garcia                     NaN      84.0
# 5032             Color      Ash Baron-Cohen                    10.0      98.0
# 5038             Color          Scott Smith                     1.0      87.0
# 5039             Color                  NaN                    43.0      43.0
# 5041             Color          Daniel Hsia                    14.0     100.0
#
#       director_facebook_likes  actor_3_facebook_likes            actor_2_name  \
# 2988                    584.0                    74.0            Kang-ho Song
# 3859                      0.0                    38.0            Yeong-ae Lee
# 3005                     45.0                     0.0         Péter Fancsikai
# 2323                   6000.0                   745.0      Jada Pinkett Smith
# 2334                     78.0                   101.0      Robin Atkin Downes
# 3423                     78.0                     4.0           Takeshi Kusao
# 4542                      2.0                     3.0           Naomi Nishida
# 3075                    160.0                   860.0            John Abraham
# 3851                     98.0                     4.0      Juan Luis Galiardo
# 3273                    116.0                   303.0  Steven Michael Quezada
# 1338                    610.0                   478.0     Tony Chiu Wai Leung
# 3311                      6.0                     6.0    Chatchai Plengpanich
# 1016                      0.0                    15.0            David Bailie
# 2740                      0.0                     7.0     Petchtai Wongkamlao
# 1                       563.0                  1000.0           Orlando Bloom
# 5                       475.0                   530.0         Samantha Morton
# 7                        15.0                   284.0            Donna Murphy
# 6                         0.0                  4000.0            James Franco
# 3461                      0.0                  4000.0            James Franco
# 10                        0.0                  2000.0            Lauren Cohan
# 9                       282.0                 10000.0        Daniel Radcliffe
# 8                         0.0                 19000.0       Robert Downey Jr.
# 18                      252.0                  1000.0             Sam Claflin
# 20                        0.0                   773.0              Adam Brown
# 3                     22000.0                 23000.0          Christian Bale
# 27                       94.0                 11000.0      Scarlett Johansson
# 2                         0.0                   161.0            Rory Kinnear
# 0                         0.0                   855.0        Joel David Moore
# 21                      464.0                   963.0         Andrew Garfield
# 15                        0.0                   748.0      Christopher Meloni
# ...                       ...                     ...                     ...
# 4902                    670.0                     9.0      Sebastian Schipper
# 4909                    157.0                    98.0        Jennifer Lafleur
# 4910                      0.0                    15.0       Victoria Lachelle
# 4912                    147.0                     0.0        Sylvia Eckhausen
# 4913                    123.0                   782.0            Martin Starr
# 4919                      0.0                    75.0          Robin Bartlett
# 4927                     14.0                   826.0           Ellen Burstyn
# 4934                      6.0                   115.0         Martin Compston
# 4935                      0.0                    21.0              Bill Allen
# 4944                    129.0                   100.0          James Urbaniak
# 4960                     23.0                   545.0            Elden Henson
# 4967                      2.0                    75.0            John Ireland
# 4969                      6.0                    13.0           Trevor Howard
# 4974                     12.0                   117.0     Meredith Scott Lynn
# 4982                      8.0                   272.0          Kevin Corrigan
# 4985                      8.0                     8.0        Shailene Garnett
# 4986                      9.0                     3.0             Sonia Braga
# 4989                      0.0                    15.0            Chelse Swain
# 5001                  17000.0                   476.0              Levon Helm
# 5003                      2.0                    20.0            Mark Rendall
# 5005                     26.0                     3.0        Kate Dollenmayer
# 5007                    214.0                    59.0                Tony Way
# 5010                     26.0                     3.0        Kate Dollenmayer
# 5014                    892.0                   492.0      Katharine Isabelle
# 5019                    158.0                   265.0         Brittany Curran
# 5030                      5.0                    12.0          Michael Cortez
# 5032                      3.0                   152.0       Stanley B. Herman
# 5038                      2.0                   318.0           Daphne Zuniga
# 5039                      NaN                   319.0           Valorie Curry
# 5041                      0.0                   489.0           Daniel Henney
#
#       actor_1_facebook_likes        gross  \
# 2988                   629.0    2201412.0
# 3859                   717.0     211667.0
# 3005                     9.0     195888.0
# 2323                   893.0    2298191.0
# 2334                   488.0     410388.0
# 3423                     6.0     439162.0
# 4542                    43.0   10037390.0
# 3075                  8000.0    3275443.0
# 3851                   341.0    1687311.0
# 3273                   594.0    1602466.0
# 1338                   755.0     626809.0
# 3311                     7.0     454255.0
# 1016                    51.0   14131298.0
# 2740                    64.0     102055.0
# 1                    40000.0  309404152.0
# 5                      640.0   73058679.0
# 7                      799.0  200807262.0
# 6                    24000.0  336530303.0
# 3461                 24000.0  336530303.0
# 10                   15000.0  330249062.0
# 9                    25000.0  301956980.0
# 8                    26000.0  458991599.0
# 18                   40000.0  241063875.0
# 20                    5000.0  255108370.0
# 3                    27000.0  448130642.0
# 27                   21000.0  407197282.0
# 2                    11000.0  200074175.0
# 0                     1000.0  760505847.0
# 21                   15000.0  262030663.0
# 15                   15000.0  291021565.0
# ...                      ...          ...
# 4902                    24.0      59774.0
# 4909                   962.0     140016.0
# 4910                   138.0          NaN
# 4912                     0.0          NaN
# 4913                  3000.0      15542.0
# 4919                   110.0          NaN
# 4927                  2000.0          NaN
# 4934                   498.0          NaN
# 4935                    52.0          NaN
# 4944                   120.0     405614.0
# 4960                  1000.0    2643689.0
# 4967                   142.0          NaN
# 4969                   440.0          NaN
# 4974                   238.0      33598.0
# 4982                   969.0          NaN
# 4985                   111.0          NaN
# 4986                   866.0          NaN
# 4989                  1000.0          NaN
# 5001                   725.0     321952.0
# 5003                   962.0      24705.0
# 5005                    26.0          NaN
# 5007                   177.0       9609.0
# 5010                    26.0          NaN
# 5014                   986.0          NaN
# 5019                   630.0          NaN
# 5030                    21.0          NaN
# 5032                   789.0          NaN
# 5038                   637.0          NaN
# 5039                   841.0          NaN
# 5041                   946.0      10443.0
#
#                                                  genres          actor_1_name  \
# 2988                         Comedy|Drama|Horror|Sci-Fi             Doona Bae
# 3859                                        Crime|Drama          Min-sik Choi
# 3005                                  Drama|Romance|War          Marcell Nagy
# 2323                        Adventure|Animation|Fantasy         Minnie Driver
# 2334  Action|Adventure|Animation|Family|Sci-Fi|Thriller      William Hootkins
# 3423                            Action|Animation|Sci-Fi          Mitsuo Iwata
# 4542             Action|Adventure|Drama|Sci-Fi|Thriller           Hiroshi Abe
# 3075                                              Drama        Shah Rukh Khan
# 3851                                      Drama|Musical           Mía Maestro
# 3273                      Action|Drama|Romance|Thriller          Bárbara Mori
# 1338                 Action|Adventure|Drama|History|War     Takeshi Kaneshiro
# 3311                 Action|Adventure|Drama|History|War  Sarunyu Wongkrachang
# 1016              Adventure|Biography|Drama|History|War           Paul Brooke
# 2740                                             Action      Nirut Sirichanya
# 1                              Action|Adventure|Fantasy           Johnny Depp
# 5                               Action|Adventure|Sci-Fi          Daryl Sabara
# 7     Adventure|Animation|Comedy|Family|Fantasy|Musi...          Brad Garrett
# 6                              Action|Adventure|Romance          J.K. Simmons
# 3461                           Action|Adventure|Romance          J.K. Simmons
# 10                              Action|Adventure|Sci-Fi          Henry Cavill
# 9                      Adventure|Family|Fantasy|Mystery          Alan Rickman
# 8                               Action|Adventure|Sci-Fi       Chris Hemsworth
# 18                             Action|Adventure|Fantasy           Johnny Depp
# 20                                    Adventure|Fantasy          Aidan Turner
# 3                                       Action|Thriller             Tom Hardy
# 27                              Action|Adventure|Sci-Fi     Robert Downey Jr.
# 2                             Action|Adventure|Thriller       Christoph Waltz
# 0                       Action|Adventure|Fantasy|Sci-Fi           CCH Pounder
# 21                             Action|Adventure|Fantasy            Emma Stone
# 15                      Action|Adventure|Fantasy|Sci-Fi          Henry Cavill
# ...                                                 ...                   ...
# 4902                               Comedy|Drama|Romance        Devid Striesow
# 4909                        Comedy|Drama|Horror|Romance          Greta Gerwig
# 4910                     Comedy|Horror|Mystery|Thriller        Susan Chambers
# 4912                                      Drama|Fantasy         Hanne Aagesen
# 4913                               Comedy|Drama|Romance   Bryce Dallas Howard
# 4919                              Drama|Sci-Fi|Thriller          Paul Hickert
# 4927                                           Thriller          Topher Grace
# 4934                                             Horror            Alan Brent
# 4935                                 Action|Drama|Sport            Joel Moody
# 4944                      Drama|Mystery|Sci-Fi|Thriller    Christopher Denham
# 4960                                       Comedy|Drama         Kieran Culkin
# 4967                                        Crime|Drama       Sheldon Leonard
# 4969                              Crime|Horror|Thriller           Liv Ullmann
# 4974                                     Comedy|Romance            Jack McGee
# 4982                                             Comedy           Lena Dunham
# 4985                               Crime|Drama|Thriller    Paul Daniel Ayotte
# 4986                               Comedy|Drama|Romance  Marcello Mastroianni
# 4989                                       Comedy|Drama        Corbin Bernsen
# 5001                                  Documentary|Music           Ringo Starr
# 5003                                              Drama             Zoe Kazan
# 5005                                             Comedy       Andrew Bujalski
# 5007                                 Comedy|Crime|Drama        Michael Smiley
# 5010                                       Comedy|Drama       Andrew Bujalski
# 5014                              Action|Crime|Thriller           Matt Frewer
# 5019                            Horror|Mystery|Thriller       Ashley Tramonte
# 5030                                              Drama   Tatiana Suarez-Pico
# 5032                                        Crime|Drama          Peter Greene
# 5038                                       Comedy|Drama           Eric Mabius
# 5039                       Crime|Drama|Mystery|Thriller           Natalie Zea
# 5041                               Comedy|Drama|Romance             Alan Ruck
#
#                                        movie_title  num_voted_users  \
# 2988                                     The Host             68883
# 3859                               Lady Vengeance             53508
# 3005                                     Fateless              5603
# 2323                            Princess Mononoke            221552
# 2334                                     Steamboy             13727
# 3423                                        Akira            106160
# 4542                                Godzilla 2000              5442
# 3075                       Kabhi Alvida Naa Kehna             13998
# 3851                                        Tango              2412
# 3273                                        Kites              9673
# 1338                                    Red Cliff             36894
# 3311                     The Legend of Suriyothai              1666
# 1016      The Messenger: The Story of Joan of Arc             55889
# 2740                                    Ong-bak 2             24570
# 1        Pirates of the Caribbean: At World's End            471220
# 5                                     John Carter            212204
# 7                                         Tangled            294810
# 6                                    Spider-Man 3            383056
# 3461                                 Spider-Man 3            383071
# 10             Batman v Superman: Dawn of Justice            371639
# 9          Harry Potter and the Half-Blood Prince            321795
# 8                         Avengers: Age of Ultron            462669
# 18    Pirates of the Caribbean: On Stranger Tides            370704
# 20      The Hobbit: The Battle of the Five Armies            354228
# 3                           The Dark Knight Rises           1144337
# 27                     Captain America: Civil War            272670
# 2                                         Spectre            275868
# 0                                          Avatar            886204
# 21                         The Amazing Spider-Man            451803
# 15                                   Man of Steel            548573
# ...                                            ...              ...
# 4902                                            3              4212
# 4909                                      Baghead              3507
# 4910                                     Solitude                78
# 4912                                        Ordet              9903
# 4913                                    Good Dick              6689
# 4919                                           H.               191
# 4927                                  The Calling              6025
# 4934                     When the Lights Went Out              3813
# 4935                               Heroes of Dirt                53
# 4944                            Sound of My Voice             15775
# 4960                                   The Mighty             10499
# 4967                                  Open Secret                67
# 4969                            The Night Visitor               544
# 4974                  I Love You, Don't Touch Me!               405
# 4982                        Supporting Characters               760
# 4985                                  The Dirties              3885
# 4986                                     Gabriela               712
# 4989                                The Naked Ape               128
# 5001                               The Last Waltz             12611
# 5003                           The Exploding Girl              1516
# 5005                          Mutual Appreciation              1578
# 5007                                 Down Terrace              2646
# 5010                                  Funny Ha Ha              1894
# 5014                                      Rampage             15091
# 5019                                       Exeter              3836
# 5030                               On the Downlow               156
# 5032                                         Bang               438
# 5038                      Signed Sealed Delivered               629
# 5039                    The Following                         73839
# 5041                             Shanghai Calling              1255
#
#       cast_total_facebook_likes           actor_3_name  facenumber_in_poster  \
# 2988                       1173             Ah-sung Ko                   0.0
# 3859                        907         Hye-jeong Kang                   0.0
# 3005                         11          Bálint Péntek                   0.0
# 2323                       2710           Billy Crudup                   0.0
# 2334                        991         Rosalind Ayres                   1.0
# 3423                         28           Tesshô Genda                   0.0
# 4542                         53           Sakae Kimura                   0.0
# 3075                      10822           Preity Zinta                   2.0
# 3851                        371      Miguel Ángel Solá                   3.0
# 3273                       1836             Kabir Bedi                   0.0
# 1338                       2172               Wei Zhao                   4.0
# 3311                         32        Mai Charoenpura                   3.0
# 1016                        144            Rab Affleck                   0.0
# 2740                        134   Sarunyu Wongkrachang                   0.0
# 1                         48350         Jack Davenport                   0.0
# 5                          1873           Polly Walker                   1.0
# 7                          2036            M.C. Gainey                   1.0
# 6                         46055          Kirsten Dunst                   0.0
# 3461                      46055          Kirsten Dunst                   0.0
# 10                        24450         Alan D. Purwin                   0.0
# 9                         58753           Rupert Grint                   3.0
# 8                         92000     Scarlett Johansson                   4.0
# 18                        54083         Stephen Graham                   4.0
# 20                         9152          James Nesbitt                   0.0
# 3                        106759   Joseph Gordon-Levitt                   0.0
# 27                        64798            Chris Evans                   0.0
# 2                         11700       Stephanie Sigman                   1.0
# 0                          4834              Wes Studi                   0.0
# 21                        28489            Chris Zylka                   0.0
# 15                        20495           Harry Lennix                   0.0
# ...                         ...                    ...                   ...
# 4902                         69            Sophie Rois                   0.0
# 4909                       2016           Elise Muller                   0.0
# 4910                        192            Ali Daniels                   0.0
# 4912                          0       Ejner Federspiel                   0.0
# 4913                       7144           Jason Ritter                   0.0
# 4919                        338          Rebecca Dayan                   0.0
# 4927                       4385  Christopher Heyerdahl                   2.0
# 4934                        895          Kate Ashfield                   0.0
# 4935                        130             Lia Tucker                   0.0
# 4944                        511           Constance Wu                   0.0
# 4960                       2283          Gena Rowlands                   4.0
# 4967                        354       Arthur O'Connell                   3.0
# 4969                        564            Andrew Keir                   1.0
# 4974                        623             Tim DeZarn                   1.0
# 4982                       2398         Alex Karpovsky                   0.0
# 4985                        147           Matt Johnson                   0.0
# 4986                       1179          Joffre Soares                   0.0
# 4989                       1077       Amanda MacDonald                   0.0
# 5001                       2783              Bob Dylan                   0.0
# 5003                       1054          Jordan Scovel                   0.0
# 5005                         38            Justin Rice                   0.0
# 5007                        365           David Schaal                   4.0
# 5010                         40            Justin Rice                   1.0
# 5014                       3197           Michael Paré                   0.0
# 5019                       2679      Lindsay MacDonald                   0.0
# 5030                         62            Eric Ambriz                   2.0
# 5032                       1186            James Noble                   1.0
# 5038                       2283           Crystal Lowe                   2.0
# 5039                       1753          Sam Underwood                   1.0
# 5041                       2386            Eliza Coupe                   5.0
#
#                                           plot_keywords  \
# 2988             daughter|han river|monster|river|seoul
# 3859  cake|christian|lesbian sex|oral sex|pregnant s...
# 3005                   bus|death|gay slur|hatred|jewish
# 2323      anime|cult film|forest|princess|studio ghibli
# 2334               19th century|ball|boy|inventor|steam
# 3423  based on manga|biker gang|gifted child|post th...
# 4542                    godzilla|kaiju|monster|orga|ufo
# 3075  extramarital affair|fashion magazine editor|ma...
# 3851      dancer|director|love|musical filmmaking|tango
# 3273            casino|desert|love|suicide|tragic event
# 1338             alliance|battle|china|chinese|strategy
# 3311       16th century|burmese|invasion|queen|thailand
# 1016        cathedral|dauphin|france|trial|wartime rape
# 2740  cult film|elephant|jungle|martial arts|stylize...
# 1     goddess|marriage ceremony|marriage proposal|pi...
# 5     alien|american civil war|male nipple|mars|prin...
# 7     17th century|based on fairy tale|disney|flower...
# 6             sandman|spider man|symbiote|venom|villain
# 3461          sandman|spider man|symbiote|venom|villain
# 10    based on comic book|batman|sequel to a reboot|...
# 9                      blood|book|love|potion|professor
# 8     artificial intelligence|based on comic book|ca...
# 18            blackbeard|captain|pirate|revenge|soldier
# 20                     army|elf|hobbit|middle earth|orc
# 3     deception|imprisonment|lawlessness|police offi...
# 27    based on comic book|knife|marvel cinematic uni...
# 2                   bomb|espionage|sequel|spy|terrorist
# 0                avatar|future|marine|native|paraplegic
# 21            lizard|outcast|spider|spider man|teenager
# 15    based on comic book|british actor playing amer...
# ...                                                 ...
# 4902  female nudity|full frontal female nudity|male ...
# 4909          actor|cabin|california|paper bag|vomiting
# 4910                                                NaN
# 4912               august|doctor|faith|patriarch|prayer
# 4913  avoidant personality disorder|emotionally vuln...
# 4919                                                NaN
# 4927  bouquet|house fire|praying|serial killer|tied ...
# 4934  father daughter relationship|poltergeist|spiri...
# 4935                 bike|bmx|drugs|troubled teen|youth
# 4944  cult|cult leader|female nudity|greedy institut...
# 4960   book|friendship|knight|learning disability|tutor
# 4967                             anti semitism|gangster
# 4969  escape|independent film|mental illness|prison|...
# 4974  female frontal nudity|female rear nudity|title...
# 4982  film editor|kiss|marriage proposal|movie scree...
# 4985            best friend|bully|friend|revenge|school
# 4986  based on novel|brazil|female underarm hair|sex...
# 4989  coming of age|male nudity|road trip|skinny dip...
# 5001   band|final concert|guitar|interview|thanksgiving
# 5003        friend|hospital|low budget film|ring|stoned
# 5005  friendship|guitarist|mumblecore|musician|new york
# 5007                                       black comedy
# 5010                                         mumblecore
# 5014     death|first part|killing spree|massacre|murder
# 5019                 asylum|demon|party|secret|teenager
# 5030  gang initiation|gunplay|hazing|latino|shakespe...
# 5032  corruption|homeless|homeless man|motorcycle|ur...
# 5038             fraud|postal worker|prison|theft|trial
# 5039       cult|fbi|hideout|prison escape|serial killer
# 5041                                                NaN
#
#                                         movie_imdb_link  num_user_for_reviews  \
# 2988  http://www.imdb.com/title/tt0468492/?ref_=fn_t...                 279.0
# 3859  http://www.imdb.com/title/tt0451094/?ref_=fn_t...                 131.0
# 3005  http://www.imdb.com/title/tt0367082/?ref_=fn_t...                  45.0
# 2323  http://www.imdb.com/title/tt0119698/?ref_=fn_t...                 570.0
# 2334  http://www.imdb.com/title/tt0348121/?ref_=fn_t...                  79.0
# 3423  http://www.imdb.com/title/tt0094625/?ref_=fn_t...                 430.0
# 4542  http://www.imdb.com/title/tt0188640/?ref_=fn_t...                 140.0
# 3075  http://www.imdb.com/title/tt0449999/?ref_=fn_t...                 264.0
# 3851  http://www.imdb.com/title/tt0120274/?ref_=fn_t...                  40.0
# 3273  http://www.imdb.com/title/tt1198101/?ref_=fn_t...                 106.0
# 1338  http://www.imdb.com/title/tt0425637/?ref_=fn_t...                 105.0
# 3311  http://www.imdb.com/title/tt0290879/?ref_=fn_t...                  47.0
# 1016  http://www.imdb.com/title/tt0151137/?ref_=fn_t...                 390.0
# 2740  http://www.imdb.com/title/tt0785035/?ref_=fn_t...                  72.0
# 1     http://www.imdb.com/title/tt0449088/?ref_=fn_t...                1238.0
# 5     http://www.imdb.com/title/tt0401729/?ref_=fn_t...                 738.0
# 7     http://www.imdb.com/title/tt0398286/?ref_=fn_t...                 387.0
# 6     http://www.imdb.com/title/tt0413300/?ref_=fn_t...                1902.0
# 3461  http://www.imdb.com/title/tt0413300/?ref_=fn_t...                1902.0
# 10    http://www.imdb.com/title/tt2975590/?ref_=fn_t...                3018.0
# 9     http://www.imdb.com/title/tt0417741/?ref_=fn_t...                 973.0
# 8     http://www.imdb.com/title/tt2395427/?ref_=fn_t...                1117.0
# 18    http://www.imdb.com/title/tt1298650/?ref_=fn_t...                 484.0
# 20    http://www.imdb.com/title/tt2310332/?ref_=fn_t...                 802.0
# 3     http://www.imdb.com/title/tt1345836/?ref_=fn_t...                2701.0
# 27    http://www.imdb.com/title/tt3498820/?ref_=fn_t...                1022.0
# 2     http://www.imdb.com/title/tt2379713/?ref_=fn_t...                 994.0
# 0     http://www.imdb.com/title/tt0499549/?ref_=fn_t...                3054.0
# 21    http://www.imdb.com/title/tt0948470/?ref_=fn_t...                1225.0
# 15    http://www.imdb.com/title/tt0770828/?ref_=fn_t...                2536.0
# ...                                                 ...                   ...
# 4902  http://www.imdb.com/title/tt1517177/?ref_=fn_t...                  18.0
# 4909  http://www.imdb.com/title/tt0923600/?ref_=fn_t...                  40.0
# 4910  http://www.imdb.com/title/tt3565836/?ref_=fn_t...                   1.0
# 4912  http://www.imdb.com/title/tt0048452/?ref_=fn_t...                  49.0
# 4913  http://www.imdb.com/title/tt0944101/?ref_=fn_t...                  51.0
# 4919  http://www.imdb.com/title/tt3666210/?ref_=fn_t...                   1.0
# 4927  http://www.imdb.com/title/tt1666335/?ref_=fn_t...                  28.0
# 4934  http://www.imdb.com/title/tt1743993/?ref_=fn_t...                  27.0
# 4935  http://www.imdb.com/title/tt1934172/?ref_=fn_t...                   1.0
# 4944  http://www.imdb.com/title/tt1748207/?ref_=fn_t...                  69.0
# 4960  http://www.imdb.com/title/tt0119670/?ref_=fn_t...                 113.0
# 4967  http://www.imdb.com/title/tt0040671/?ref_=fn_t...                   9.0
# 4969  http://www.imdb.com/title/tt0066141/?ref_=fn_t...                  19.0
# 4974  http://www.imdb.com/title/tt0130019/?ref_=fn_t...                  15.0
# 4982  http://www.imdb.com/title/tt1874789/?ref_=fn_t...                   4.0
# 4985  http://www.imdb.com/title/tt2334896/?ref_=fn_t...                  40.0
# 4986  http://www.imdb.com/title/tt0085575/?ref_=fn_t...                   9.0
# 4989  http://www.imdb.com/title/tt0381053/?ref_=fn_t...                   3.0
# 5001  http://www.imdb.com/title/tt0077838/?ref_=fn_t...                 113.0
# 5003  http://www.imdb.com/title/tt1294161/?ref_=fn_t...                  10.0
# 5005  http://www.imdb.com/title/tt0446747/?ref_=fn_t...                  23.0
# 5007  http://www.imdb.com/title/tt1489167/?ref_=fn_t...                  22.0
# 5010  http://www.imdb.com/title/tt0327753/?ref_=fn_t...                  61.0
# 5014  http://www.imdb.com/title/tt1337057/?ref_=fn_t...                 129.0
# 5019  http://www.imdb.com/title/tt1945044/?ref_=fn_t...                  33.0
# 5030  http://www.imdb.com/title/tt0390323/?ref_=fn_t...                   3.0
# 5032  http://www.imdb.com/title/tt0109266/?ref_=fn_t...                  14.0
# 5038  http://www.imdb.com/title/tt3000844/?ref_=fn_t...                   6.0
# 5039  http://www.imdb.com/title/tt2071645/?ref_=fn_t...                 359.0
# 5041  http://www.imdb.com/title/tt2070597/?ref_=fn_t...                   9.0
#
#         language      country content_rating        budget  title_year  \
# 2988      Korean  South Korea              R  1.221550e+10      2006.0
# 3859      Korean  South Korea              R  4.200000e+09      2005.0
# 3005   Hungarian      Hungary              R  2.500000e+09      2005.0
# 2323    Japanese        Japan          PG-13  2.400000e+09      1997.0
# 2334    Japanese        Japan          PG-13  2.127520e+09      2004.0
# 3423    Japanese        Japan              R  1.100000e+09      1988.0
# 4542    Japanese        Japan             PG  1.000000e+09      1999.0
# 3075       Hindi        India              R  7.000000e+08      2006.0
# 3851     Spanish        Spain          PG-13  7.000000e+08      1998.0
# 3273     English        India            NaN  6.000000e+08      2010.0
# 1338    Mandarin        China              R  5.536320e+08      2008.0
# 3311        Thai     Thailand              R  4.000000e+08      2001.0
# 1016     English       France              R  3.900000e+08      1999.0
# 2740        Thai     Thailand              R  3.000000e+08      2008.0
# 1        English          USA          PG-13  3.000000e+08      2007.0
# 5        English          USA          PG-13  2.637000e+08      2012.0
# 7        English          USA             PG  2.600000e+08      2010.0
# 6        English          USA          PG-13  2.580000e+08      2007.0
# 3461     English          USA          PG-13  2.580000e+08      2007.0
# 10       English          USA          PG-13  2.500000e+08      2016.0
# 9        English           UK             PG  2.500000e+08      2009.0
# 8        English          USA          PG-13  2.500000e+08      2015.0
# 18       English          USA          PG-13  2.500000e+08      2011.0
# 20       English  New Zealand          PG-13  2.500000e+08      2014.0
# 3        English          USA          PG-13  2.500000e+08      2012.0
# 27       English          USA          PG-13  2.500000e+08      2016.0
# 2        English           UK          PG-13  2.450000e+08      2015.0
# 0        English          USA          PG-13  2.370000e+08      2009.0
# 21       English          USA          PG-13  2.300000e+08      2012.0
# 15       English          USA          PG-13  2.250000e+08      2013.0
# ...          ...          ...            ...           ...         ...
# 4902      German      Germany        Unrated           NaN      2010.0
# 4909     English          USA              R           NaN      2008.0
# 4910     English          USA            NaN           NaN      2014.0
# 4912      Danish      Denmark      Not Rated           NaN      1955.0
# 4913     English          USA              R           NaN      2008.0
# 4919     English          USA            NaN           NaN      2014.0
# 4927     English          USA              R           NaN      2014.0
# 4934     English           UK            NaN           NaN      2012.0
# 4935     English          USA          PG-13           NaN      2015.0
# 4944     English          USA              R           NaN      2011.0
# 4960     English          USA          PG-13           NaN      1998.0
# 4967     English          USA       Approved           NaN      1948.0
# 4969     English          USA             GP           NaN      1971.0
# 4974     English          USA              R           NaN      1997.0
# 4982     English          USA      Not Rated           NaN      2012.0
# 4985     English       Canada      Not Rated           NaN      2013.0
# 4986  Portuguese       Brazil              R           NaN      1983.0
# 4989     English          USA            NaN           NaN      2006.0
# 5001     English          USA             PG           NaN      1978.0
# 5003     English          USA        Unrated           NaN      2009.0
# 5005     English          USA              R           NaN      2005.0
# 5007     English           UK              R           NaN      2009.0
# 5010     English          USA            NaN           NaN      2002.0
# 5014     English       Canada              R           NaN      2009.0
# 5019     English          USA              R           NaN      2015.0
# 5030     English          USA            NaN           NaN      2004.0
# 5032     English          USA            NaN           NaN      1995.0
# 5038     English       Canada            NaN           NaN      2013.0
# 5039     English          USA          TV-14           NaN         NaN
# 5041     English          USA          PG-13           NaN      2012.0
#
#       actor_2_facebook_likes  imdb_score  aspect_ratio  movie_facebook_likes
# 2988                   398.0         7.0          1.85                  7000
# 3859                   126.0         7.7          2.35                  4000
# 3005                     2.0         7.1          2.35                   607
# 2323                   851.0         8.4          1.85                 11000
# 2334                   336.0         6.9          1.85                   973
# 3423                     5.0         8.1          1.85                     0
# 4542                     3.0         6.0          2.35                   339
# 3075                  1000.0         6.0          2.35                   659
# 3851                    26.0         7.2          2.00                   539
# 3273                   412.0         6.0           NaN                     0
# 1338                   643.0         7.4          2.35                     0
# 3311                     6.0         6.6          1.85                   124
# 1016                    40.0         6.4          2.35                     0
# 2740                    45.0         6.2          2.35                     0
# 1                     5000.0         7.1          2.35                     0
# 5                      632.0         6.6          2.35                 24000
# 7                      553.0         7.8          1.85                 29000
# 6                    11000.0         6.2          2.35                     0
# 3461                 11000.0         6.2          2.35                     0
# 10                    4000.0         6.9          2.35                197000
# 9                    11000.0         7.5          2.35                 10000
# 8                    21000.0         7.5          2.35                118000
# 18                   11000.0         6.7          2.35                 58000
# 20                     972.0         7.5          2.35                 65000
# 3                    23000.0         8.5          2.35                164000
# 27                   19000.0         8.2          2.35                 72000
# 2                      393.0         6.8          2.35                 85000
# 0                      936.0         7.9          1.78                 33000
# 21                   10000.0         7.0          2.35                 56000
# 15                    3000.0         7.2          2.35                118000
# ...                      ...         ...           ...                   ...
# 4902                    20.0         6.8          2.35                  2000
# 4909                   873.0         6.0          1.85                   443
# 4910                    18.0         6.8           NaN                   267
# 4912                     0.0         8.1          1.37                   863
# 4913                   985.0         6.5          1.85                     0
# 4919                    79.0         6.3           NaN                   142
# 4927                  1000.0         5.8           NaN                     0
# 4934                   204.0         5.4          2.35                     0
# 4935                    36.0         7.1           NaN                   197
# 4944                   119.0         6.7          1.85                     0
# 4960                   577.0         7.3          1.85                     0
# 4967                    86.0         7.1          1.37                    10
# 4969                    98.0         6.8           NaN                    65
# 4974                   166.0         5.4           NaN                    97
# 4982                   778.0         6.3           NaN                   209
# 4985                    19.0         6.7           NaN                  1000
# 4986                   308.0         6.4          2.35                   114
# 4989                    36.0         4.7           NaN                     2
# 5001                   572.0         8.2          1.85                     0
# 5003                    72.0         6.3           NaN                   377
# 5005                     6.0         6.9          1.66                    91
# 5007                    95.0         6.5           NaN                   535
# 5010                     6.0         6.4          1.37                   108
# 5014                   918.0         6.3          2.35                     0
# 5019                   512.0         4.6          1.85                     0
# 5030                    20.0         6.1           NaN                    22
# 5032                   194.0         6.4           NaN                    20
# 5038                   470.0         7.7           NaN                    84
# 5039                   593.0         7.5         16.00                 32000
# 5041                   719.0         6.3          2.35                   660
#
# [5043 rows x 28 columns]

# %%
plt.figure(figsize=(12,6)) # This line changes the size of the plot. The width and height are in inches.
plt.hist(df.dropna()[df.country=='USA']['budget'],bins=20,edgecolor='k')
# Out:
# //anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   from ipykernel import kernelapp as app
# (array([ 990.,  696.,  395.,  285.,  172.,  123.,   74.,   52.,   42.,
#           59.,   16.,   28.,   11.,   22.,   10.,    2.,    5.,    4.,
#            0.,    1.]),
#  array([  2.18000000e+02,   1.50002071e+07,   3.00001962e+07,
#           4.50001853e+07,   6.00001744e+07,   7.50001635e+07,
#           9.00001526e+07,   1.05000142e+08,   1.20000131e+08,
#           1.35000120e+08,   1.50000109e+08,   1.65000098e+08,
#           1.80000087e+08,   1.95000076e+08,   2.10000065e+08,
#           2.25000054e+08,   2.40000044e+08,   2.55000033e+08,
#           2.70000022e+08,   2.85000011e+08,   3.00000000e+08]),
#  <a list of 20 Patch objects>)

# %% [markdown]
# - Pandas dataframe also provides plotting function. It is calling the matplotlib library behind the scenes.
# - Check all the available plots from the documenation [here](http://pandas.pydata.org/pandas-docs/version/0.19.2/visualization.html#visualization)

# %%
np.log(df[df.country=='USA']['budget']).plot.hist(bins=25)
plt.xlabel('log of budget')
plt.ylabel('count')
plt.title('Histogram of budget', fontsize=20)

# %% [markdown]
# # Scatterplot
# Scatterplots are useful for bivariate analysis. We can check the relationship between two columns.
# Suppose we want to figure out whether there is a relationship between the gross income and the budget.

# %%
plt.scatter(df[df.country=='USA']['budget'], df[df.country=='USA']['gross'])
plt.xlabel('Budget')
plt.ylabel('Gross Income')

# %%
#another way
plt.plot(df[df.country=='USA']['budget'], df[df.country=='USA']['gross'],'.')
plt.xlabel('Budget')
plt.ylabel('Gross Income')

# %% [markdown]
# Here is a way to plot it using the plotting function from pandas.

# %%
df1=df[df.country=='USA']

# %%
df1.plot(x='budget', y='gross',kind='scatter')
plt.xlabel('Budget')
plt.ylabel('Gross Income')

# %%
#another way
df1.plot.scatter(x='budget', y='gross')
plt.xlabel('Budget')
plt.ylabel('Gross Income')

# %% [markdown]
# There are some outliers which make the graph less useful. Remove them from the dataframe using the apply function.

# %%
scatter_df = df1[['gross', 'budget']]
scatter_df = scatter_df[scatter_df.apply(lambda x: np.abs(x - x.mean()) / x.std() < 3).all(axis=1)]

# %%
plt.scatter(scatter_df['budget'], scatter_df['gross'],alpha=0.1)

# %% [markdown]
# Now take a look at those outliers. In the previous example the ouliers were removed. Use the **~** symbol to invert the boolean mask.

# %%
not True
# Out:
# False

# %%
~pd.DataFrame([[True]])
# Out:
#        0
# 0  False

# %%
~pd.DataFrame([[False]])
# Out:
#       0
# 0  True

# %% [markdown]
# Merge the outlier dataframe with the original other features.  Sort by budget in descending order.

# %%
outliers = df1[['gross', 'budget']].dropna()
outliers = outliers[~outliers.apply(lambda x: np.abs(x - x.mean()) / x.std() < 3).all(axis=1)]
outliers.merge(df)[['gross', 'budget', 'movie_title']].sort_values(by='budget', ascending=False)
# Out:
#            gross       budget                                      movie_title
# 1    309404152.0  300000000.0        Pirates of the Caribbean: At World's End
# 3     73058679.0  263700000.0                                     John Carter
# 8    200807262.0  260000000.0                                         Tangled
# 4    336530303.0  258000000.0                                    Spider-Man 3
# 5    336530303.0  258000000.0                                    Spider-Man 3
# 6    336530303.0  258000000.0                                    Spider-Man 3
# 7    336530303.0  258000000.0                                    Spider-Man 3
# 20   241063875.0  250000000.0     Pirates of the Caribbean: On Stranger Tides
# 2    448130642.0  250000000.0                           The Dark Knight Rises
# 9    458991599.0  250000000.0                         Avengers: Age of Ultron
# 10   330249062.0  250000000.0              Batman v Superman: Dawn of Justice
# 27   407197282.0  250000000.0                      Captain America: Civil War
# 0    760505847.0  237000000.0                                          Avatar
# 22   262030663.0  230000000.0                          The Amazing Spider-Man
# 14   291021565.0  225000000.0                                    Man of Steel
# 15   141614023.0  225000000.0        The Chronicles of Narnia: Prince Caspian
# 21   179020854.0  225000000.0                                  Men in Black 3
# 12   423032628.0  225000000.0      Pirates of the Caribbean: Dead Man's Chest
# 24   258355354.0  225000000.0             The Hobbit: The Desolation of Smaug
# 16   623279547.0  220000000.0                                    The Avengers
# 17   623279547.0  220000000.0                                    The Avengers
# 18   623279547.0  220000000.0                                    The Avengers
# 19   623279547.0  220000000.0                                    The Avengers
# 13    89289910.0  215000000.0                                 The Lone Ranger
# 39   234903076.0  215000000.0                       Oz the Great and Powerful
# 42   234903076.0  215000000.0                       Oz the Great and Powerful
# 40   234903076.0  215000000.0                       Oz the Great and Powerful
# 41   234903076.0  215000000.0                       Oz the Great and Powerful
# 38   245428137.0  210000000.0                 Transformers: Age of Extinction
# 28    65173160.0  209000000.0                                      Battleship
# ..           ...          ...                                              ...
# 97   292298923.0  120000000.0       The Twilight Saga: Breaking Dawn - Part 2
# 96   292298923.0  120000000.0       The Twilight Saga: Breaking Dawn - Part 2
# 95   292298923.0  120000000.0       The Twilight Saga: Breaking Dawn - Part 2
# 94   292298923.0  120000000.0       The Twilight Saga: Breaking Dawn - Part 2
# 102  310675583.0  115000000.0    Star Wars: Episode II - Attack of the Clones
# 103  289907418.0  115000000.0                                  Monsters, Inc.
# 104  474544677.0  115000000.0       Star Wars: Episode I - The Phantom Menace
# 101  380262555.0  113000000.0    Star Wars: Episode III - Revenge of the Sith
# 105  380838870.0   94000000.0                                    Finding Nemo
# 106  377019252.0   94000000.0   The Lord of the Rings: The Return of the King
# 107  340478898.0   94000000.0           The Lord of the Rings: The Two Towers
# 116  279167575.0   80000000.0                                Meet the Fockers
# 108  407999255.0   78000000.0                                The Hunger Games
# 110  368049635.0   76000000.0                                 Despicable Me 2
# 111  306124059.0   75000000.0                                Independence Day
# 112  336029560.0   74000000.0                                         Minions
# 114  300523113.0   68000000.0                      The Twilight Saga: Eclipse
# 115  356784000.0   63000000.0                                   Jurassic Park
# 118  350123553.0   58800000.0                                 American Sniper
# 117  363024263.0   58000000.0                                        Deadpool
# 119  329691196.0   55000000.0                                    Forrest Gump
# 120  296623634.0   50000000.0                     The Twilight Saga: New Moon
# 109  422783777.0   45000000.0                                   The Lion King
# 121  293501675.0   40000000.0                                 The Sixth Sense
# 122  277313371.0   35000000.0                                    The Hangover
# 123  309125409.0   32500000.0      Star Wars: Episode VI - Return of the Jedi
# 124  290158751.0   18000000.0  Star Wars: Episode V - The Empire Strikes Back
# 125  285761243.0   18000000.0                                      Home Alone
# 126  460935665.0   11000000.0              Star Wars: Episode IV - A New Hope
# 127  434949459.0   10500000.0                      E.T. the Extra-Terrestrial
#
# [128 rows x 3 columns]

# %% [markdown]
# Examine the relationship between imdb_score and gross income.

# %%
score_df = df1[['gross', 'imdb_score']].dropna()
#score_df = score_df[score_df.apply(lambda x: np.abs(x - x.mean()) / x.std() < 3).all(axis=1)]

# %%
score_df.plot.scatter('gross', 'imdb_score',alpha=0.3)

# %%
df1=df1.dropna()
df1['p_factor']=df1['gross']/df1['budget']

# %%
pscore_df = df1[df1.p_factor<100][['p_factor', 'imdb_score']].dropna()

# %%
pscore_df.plot.scatter('p_factor', 'imdb_score',alpha=0.3)

# %% [markdown]
# ### Exercise 2
# - How is gross income related to director Facebook likes?
# - How is the imdb_score related to num_critic_for_reviews?

# %%
#### Your code here
f1='gross'
f2='director_facebook_likes'
df1[[f1, f2]].dropna().plot.scatter(f1, f2)

# %%
f1='imdb_score'
f2='num_critic_for_reviews'
df1[[f1, f2]].dropna().plot.scatter(f1, f2,alpha=0.4)

# %% [markdown]
# # Barplot
#
# Barplot is often used to visualize the amount of each class in a categorical feature. It shows the difference between factors.
#
# Below is a bar graph showing the median imdb score for different countries.  The results are shown in descending values.  What is the story this graph tells?

# %%
plt.figure(figsize=(12,6))
df.groupby('country')['imdb_score'].median().sort_values(ascending=False).plot.bar()

# %% [markdown]
# Here are the top seven countries.

# %%
plt.figure(figsize=(12,6))
df.groupby('country')['imdb_score'].median().sort_values(ascending=False).head(7).plot.bar()

# %% [markdown]
# The next data frame examines the mean budget of movies over the last ten years.  What story does this graph tell?

# %%
df_clean = df1.dropna()
bar_df = df_clean.groupby('title_year')[['budget']].mean().tail(10)
bar_df
# Out:
#                   budget
# title_year
# 2007.0      4.540601e+07
# 2008.0      4.325775e+07
# 2009.0      4.525024e+07
# 2010.0      5.388099e+07
# 2011.0      5.072492e+07
# 2012.0      5.053131e+07
# 2013.0      5.668649e+07
# 2014.0      5.227248e+07
# 2015.0      5.892976e+07
# 2016.0      7.977556e+07

# %%
bar_df.index = bar_df.index.astype(np.int16)
bar_df.plot.bar()

# %% [markdown]
# ### Genre
# - Check how column features vary across different genres. This is tricky since there are many films with multiple genres separated by the `|` symbol. One solution is to duplicate each film with multiple genres into multiple rows, each with one genre.
# - Then look at the imdb distribution over all the genres.

# %%
df_clean = df1[['genres', 'budget', 'gross', 'title_year', 'imdb_score','movie_title']].dropna()
df_genre = pd.DataFrame(columns = ['genre', 'budget', 'gross', 'year', 'imdb_score','movie_title'])

def genreRemap(row):
    global df_genre
    d = {}
    genres = row['genres'].split('|')
    n = len(genres)
    d['genre'] = genres
    d['movie_title'] = [row['movie_title']] * n
    d['budget'] = [row['budget']] * n
    d['gross'] = [row['gross']] * n
    d['year'] = [row['title_year']] * n
    d['imdb_score'] = [row['imdb_score']] * n

    df_genre = df_genre.append(pd.DataFrame(d), ignore_index = True)

df_clean.apply(genreRemap, axis = 1)
df_genre['year'] = df_genre['year'].astype(np.int16)

# %%
df_genre
# Out:
#            budget        genre        gross  imdb_score  \
# 0     237000000.0       Action  760505847.0         7.9
# 1     237000000.0    Adventure  760505847.0         7.9
# 2     237000000.0      Fantasy  760505847.0         7.9
# 3     237000000.0       Sci-Fi  760505847.0         7.9
# 4     300000000.0       Action  309404152.0         7.1
# 5     300000000.0    Adventure  309404152.0         7.1
# 6     300000000.0      Fantasy  309404152.0         7.1
# 7     250000000.0       Action  448130642.0         8.5
# 8     250000000.0     Thriller  448130642.0         8.5
# 9     263700000.0       Action   73058679.0         6.6
# 10    263700000.0    Adventure   73058679.0         6.6
# 11    263700000.0       Sci-Fi   73058679.0         6.6
# 12    258000000.0       Action  336530303.0         6.2
# 13    258000000.0    Adventure  336530303.0         6.2
# 14    258000000.0      Romance  336530303.0         6.2
# 15    260000000.0    Adventure  200807262.0         7.8
# 16    260000000.0    Animation  200807262.0         7.8
# 17    260000000.0       Comedy  200807262.0         7.8
# 18    260000000.0       Family  200807262.0         7.8
# 19    260000000.0      Fantasy  200807262.0         7.8
# 20    260000000.0      Musical  200807262.0         7.8
# 21    260000000.0      Romance  200807262.0         7.8
# 22    250000000.0       Action  458991599.0         7.5
# 23    250000000.0    Adventure  458991599.0         7.5
# 24    250000000.0       Sci-Fi  458991599.0         7.5
# 25    250000000.0       Action  330249062.0         6.9
# 26    250000000.0    Adventure  330249062.0         6.9
# 27    250000000.0       Sci-Fi  330249062.0         6.9
# 28    209000000.0       Action  200069408.0         6.1
# 29    209000000.0    Adventure  200069408.0         6.1
# ...           ...          ...          ...         ...
# 8841      70000.0       Comedy      30084.0         5.6
# 8842      70000.0        Drama      30084.0         5.6
# 8843      25000.0       Comedy   10246600.0         6.6
# 8844      25000.0        Drama   10246600.0         6.6
# 8845      25000.0      Romance   10246600.0         6.6
# 8846      65000.0       Comedy     389804.0         6.3
# 8847      65000.0        Drama     389804.0         6.3
# 8848      65000.0      Romance     389804.0         6.3
# 8849      42000.0        Drama     241816.0         7.5
# 8850      40000.0       Comedy     277233.0         7.6
# 8851      40000.0      Romance     277233.0         7.6
# 8852     230000.0       Comedy    3151130.0         7.8
# 8853   35000000.0       Action   10499968.0         5.7
# 8854   35000000.0        Crime   10499968.0         5.7
# 8855   35000000.0        Drama   10499968.0         5.7
# 8856   35000000.0     Thriller   10499968.0         5.7
# 8857      23000.0       Comedy    1227508.0         7.1
# 8858      23000.0        Drama    1227508.0         7.1
# 8859      10000.0       Comedy     180483.0         6.1
# 8860      10000.0        Crime     180483.0         6.1
# 8861      10000.0       Horror     180483.0         6.1
# 8862       7000.0        Drama     424760.0         7.0
# 8863       7000.0       Sci-Fi     424760.0         7.0
# 8864       7000.0     Thriller     424760.0         7.0
# 8865       7000.0       Action    2040920.0         6.9
# 8866       7000.0        Crime    2040920.0         6.9
# 8867       7000.0        Drama    2040920.0         6.9
# 8868       7000.0      Romance    2040920.0         6.9
# 8869       7000.0     Thriller    2040920.0         6.9
# 8870       1100.0  Documentary      85222.0         6.6
#
#                                     movie_title  year
# 0                                       Avatar   2009
# 1                                       Avatar   2009
# 2                                       Avatar   2009
# 3                                       Avatar   2009
# 4     Pirates of the Caribbean: At World's End   2007
# 5     Pirates of the Caribbean: At World's End   2007
# 6     Pirates of the Caribbean: At World's End   2007
# 7                        The Dark Knight Rises   2012
# 8                        The Dark Knight Rises   2012
# 9                                  John Carter   2012
# 10                                 John Carter   2012
# 11                                 John Carter   2012
# 12                                Spider-Man 3   2007
# 13                                Spider-Man 3   2007
# 14                                Spider-Man 3   2007
# 15                                     Tangled   2010
# 16                                     Tangled   2010
# 17                                     Tangled   2010
# 18                                     Tangled   2010
# 19                                     Tangled   2010
# 20                                     Tangled   2010
# 21                                     Tangled   2010
# 22                     Avengers: Age of Ultron   2015
# 23                     Avengers: Age of Ultron   2015
# 24                     Avengers: Age of Ultron   2015
# 25          Batman v Superman: Dawn of Justice   2016
# 26          Batman v Superman: Dawn of Justice   2016
# 27          Batman v Superman: Dawn of Justice   2016
# 28                            Superman Returns   2006
# 29                            Superman Returns   2006
# ...                                         ...   ...
# 8841                           Happy Christmas   2014
# 8842                           Happy Christmas   2014
# 8843                     The Brothers McMullen   1995
# 8844                     The Brothers McMullen   1995
# 8845                     The Brothers McMullen   1995
# 8846                            Tiny Furniture   2010
# 8847                            Tiny Furniture   2010
# 8848                            Tiny Furniture   2010
# 8849                         George Washington   2000
# 8850               Smiling Fish & Goat on Fire   1999
# 8851               Smiling Fish & Goat on Fire   1999
# 8852                                    Clerks   1994
# 8853                                  Sabotage   2014
# 8854                                  Sabotage   2014
# 8855                                  Sabotage   2014
# 8856                                  Sabotage   2014
# 8857                                   Slacker   1991
# 8858                                   Slacker   1991
# 8859                            Pink Flamingos   1972
# 8860                            Pink Flamingos   1972
# 8861                            Pink Flamingos   1972
# 8862                                    Primer   2004
# 8863                                    Primer   2004
# 8864                                    Primer   2004
# 8865                               El Mariachi   1992
# 8866                               El Mariachi   1992
# 8867                               El Mariachi   1992
# 8868                               El Mariachi   1992
# 8869                               El Mariachi   1992
# 8870                         My Date with Drew   2004
#
# [8871 rows x 6 columns]

# %% [markdown]
# Next we can group by the genre column.  Then look at the imdb score across different genres.

# %%
df_genre.groupby('genre')[['imdb_score']].mean().sort_values('imdb_score').plot.bar()
plt.ylabel('Averge Imdb Score')

# %% [markdown]
# ### Exercise 3
# - Which genre has the highest mean budget?
# - When the number of bars becomes larger try to a horizontal plot.

# %%
#### Your code here
df_genre.groupby('genre')['budget'].mean().sort_values(ascending=False).index[0]
# Out:
# 'Animation'

# %%
df_genre.groupby('genre').agg({'budget':['mean','std']})[('budget','mean')].sort_values(ascending=False).index[0]
# Out:
# 'Animation'

# %% [markdown]
# # Boxplot
# - A boxplot is another way to visualize the distribution of a numeric feature. Let Q1, Q2 and Q3 represent the 25%, 50% and 75% quantile, respectively.
# - A Boxplot is made of five quantiles: Q1−1.5(Q3−Q1), Q1, Q2, Q3, and Q3+1. 5(Q3−Q1). It can be made by function boxplot.

# %%
df_score = df[['color', 'imdb_score']].dropna()
df_score.boxplot(by='color', column='imdb_score')
plt.ylabel('Imdb Score')

# %% [markdown]
# ### Exercise 4
# What is the duration distribution for different kinds of posters?

# %%
#### Your code here
df_dur = df[['color', 'duration']]
df_dur.boxplot(by='color', column='duration')
plt.ylabel('Length of Duration')

# %% [markdown]
# # Seaborn

# %%
import seaborn as sns

# %% [markdown]
# Seaborn provides functionality to infer a distribution from the sample data.  This is known as kernel density estimation.

# %%
sns.kdeplot(df['imdb_score'], shade=True, label='Estimated PDF of imdb score')
# Out:
# //anaconda/lib/python3.6/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %% [markdown]
# It is possible to combine histogram and the distribution estimate plot:

# %%
sns.distplot(df['imdb_score'])
# Out:
# //anaconda/lib/python3.6/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %% [markdown]
# The joinplot() function combines histogram and scatter plot.

# %%
sns.jointplot(df['num_critic_for_reviews'], df['imdb_score'])

# %% [markdown]
# The "pearsonr=0.31" indicates the pearson correlation of these two variables. The p value is pretty small, indicating that there is a significant linear relation between the two variables.

# %% [markdown]
# Visualize the distribution of multiple features by using boxplot:

# %%
sns.boxplot(x='color', y='imdb_score', data=df)

# %% [markdown]
# ### Advanced plots
# Seaborn also provides another famous sample dataset named "tips":

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# This is a famous dataset record the information of people of different sex, being a smoker or not, visiting at different day or for different meal, the size of parties they joined, and the tip and the total bill they pay.
#
# To visualize the relation between total_bill and tip, use scatter plot. Seaborn performs linear fitting as well.

# %%
sns.lmplot("total_bill", "tip", tips)

# %%
sns.jointplot("total_bill", "tip", tips,kind='reg')
# Out:
# //anaconda/lib/python3.6/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %% [markdown]
# Visualize "Male" and "Female" data points, represented by hue.

# %%
sns.lmplot("total_bill", "tip", tips, hue="sex", palette="Set2")

# %% [markdown]
# Pass a dictionary to the palette argument, specifying the color of each level in the hue variable.

# %%
sns.lmplot("total_bill", "tip", tips, hue="sex", palette={"Male": "b", "Female": "r"})

# %% [markdown]
# Here:
# - hue indicates the column categorical feature used to split the data
# - palette specifies the color used in the graphic

# %% [markdown]
# To compare the same kind of plot for different features, faceting is useful.

# %%
SexGrid = sns.FacetGrid(tips, col='sex', hue="sex", palette="Set1", size=4)
SexGrid.map(sns.distplot, "tip")
# Out:
# //anaconda/lib/python3.6/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %% [markdown]
# Above the column and hue are mapped to the same categorical feature.  Below column and hue are mapped to different categorical features.

# %%
SexGrid = sns.FacetGrid(tips, col='smoker', hue="sex", palette="Set1", size=4)
SexGrid.map(sns.distplot, "tip")
# Out:
# //anaconda/lib/python3.6/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %% [markdown]
# FacetGrid() offers three ways to split data: hue, column and row.  The .map() method specifies the plot type and the x,y axes.

# %% [markdown]
# Facet can be used to differentiate multiple factors as well.

# %%
tipsGrid = sns.FacetGrid(tips, row='sex', col='smoker',\
                               hue='time', palette="Set2")
tipsGrid.map(sns.regplot, 'total_bill', 'tip')
tipsGrid.add_legend()

# %% [markdown]
# ### Exercise 5
# Use FacetGrid to compare the distribution of imdb score for different poster color.

# %%
#### Your code here
g = sns.FacetGrid(df1, col='color', hue='color', palette='Set1', size=4)
g.map(sns.distplot, 'imdb_score')
# Out:
# //anaconda/lib/python3.6/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %% [markdown]
# FacetGrid helps explore specific variables and the relationships between pairs of variables, while segmenting the data set across multiple categorical features.
#
# PairGrid explores the relationships between whole sets of numerical features.

# %%
tipGrid = sns.PairGrid(tips)
tipGrid.map(plt.scatter)

# %% [markdown]
# Switching to the iris data:

# %%
iris = sns.load_dataset("iris")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
g = sns.PairGrid(iris)
g.map_diag(plt.hist)
g.map_offdiag(plt.scatter)

# %% [markdown]
# Some examples with different type of plot and colors.

# %%
g = sns.PairGrid(iris, hue = 'species', palette='Set2',\
           hue_kws={'cmap':['Greens','Oranges','Blues']})

g.map_diag(plt.hist)
g.map_upper(plt.scatter)
g.map_lower(sns.kdeplot)
g.add_legend()

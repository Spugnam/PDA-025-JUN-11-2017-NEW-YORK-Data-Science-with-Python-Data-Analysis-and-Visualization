# %% [markdown]
# # Matplotlib & Seaborn

# %% [markdown]
# ## Overview
#
# matplotlib is a python 2D plotting library built on the top of the basic Python language and Numpy.
# More about matplotlib can be found in its [documentation](http://matplotlib.org/contents.html).
#
# Seaborn is a Python visualization library based on matplotlib. It provides a high-level interface for drawing attractive statistical graphics. Here is the [documentation](http://seaborn.pydata.org/index.html).

# %% [markdown]
# To display the graph inside IPython notebook, run the following code.

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# Begin by making a simple plot matplotlib.  Create a set of x-coordinates and y-coordinates.  Then plot them, as follows:

# %%
x=[7,8,9,11]
y=[9,4,6,7]
plt.plot(x,y)

# %%
#for information on plot function
# ?plt.plot

# %% [markdown]
# The style of the plot can be set in several ways.  The line style, color, marker size, line width and opacity may be set using additional parameters.  Multiple series can also be plotted in the the same graph.

# %%
plt.plot(x,y,'.-',color='green',markersize=20,alpha=0.4)
y2=[1,8,3,5]
plt.plot(x,y2,'.--',color='red',markersize=10,alpha=0.7)

# %% [markdown]
# The plot can also be given a legend, title and labels on the x and y axis.  The range and tick marks can also be set for the axes.  Text can be added to the plot as well.  These are all sown in the following graph.

# %%
plt.plot(x,y,'.-',color='green',markersize=20,
         linewidth=4,alpha=0.4,label='data1')
plt.plot(x,y2,'.--',color='red',markersize=10,alpha=0.7,
         linewidth=0.3,label='data2')
plt.legend(loc=1)
plt.title('Example Plot $x^2\lambda$')
plt.xlabel('horizontal axis')
plt.ylabel('vertical axis')
plt.xlim(6,12)
plt.ylim(0,10)
plt.xticks([6,9,12])
plt.yticks([0,4,8])
plt.text(10,2,'random text',color='blue',size=14)

# %% [markdown]
# One-dimensional numpy arrays may also be used as data series.  Below a sin function is plotted.
#
# The resulting plot may be saved as an image.

# %%
X=np.linspace(0,4*3.14,101)
Y=np.sin(X)
plt.plot(X,Y,'.')

### save file
plt.savefig('myplot.png')

# %%
#the resulting image
from IPython.display import Image
Image('myplot.png')

# %% [markdown]
# Bar plots are another type of graph which can be redered.

# %%
t=np.linspace(0,5*3.14,51)
s=(9*np.sin(t)/((t+1)))+0.5*t+3*(np.random.randn(51)/(2+t/2.5))**2
plt.bar(t,s,edgecolor='black', width=0.2)
# Out:
# <Container object of 51 artists>

# %%
#horizontal bar plot
plt.barh(t[:10],s[:10], height=0.3)
# Out:
# <Container object of 10 artists>

# %% [markdown]
# Scatter plots are also useful.
#
# Below are four 2-D standard normal distributions centered at (2,2),(2,-2),(-2,2),(-2,-2)

# %%
N=400
D=2

X=np.random.randn(N,D)

X[:200,:] = X[:200,:] - 2*np.ones((200,D))
X[200:,:] = X[200:,:] + 2*np.ones((200,D))
X[100:300,0]=-X[100:300,0]

#note how colors are assigned with a list
T=np.array([0]*100 + [1]*100 + [2]*100 + [3]*100)
 
plt.scatter(X[:,0],X[:,1],c=T,s=100, alpha=0.5)

# %% [markdown]
# **Exercise 0**
#
# The code below creates a pandas data frame from the file 'gold_hist.txt'.  It contains historical gold prices (end of year) from 1792 to 2015.
#
# - Plot the data with time on the horizontal axis and gold price on the vertical.  Provide a title and labels for the horizontal and vertical axes.
# - Plot the the data again using a log vertical scale.
# Use `plt.yscale('log')`
#
# - The US dollar was removed from a gold standard in 1973.  Plot the data again, on a linear scale (normal scale), from 1972 and after.  Label the point representing peak price.

# %%
f = open('gold_hist.txt', 'r')
lines = f.readlines()
f.close()
lines=list(map(lambda x: x.strip() ,lines))
prices=[[int(lines[2*i]),float(lines[2*i+1][1:].replace(',',''))]\
        for i in range(int(len(lines)/2)) ]
prices.sort()
gold=pd.DataFrame(prices,columns=['year','price'])
gold.head(2)
# Out:
#    year  price
# 0  1792  19.39
# 1  1793  19.39

# %%
#your code here

P=gold['price']
T=gold['year']
plt.plot(T,P,'.')
plt.xlabel('Year')
plt.ylabel('Price in Dollars')
plt.title('Historical Gold Price')

# %%
plt.plot(T,P,'.')
plt.xlabel('Year')
plt.ylabel('log(Price in Dollars)')
plt.title('Historical Gold Price')
plt.yscale('log')

# %%
peak_price=gold['price'].max()
peak_year=gold.loc[gold.price==peak_price,'year'].tolist()[0]

gold72=gold[gold['year']>=1972]
P=gold72['price']
T=gold72['year']
plt.plot(T,P,'.')
plt.xlabel('Year')
plt.ylabel('Price in Dollars')
plt.title('Historical Gold Price')
plt.text(peak_year,peak_price,'$%i '%(peak_price),color='black',size=10,
          fontweight='bold',verticalalignment='center',horizontalalignment='right')

# %%
peak_price=gold['price'].max()
peak_price
# Out:
# 1664.0

# %%
peak_year=gold.loc[gold.price==peak_price,'year'].tolist()[0]
peak_year
# Out:
# 2012

# %% [markdown]
# # Case Study

# %% [markdown]
# For this case study use the IMDB dataset.  It was scraped and uploaded to Kaggle by Sun Chuan (graduate of Bootcamp 6). Check it out [here](https://www.kaggle.com/deepmatrix/imdb-5000-movie-dataset).
#
# Load the data first.

# %%
df = pd.read_csv('movie_metadata.csv')

# %%
df.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# 1                 40000.0  309404152.0         Action|Adventure|Fantasy
# 2                 11000.0  200074175.0        Action|Adventure|Thriller
# 3                 27000.0  448130642.0                  Action|Thriller
# 4                   131.0          NaN                      Documentary
#
#           ...          num_user_for_reviews language  country  content_rating  \
# 0         ...                        3054.0  English      USA           PG-13
# 1         ...                        1238.0  English      USA           PG-13
# 2         ...                         994.0  English       UK           PG-13
# 3         ...                        2701.0  English      USA           PG-13
# 4         ...                           NaN      NaN      NaN             NaN
#
#         budget  title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 0  237000000.0      2009.0                  936.0        7.9          1.78
# 1  300000000.0      2007.0                 5000.0        7.1          2.35
# 2  245000000.0      2015.0                  393.0        6.8          2.35
# 3  250000000.0      2012.0                23000.0        8.5          2.35
# 4          NaN         NaN                   12.0        7.1           NaN
#
#   movie_facebook_likes
# 0                33000
# 1                    0
# 2                85000
# 3               164000
# 4                    0
#
# [5 rows x 28 columns]

# %% [markdown]
# To display the full data frame set the maximum number of columns shown, as follows:

# %%
pd.set_option('display.max_columns', df.shape[1])

# %%
df.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# 1                 40000.0  309404152.0         Action|Adventure|Fantasy
# 2                 11000.0  200074175.0        Action|Adventure|Thriller
# 3                 27000.0  448130642.0                  Action|Thriller
# 4                   131.0          NaN                      Documentary
#
#       actor_1_name                                        movie_title  \
# 0      CCH Pounder                                            Avatar
# 1      Johnny Depp          Pirates of the Caribbean: At World's End
# 2  Christoph Waltz                                           Spectre
# 3        Tom Hardy                             The Dark Knight Rises
# 4      Doug Walker  Star Wars: Episode VII - The Force Awakens    ...
#
#    num_voted_users  cast_total_facebook_likes          actor_3_name  \
# 0           886204                       4834             Wes Studi
# 1           471220                      48350        Jack Davenport
# 2           275868                      11700      Stephanie Sigman
# 3          1144337                     106759  Joseph Gordon-Levitt
# 4                8                        143                   NaN
#
#    facenumber_in_poster                                      plot_keywords  \
# 0                   0.0             avatar|future|marine|native|paraplegic
# 1                   0.0  goddess|marriage ceremony|marriage proposal|pi...
# 2                   1.0                bomb|espionage|sequel|spy|terrorist
# 3                   0.0  deception|imprisonment|lawlessness|police offi...
# 4                   0.0                                                NaN
#
#                                      movie_imdb_link  num_user_for_reviews  \
# 0  http://www.imdb.com/title/tt0499549/?ref_=fn_t...                3054.0
# 1  http://www.imdb.com/title/tt0449088/?ref_=fn_t...                1238.0
# 2  http://www.imdb.com/title/tt2379713/?ref_=fn_t...                 994.0
# 3  http://www.imdb.com/title/tt1345836/?ref_=fn_t...                2701.0
# 4  http://www.imdb.com/title/tt5289954/?ref_=fn_t...                   NaN
#
#   language country content_rating       budget  title_year  \
# 0  English     USA          PG-13  237000000.0      2009.0
# 1  English     USA          PG-13  300000000.0      2007.0
# 2  English      UK          PG-13  245000000.0      2015.0
# 3  English     USA          PG-13  250000000.0      2012.0
# 4      NaN     NaN            NaN          NaN         NaN
#
#    actor_2_facebook_likes  imdb_score  aspect_ratio  movie_facebook_likes
# 0                   936.0         7.9          1.78                 33000
# 1                  5000.0         7.1          2.35                     0
# 2                   393.0         6.8          2.35                 85000
# 3                 23000.0         8.5          2.35                164000
# 4                    12.0         7.1           NaN                     0

# %% [markdown]
# Describe will exclude the missing value by default.

# %%
#df.describe()
df.dropna().describe()
# Out:
#        num_critic_for_reviews     duration  director_facebook_likes  \
# count             3756.000000  3756.000000              3756.000000
# mean               167.378328   110.257987               807.336528
# std                123.452040    22.646717              3068.171683
# min                  2.000000    37.000000                 0.000000
# 25%                 77.000000    96.000000                11.000000
# 50%                138.500000   106.000000                64.000000
# 75%                224.000000   120.000000               235.000000
# max                813.000000   330.000000             23000.000000
#
#        actor_3_facebook_likes  actor_1_facebook_likes         gross  \
# count             3756.000000             3756.000000  3.756000e+03
# mean               771.279553             7751.338658  5.261282e+07
# std               1894.249869            15519.339621  7.031787e+07
# min                  0.000000                0.000000  1.620000e+02
# 25%                194.000000              745.000000  8.270233e+06
# 50%                436.000000             1000.000000  3.009311e+07
# 75%                691.000000            13000.000000  6.688194e+07
# max              23000.000000           640000.000000  7.605058e+08
#
#        num_voted_users  cast_total_facebook_likes  facenumber_in_poster  \
# count     3.756000e+03                3756.000000           3756.000000
# mean      1.058267e+05               11527.101970              1.377263
# std       1.520354e+05               19122.176905              2.041541
# min       9.100000e+01                   0.000000              0.000000
# 25%       1.966700e+04                1919.750000              0.000000
# 50%       5.397350e+04                4059.500000              1.000000
# 75%       1.286020e+05               16240.000000              2.000000
# max       1.689764e+06              656730.000000             43.000000
#
#        num_user_for_reviews        budget   title_year  \
# count           3756.000000  3.756000e+03  3756.000000
# mean             336.843184  4.623685e+07  2002.976571
# std              411.227368  2.260103e+08     9.888108
# min                4.000000  2.180000e+02  1927.000000
# 25%              110.000000  1.000000e+07  1999.000000
# 50%              210.000000  2.500000e+07  2004.000000
# 75%              398.250000  5.000000e+07  2010.000000
# max             5060.000000  1.221550e+10  2016.000000
#
#        actor_2_facebook_likes   imdb_score  aspect_ratio  movie_facebook_likes
# count             3756.000000  3756.000000   3756.000000           3756.000000
# mean              2021.775825     6.465282      2.111014           9353.829340
# std               4544.908236     1.056247      0.353068          21462.889123
# min                  0.000000     1.600000      1.180000              0.000000
# 25%                384.750000     5.900000      1.850000              0.000000
# 50%                685.500000     6.600000      2.350000            227.000000
# 75%                976.000000     7.200000      2.350000          11000.000000
# max             137000.000000     9.300000     16.000000         349000.000000

# %% [markdown]
# `value_counts()` will freturn a frequency count for every value in a column.

# %%
df['language'].value_counts()
# Out:
# English       4704
# French          73
# Spanish         40
# Hindi           28
# Mandarin        26
# German          19
# Japanese        18
# Russian         11
# Italian         11
# Cantonese       11
# Korean           8
# Portuguese       8
# Danish           5
# Arabic           5
# Swedish          5
# Hebrew           5
# Polish           4
# Persian          4
# Norwegian        4
# Dutch            4
# Thai             3
# Chinese          3
# Aboriginal       2
# Zulu             2
# Romanian         2
# Icelandic        2
# Dari             2
# Indonesian       2
# None             2
# Czech            1
# Urdu             1
# Tamil            1
# Bosnian          1
# Aramaic          1
# Slovenian        1
# Kannada          1
# Filipino         1
# Greek            1
# Maya             1
# Dzongkha         1
# Panjabi          1
# Hungarian        1
# Kazakh           1
# Vietnamese       1
# Swahili          1
# Mongolian        1
# Telugu           1
# Name: language, dtype: int64

# %%
df['director_name'].value_counts()
# Out:
# Steven Spielberg        26
# Woody Allen             22
# Clint Eastwood          20
# Martin Scorsese         20
# Ridley Scott            17
# Steven Soderbergh       16
# Tim Burton              16
# Spike Lee               16
# Renny Harlin            15
# Oliver Stone            14
# Barry Levinson          13
# Joel Schumacher         13
# Robert Rodriguez        13
# Ron Howard              13
# Sam Raimi               13
# Michael Bay             13
# Robert Zemeckis         13
# John Carpenter          13
# Tony Scott              12
# Peter Jackson           12
# Brian De Palma          12
# Shawn Levy              12
# Wes Craven              12
# Kevin Smith             12
# Richard Donner          12
# Rob Reiner              11
# Stephen Frears          11
# Rob Cohen               11
# Francis Ford Coppola    11
# Richard Linklater       11
#                         ..
# J Blakeson               1
# Jim Field Smith          1
# E.L. Katz                1
# James Schamus            1
# Sharon Greytak           1
# Siddharth Anand          1
# John Maclean             1
# Chia-Liang Liu           1
# Sam Fell                 1
# Chad Hartigan            1
# Duke Johnson             1
# Carl Rinsch              1
# Howard Hughes            1
# Gideon Raff              1
# Barry W. Blaustein       1
# Dan Harris               1
# John Murlowski           1
# Steve Taylor             1
# Mike Bruce               1
# Cristian Mungiu          1
# Steve Trenbirth          1
# Stephen Chbosky          1
# Jim Goddard              1
# Angelo Pizzo             1
# Sam Firstenberg          1
# Ingmar Bergman           1
# Eugenio Derbez           1
# Rob Schmidt              1
# Mike van Diem            1
# Debra Granik             1
# Name: director_name, dtype: int64

# %% [markdown]
# # Histogram

# %%
plt.hist(df['imdb_score'],edgecolor='k')
# Out:
# (array([   16.,    38.,   102.,   222.,   579.,  1158.,  1515.,  1085.,
#           307.,    21.]),
#  array([ 1.6 ,  2.39,  3.18,  3.97,  4.76,  5.55,  6.34,  7.13,  7.92,
#          8.71,  9.5 ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# Explore some of the available parameters by placing the cursor inside the function parentheses and pressing **shift+tab**
#
# It is possible to set the color and the number of bins. For color, type `"blue"` or `"b"` for short. Color accepts hex color code, pick a color from this [website](http://www.color-hex.com/) and paste the hexadecimal code.

# %%
import seaborn as sns
sns.distplot(df['imdb_score'])
# Out:
# //anaconda/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
plt.hist(df['imdb_score'], bins=20, color="#666699", orientation="horizontal")
# Out:
# (array([   5.,   11.,   12.,   26.,   51.,   51.,   95.,  127.,  217.,
#          362.,  497.,  661.,  795.,  720.,  666.,  419.,  226.,   81.,
#           18.,    3.]),
#  array([ 1.6  ,  1.995,  2.39 ,  2.785,  3.18 ,  3.575,  3.97 ,  4.365,
#          4.76 ,  5.155,  5.55 ,  5.945,  6.34 ,  6.735,  7.13 ,  7.525,
#          7.92 ,  8.315,  8.71 ,  9.105,  9.5  ]),
#  <a list of 20 Patch objects>)

# %% [markdown]
# ### Exercise 1
#
# - Create a histogram of the budget column. Does Python raise an error? Fix it by following this [Stack Overflow Link](http://stackoverflow.com/q/20656663)
#
# - How does the graph look? Is there anyway to improve this? What does the x-axis stand for?
# - All the code in the same cell will contribute to the same plot.
# - Type `plt.` and press tab to get a hint.

# %%
#### Your code here
plt.figure(figsize=(12,6)) # This line changes the size of the plot. The width and height are in inches.
plt.hist(df.dropna()[df.budget<200000000]['budget'],bins=20,edgecolor='k')
# Out:
# //anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   app.launch_new_instance()
# (array([ 863.,  688.,  530.,  390.,  256.,  215.,  173.,  120.,   93.,
#           60.,   70.,   34.,   35.,   32.,   28.,   46.,   14.,   21.,
#           13.,    7.]),
#  array([  2.18000000e+02,   9.75020710e+06,   1.95001962e+07,
#           2.92501853e+07,   3.90001744e+07,   4.87501635e+07,
#           5.85001526e+07,   6.82501417e+07,   7.80001308e+07,
#           8.77501199e+07,   9.75001090e+07,   1.07250098e+08,
#           1.17000087e+08,   1.26750076e+08,   1.36500065e+08,
#           1.46250054e+08,   1.56000044e+08,   1.65750033e+08,
#           1.75500022e+08,   1.85250011e+08,   1.95000000e+08]),
#  <a list of 20 Patch objects>)

# %%
plt.figure(figsize=(12,6)) # This line changes the size of the plot. The width and height are in inches.
plt.hist(df.dropna()[df.country=='USA']['budget'],bins=20,edgecolor='k')
# Out:
# //anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   from ipykernel import kernelapp as app
# (array([ 990.,  696.,  395.,  285.,  172.,  123.,   74.,   52.,   42.,
#           59.,   16.,   28.,   11.,   22.,   10.,    2.,    5.,    4.,
#            0.,    1.]),
#  array([  2.18000000e+02,   1.50002071e+07,   3.00001962e+07,
#           4.50001853e+07,   6.00001744e+07,   7.50001635e+07,
#           9.00001526e+07,   1.05000142e+08,   1.20000131e+08,
#           1.35000120e+08,   1.50000109e+08,   1.65000098e+08,
#           1.80000087e+08,   1.95000076e+08,   2.10000065e+08,
#           2.25000054e+08,   2.40000044e+08,   2.55000033e+08,
#           2.70000022e+08,   2.85000011e+08,   3.00000000e+08]),
#  <a list of 20 Patch objects>)

# %%
maxb=df.dropna()['budget'].max()
df.sort_values('budget',ascending=False).dropna()[['movie_title','budget','country']]
#the budget values are not all in the same currency
# Out:
#                                        movie_title        budget      country
# 2988                                     The Host   1.221550e+10  South Korea
# 3859                               Lady Vengeance   4.200000e+09  South Korea
# 3005                                     Fateless   2.500000e+09      Hungary
# 2323                            Princess Mononoke   2.400000e+09        Japan
# 2334                                     Steamboy   2.127520e+09        Japan
# 3423                                        Akira   1.100000e+09        Japan
# 4542                                Godzilla 2000   1.000000e+09        Japan
# 3075                       Kabhi Alvida Naa Kehna   7.000000e+08        India
# 3851                                        Tango   7.000000e+08        Spain
# 1338                                    Red Cliff   5.536320e+08        China
# 3311                     The Legend of Suriyothai   4.000000e+08     Thailand
# 1016      The Messenger: The Story of Joan of Arc   3.900000e+08       France
# 2740                                    Ong-bak 2   3.000000e+08     Thailand
# 1        Pirates of the Caribbean: At World's End   3.000000e+08          USA
# 5                                     John Carter   2.637000e+08          USA
# 7                                         Tangled   2.600000e+08          USA
# 6                                    Spider-Man 3   2.580000e+08          USA
# 3461                                 Spider-Man 3   2.580000e+08          USA
# 10             Batman v Superman: Dawn of Justice   2.500000e+08          USA
# 9          Harry Potter and the Half-Blood Prince   2.500000e+08           UK
# 8                         Avengers: Age of Ultron   2.500000e+08          USA
# 18    Pirates of the Caribbean: On Stranger Tides   2.500000e+08          USA
# 20      The Hobbit: The Battle of the Five Armies   2.500000e+08  New Zealand
# 3                           The Dark Knight Rises   2.500000e+08          USA
# 27                     Captain America: Civil War   2.500000e+08          USA
# 2                                         Spectre   2.450000e+08           UK
# 0                                          Avatar   2.370000e+08          USA
# 21                         The Amazing Spider-Man   2.300000e+08          USA
# 15                                   Man of Steel   2.250000e+08          USA
# 13     Pirates of the Caribbean: Dead Man's Chest   2.250000e+08          USA
# ...                                            ...           ...          ...
# 4922                                      Weekend   1.200000e+05           UK
# 4956                                  The Gallows   1.000000e+05          USA
# 4959                            Hollywood Shuffle   1.000000e+05          USA
# 4926                                Another Earth   1.000000e+05          USA
# 4955                            Facing the Giants   1.000000e+05          USA
# 4936                 The Texas Chain Saw Massacre   8.353200e+04          USA
# 3278                 The Texas Chain Saw Massacre   8.353200e+04          USA
# 4979                              Happy Christmas   7.000000e+04          USA
# 4977                                Super Size Me   6.500000e+04          USA
# 4987                               Tiny Furniture   6.500000e+04          USA
# 4978                                       The FP   6.000000e+04          USA
# 4975                                     20 Dates   6.000000e+04          USA
# 4973                                           Pi   6.000000e+04          USA
# 4707                      The Blair Witch Project   6.000000e+04          USA
# 4735                                        Osama   4.600000e+04  Afghanistan
# 4997                            George Washington   4.200000e+04          USA
# 4998                  Smiling Fish & Goat on Fire   4.000000e+04          USA
# 4962                 The Lost Skeleton of Cadavra   4.000000e+04          USA
# 5011                        In the Company of Men   2.500000e+04       Canada
# 4984                        The Brothers McMullen   2.500000e+04          USA
# 5015                                      Slacker   2.300000e+04          USA
# 4793                          Paranormal Activity   1.500000e+04          USA
# 4311                                       London   1.400000e+04           UK
# 5027                                   The Circle   1.000000e+04         Iran
# 5025                               Pink Flamingos   1.000000e+04          USA
# 5033                                       Primer   7.000000e+03          USA
# 5035                                  El Mariachi   7.000000e+03          USA
# 5026                                        Clean   4.500000e+03       France
# 5042                            My Date with Drew   1.100000e+03          USA
# 4799                                    Tarnation   2.180000e+02          USA
#
# [3756 rows x 3 columns]

# %% [markdown]
# - Pandas dataframe also provides plotting function. It is calling the matplotlib library behind the scenes.
# - Check all the available plots from the documenation [here](http://pandas.pydata.org/pandas-docs/version/0.19.2/visualization.html#visualization)

# %%
np.log(df['budget']).plot.hist(bins=25)
plt.xlabel('log of budget')
plt.ylabel('count')
plt.title('Histogram of budget', fontsize=20)

# %% [markdown]
# # Scatterplot
# Scatterplots are useful for bivariate analysis. We can check the relationship between two columns.
# Suppose we want to figure out whether there is a relationship between the gross income and the budget.

# %%
plt.scatter(df['budget'], df['gross'])
plt.xlabel('Budget')
plt.ylabel('Gross Income')

# %%
#another way
plt.plot(df['budget'], df['gross'],'.')
plt.xlabel('Budget')
plt.ylabel('Gross Income')

# %% [markdown]
# Here is a way to plot it using the plotting function from pandas.

# %%
df.plot(x='budget', y='gross',kind='scatter')
plt.xlabel('Budget')
plt.ylabel('Gross Income')

# %%
#another way
df.plot.scatter(x='budget', y='gross')
plt.xlabel('Budget')
plt.ylabel('Gross Income')

# %% [markdown]
# There are some outliers which make the graph less useful. Remove them from the dataframe using the apply function.

# %%
scatter_df = df[['gross', 'budget']]
scatter_df = scatter_df[scatter_df.apply(lambda x: np.abs(x - x.mean()) / x.std() < 3).all(axis=1)]

# %%
plt.scatter(scatter_df['budget'], scatter_df['gross'],alpha=0.1)

# %% [markdown]
# Now take a look at those outliers. In the previous example the ouliers were removed. Use the **~** symbol to invert the boolean mask.

# %%
~pd.DataFrame([[True]])
# Out:
#        0
# 0  False

# %%
~pd.DataFrame([[False]])
# Out:
#       0
# 0  True

# %% [markdown]
# Merge the outlier dataframe with the original other features.  Sort by budget in descending order.

# %%
outliers = df[['gross', 'budget']].dropna()
outliers = outliers[~outliers.apply(lambda x: np.abs(x - x.mean()) / x.std() < 3).all(axis=1)]
outliers.merge(df)[['gross', 'budget', 'movie_title']].sort_values(by='budget', ascending=False)
# Out:
#            gross        budget  \
# 98     2201412.0  1.221550e+10
# 103     211667.0  4.200000e+09
# 99      195888.0  2.500000e+09
# 95     2298191.0  2.400000e+09
# 96      410388.0  2.127520e+09
# 102     439162.0  1.100000e+09
# 104   10037390.0  1.000000e+09
# 1    309404152.0  3.000000e+08
# 6    336530303.0  2.580000e+08
# 5    336530303.0  2.580000e+08
# 4    336530303.0  2.580000e+08
# 3    336530303.0  2.580000e+08
# 18   407197282.0  2.500000e+08
# 9    330249062.0  2.500000e+08
# 7    458991599.0  2.500000e+08
# 2    448130642.0  2.500000e+08
# 8    301956980.0  2.500000e+08
# 0    760505847.0  2.370000e+08
# 16   262030663.0  2.300000e+08
# 11   291021565.0  2.250000e+08
# 10   423032628.0  2.250000e+08
# 12   623279547.0  2.200000e+08
# 13   623279547.0  2.200000e+08
# 14   623279547.0  2.200000e+08
# 15   623279547.0  2.200000e+08
# 17   658672302.0  2.000000e+08
# 29   334185206.0  2.000000e+08
# 31   402076689.0  2.000000e+08
# 30   268488329.0  2.000000e+08
# 32   414984497.0  2.000000e+08
# ..           ...           ...
# 68   474544677.0  1.150000e+08
# 65   380262555.0  1.130000e+08
# 69   274084951.0  1.000000e+08
# 71   261970615.0  1.000000e+08
# 72   380838870.0  9.400000e+07
# 73   377019252.0  9.400000e+07
# 74   340478898.0  9.400000e+07
# 70   313837577.0  9.300000e+07
# 75   261437578.0  9.200000e+07
# 85   279167575.0  8.000000e+07
# 76   407999255.0  7.800000e+07
# 79   368049635.0  7.600000e+07
# 78   323505540.0  7.500000e+07
# 80   306124059.0  7.500000e+07
# 81   336029560.0  7.400000e+07
# 83   300523113.0  6.800000e+07
# 84   356784000.0  6.300000e+07
# 90   267652016.0  6.000000e+07
# 87   350123553.0  5.880000e+07
# 86   363024263.0  5.800000e+07
# 88   329691196.0  5.500000e+07
# 89   296623634.0  5.000000e+07
# 77   422783777.0  4.500000e+07
# 91   293501675.0  4.000000e+07
# 92   277313371.0  3.500000e+07
# 93   309125409.0  3.250000e+07
# 97   285761243.0  1.800000e+07
# 94   290158751.0  1.800000e+07
# 100  460935665.0  1.100000e+07
# 101  434949459.0  1.050000e+07
#
#                                            movie_title
# 98                                           The Host
# 103                                    Lady Vengeance
# 99                                           Fateless
# 95                                  Princess Mononoke
# 96                                           Steamboy
# 102                                             Akira
# 104                                     Godzilla 2000
# 1            Pirates of the Caribbean: At World's End
# 6                                        Spider-Man 3
# 5                                        Spider-Man 3
# 4                                        Spider-Man 3
# 3                                        Spider-Man 3
# 18                         Captain America: Civil War
# 9                  Batman v Superman: Dawn of Justice
# 7                             Avengers: Age of Ultron
# 2                               The Dark Knight Rises
# 8              Harry Potter and the Half-Blood Prince
# 0                                              Avatar
# 16                             The Amazing Spider-Man
# 11                                       Man of Steel
# 10         Pirates of the Caribbean: Dead Man's Chest
# 12                                       The Avengers
# 13                                       The Avengers
# 14                                       The Avengers
# 15                                       The Avengers
# 17                                            Titanic
# 29                                Alice in Wonderland
# 31                Transformers: Revenge of the Fallen
# 30                                Monsters University
# 32                                        Toy Story 3
# ..                                                 ...
# 68          Star Wars: Episode I - The Phantom Menace
# 65       Star Wars: Episode III - Revenge of the Sith
# 69                                            Gravity
# 71            Harry Potter and the Chamber of Secrets
# 72                                       Finding Nemo
# 73      The Lord of the Rings: The Return of the King
# 74              The Lord of the Rings: The Two Towers
# 70   The Lord of the Rings: The Fellowship of the R...
# 75                                    The Incredibles
# 85                                   Meet the Fockers
# 76                                   The Hunger Games
# 79                                    Despicable Me 2
# 78                            The Secret Life of Pets
# 80                                   Independence Day
# 81                                            Minions
# 83                         The Twilight Saga: Eclipse
# 84                                      Jurassic Park
# 90                                              Shrek
# 87                                    American Sniper
# 86                                           Deadpool
# 88                                       Forrest Gump
# 89                        The Twilight Saga: New Moon
# 77                                      The Lion King
# 91                                    The Sixth Sense
# 92                                       The Hangover
# 93         Star Wars: Episode VI - Return of the Jedi
# 97                                         Home Alone
# 94     Star Wars: Episode V - The Empire Strikes Back
# 100                Star Wars: Episode IV - A New Hope
# 101                        E.T. the Extra-Terrestrial
#
# [105 rows x 3 columns]

# %% [markdown]
# Examine the relationship between imdb_score and gross income.

# %%
score_df = df[['gross', 'imdb_score']].dropna()
#score_df = score_df[score_df.apply(lambda x: np.abs(x - x.mean()) / x.std() < 3).all(axis=1)]

# %%
score_df.plot.scatter('gross', 'imdb_score',alpha=0.3)

# %% [markdown]
# ### Exercise 2
# - How is gross income related to director Facebook likes?
# - How is the imdb_score related to num_critic_for_reviews?

# %%
#### Your code here
f1='gross'
f2='director_facebook_likes'
df[[f1, f2]].dropna().plot.scatter(f1, f2)

# %%
f1='imdb_score'
f2='num_critic_for_reviews'
df[[f1, f2]].dropna().plot.scatter(f1, f2,alpha=0.4)

# %%
df.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
df.title_year.min()
# Out:
# 1916.0

# %% [markdown]
# # Barplot
#
# Barplot is often used to visualize the amount of each class in a categorical feature. It shows the difference between factors.
#
# Below is a bar graph showing the median imdb score for different countries.  The results are shown in descending values.  What is the story this graph tells?

# %%
plt.figure(figsize=(12,6))
df.groupby('country')['imdb_score'].median().sort_values(ascending=False).plot.bar()

# %% [markdown]
# Here are the top seven countries.

# %%
plt.figure(figsize=(12,6))
df.groupby('country')['imdb_score'].median().sort_values(ascending=False).head(7).plot.bar()

# %% [markdown]
# The next data frame examines the mean budget of movies over the last ten years.  What story does this graph tell?

# %%
df_clean = df.dropna()
bar_df = df_clean.groupby('title_year')[['budget']].mean().tail(10)
bar_df
# Out:
#                   budget
# title_year
# 2007.0      4.104793e+07
# 2008.0      4.503644e+07
# 2009.0      4.169074e+07
# 2010.0      4.873580e+07
# 2011.0      4.471375e+07
# 2012.0      4.885083e+07
# 2013.0      5.095347e+07
# 2014.0      5.228738e+07
# 2015.0      5.697574e+07
# 2016.0      7.609153e+07

# %%
bar_df.index = bar_df.index.astype(np.int16)
bar_df.plot.bar()

# %% [markdown]
# ### Genre
# - Check how column features vary across different genres. This is tricky since there are many films with multiple genres separated by the `|` symbol. One solution is to duplicate each film with multiple genres into multiple rows, each with one genre.
# - Then look at the imdb distribution over all the genres.

# %%
df_clean = df[['genres', 'budget', 'gross', 'title_year', 'imdb_score','movie_title']].dropna()
df_genre = pd.DataFrame(columns = ['genre', 'budget', 'gross', 'year', 'imdb_score','movie_title'])

def genreRemap(row):
    global df_genre
    d = {}
    genres = row['genres'].split('|')
    n = len(genres)
    d['genre'] = genres
    d['movie_title'] = [row['movie_title']] * n
    d['budget'] = [row['budget']] * n
    d['gross'] = [row['gross']] * n
    d['year'] = [row['title_year']] * n
    d['imdb_score'] = [row['imdb_score']] * n

    df_genre = df_genre.append(pd.DataFrame(d), ignore_index = True)

df_clean.apply(genreRemap, axis = 1)
df_genre['year'] = df_genre['year'].astype(np.int16)

# %%
df_genre
# Out:
#             budget        genre        gross  imdb_score  \
# 0      237000000.0       Action  760505847.0         7.9
# 1      237000000.0    Adventure  760505847.0         7.9
# 2      237000000.0      Fantasy  760505847.0         7.9
# 3      237000000.0       Sci-Fi  760505847.0         7.9
# 4      300000000.0       Action  309404152.0         7.1
# 5      300000000.0    Adventure  309404152.0         7.1
# 6      300000000.0      Fantasy  309404152.0         7.1
# 7      245000000.0       Action  200074175.0         6.8
# 8      245000000.0    Adventure  200074175.0         6.8
# 9      245000000.0     Thriller  200074175.0         6.8
# 10     250000000.0       Action  448130642.0         8.5
# 11     250000000.0     Thriller  448130642.0         8.5
# 12     263700000.0       Action   73058679.0         6.6
# 13     263700000.0    Adventure   73058679.0         6.6
# 14     263700000.0       Sci-Fi   73058679.0         6.6
# 15     258000000.0       Action  336530303.0         6.2
# 16     258000000.0    Adventure  336530303.0         6.2
# 17     258000000.0      Romance  336530303.0         6.2
# 18     260000000.0    Adventure  200807262.0         7.8
# 19     260000000.0    Animation  200807262.0         7.8
# 20     260000000.0       Comedy  200807262.0         7.8
# 21     260000000.0       Family  200807262.0         7.8
# 22     260000000.0      Fantasy  200807262.0         7.8
# 23     260000000.0      Musical  200807262.0         7.8
# 24     260000000.0      Romance  200807262.0         7.8
# 25     250000000.0       Action  458991599.0         7.5
# 26     250000000.0    Adventure  458991599.0         7.5
# 27     250000000.0       Sci-Fi  458991599.0         7.5
# 28     250000000.0    Adventure  301956980.0         7.5
# 29     250000000.0       Family  301956980.0         7.5
# ...            ...          ...          ...         ...
# 11512   35000000.0     Thriller   10499968.0         5.7
# 11513      23000.0       Comedy    1227508.0         7.1
# 11514      23000.0        Drama    1227508.0         7.1
# 11515      15000.0       Comedy     192467.0         6.6
# 11516      15000.0        Drama     192467.0         6.6
# 11517      15000.0      Romance     192467.0         6.6
# 11518      15000.0      Romance      76382.0         6.2
# 11519      10000.0       Comedy     180483.0         6.1
# 11520      10000.0        Crime     180483.0         6.1
# 11521      10000.0       Horror     180483.0         6.1
# 11522       4500.0        Drama     136007.0         6.9
# 11523       4500.0        Music     136007.0         6.9
# 11524       4500.0      Romance     136007.0         6.9
# 11525      10000.0        Drama     673780.0         7.5
# 11526    1000000.0        Crime      94596.0         7.4
# 11527    1000000.0       Horror      94596.0         7.4
# 11528    1000000.0      Mystery      94596.0         7.4
# 11529    1000000.0     Thriller      94596.0         7.4
# 11530       7000.0        Drama     424760.0         7.0
# 11531       7000.0       Sci-Fi     424760.0         7.0
# 11532       7000.0     Thriller     424760.0         7.0
# 11533       7000.0     Thriller      70071.0         6.3
# 11534       7000.0       Action    2040920.0         6.9
# 11535       7000.0        Crime    2040920.0         6.9
# 11536       7000.0        Drama    2040920.0         6.9
# 11537       7000.0      Romance    2040920.0         6.9
# 11538       7000.0     Thriller    2040920.0         6.9
# 11539       9000.0       Comedy       4584.0         6.4
# 11540       9000.0        Drama       4584.0         6.4
# 11541       1100.0  Documentary      85222.0         6.6
#
#                                      movie_title  year
# 0                                        Avatar   2009
# 1                                        Avatar   2009
# 2                                        Avatar   2009
# 3                                        Avatar   2009
# 4      Pirates of the Caribbean: At World's End   2007
# 5      Pirates of the Caribbean: At World's End   2007
# 6      Pirates of the Caribbean: At World's End   2007
# 7                                       Spectre   2015
# 8                                       Spectre   2015
# 9                                       Spectre   2015
# 10                        The Dark Knight Rises   2012
# 11                        The Dark Knight Rises   2012
# 12                                  John Carter   2012
# 13                                  John Carter   2012
# 14                                  John Carter   2012
# 15                                 Spider-Man 3   2007
# 16                                 Spider-Man 3   2007
# 17                                 Spider-Man 3   2007
# 18                                      Tangled   2010
# 19                                      Tangled   2010
# 20                                      Tangled   2010
# 21                                      Tangled   2010
# 22                                      Tangled   2010
# 23                                      Tangled   2010
# 24                                      Tangled   2010
# 25                      Avengers: Age of Ultron   2015
# 26                      Avengers: Age of Ultron   2015
# 27                      Avengers: Age of Ultron   2015
# 28       Harry Potter and the Half-Blood Prince   2009
# 29       Harry Potter and the Half-Blood Prince   2009
# ...                                          ...   ...
# 11512                                  Sabotage   2014
# 11513                                   Slacker   1991
# 11514                                   Slacker   1991
# 11515                           The Puffy Chair   2005
# 11516                           The Puffy Chair   2005
# 11517                           The Puffy Chair   2005
# 11518                          Breaking Upwards   2009
# 11519                            Pink Flamingos   1972
# 11520                            Pink Flamingos   1972
# 11521                            Pink Flamingos   1972
# 11522                                     Clean   2004
# 11523                                     Clean   2004
# 11524                                     Clean   2004
# 11525                                The Circle   2000
# 11526                                  The Cure   1997
# 11527                                  The Cure   1997
# 11528                                  The Cure   1997
# 11529                                  The Cure   1997
# 11530                                    Primer   2004
# 11531                                    Primer   2004
# 11532                                    Primer   2004
# 11533                                    Cavite   2005
# 11534                               El Mariachi   1992
# 11535                               El Mariachi   1992
# 11536                               El Mariachi   1992
# 11537                               El Mariachi   1992
# 11538                               El Mariachi   1992
# 11539                                 Newlyweds   2011
# 11540                                 Newlyweds   2011
# 11541                         My Date with Drew   2004
#
# [11542 rows x 6 columns]

# %% [markdown]
# Next we can group by the genre column.  Then look at the imdb score across different genres.

# %%
df_genre.groupby('genre')[['imdb_score']].mean().sort_values('imdb_score').plot.bar()
plt.ylabel('Averge Imdb Score')

# %% [markdown]
# ### Exercise 3
# - Which genre has the highest mean budget?
# - When the number of bars becomes larger try to a horizontal plot.

# %%
#### Your code here
df_genre.groupby('genre')['budget'].mean().sort_values(ascending=False).index[0]
# Out:
# 'Animation'

# %%
df_genre.groupby('genre')['budget'].mean().sort_values().plot.barh()
plt.xlabel('Averge Budget')

# %% [markdown]
# # Boxplot
# - A boxplot is another way to visualize the distribution of a numeric feature. Let Q1, Q2 and Q3 represent the 25%, 50% and 75% quantile, respectively.
# - A Boxplot is made of five quantiles: Q1−1.5(Q3−Q1), Q1, Q2, Q3, and Q3+1. 5(Q3−Q1). It can be made by function boxplot.

# %%
df_score = df[['color', 'imdb_score']].dropna()
df_score.boxplot(by='color', column='imdb_score')
plt.ylabel('Imdb Score')

# %% [markdown]
# ### Exercise 4
# What is the duration distribution for different kinds of posters?

# %%
#### Your code here
df_dur = df[['color', 'duration']]
df_dur.boxplot(by='color', column='duration')
plt.ylabel('Length of Duration')

# %% [markdown]
# # Seaborn

# %%
import seaborn as sns

# %% [markdown]
# Seaborn provides functionality to infer a distribution from the sample data.  This is known as kernel density estimation.

# %%
sns.kdeplot(df['imdb_score'], shade=True, label='Estimated PDF of imdb score')
# Out:
# //anaconda/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %% [markdown]
# It is possible to combine histogram and the distribution estimate plot:

# %%
sns.distplot(df['imdb_score'])
# Out:
# //anaconda/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %% [markdown]
# The joinplot() function combines histogram and scatter plot.

# %%
sns.jointplot(df['num_critic_for_reviews'], df['imdb_score'])

# %% [markdown]
# The "pearsonr=0.31" indicates the pearson correlation of these two variables. The p value is pretty small, indicating that there is a significant linear relation between the two variables.

# %% [markdown]
# Visualize the distribution of multiple features by using boxplot:

# %%
sns.boxplot(x='color', y='imdb_score', data=df)

# %% [markdown]
# ### Advanced plots
# Seaborn also provides another famous sample dataset named "tips":

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# This is a famous dataset record the information of people of different sex, being a smoker or not, visiting at different day or for different meal, the size of parties they joined, and the tip and the total bill they pay.
#
# To visualize the relation between total_bill and tip, use scatter plot. Seaborn performs linear fitting as well.

# %%
sns.lmplot("total_bill", "tip", tips)

# %%
sns.jointplot("total_bill", "tip", tips,kind='reg')
# Out:
# //anaconda/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %% [markdown]
# Visualize "Male" and "Female" data points, represented by hue.

# %%
sns.lmplot("total_bill", "tip", tips, hue="sex", palette="Set2")

# %% [markdown]
# Pass a dictionary to the palette argument, specifying the color of each level in the hue variable.

# %%
sns.lmplot("total_bill", "tip", tips, hue="sex", palette={"Male": "b", "Female": "r"})

# %% [markdown]
# Here:
# - hue indicates the column categorical feature used to split the data
# - palette specifies the color used in the graphic

# %% [markdown]
# To compare the same kind of plot for different features, faceting is useful.

# %%
SexGrid = sns.FacetGrid(tips, col='sex', hue="sex", palette="Set1", size=4)
SexGrid.map(sns.distplot, "tip")
# Out:
# //anaconda/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %% [markdown]
# Above the column and hue are mapped to the same categorical feature.  Below column and hue are mapped to different categorical features.

# %%
SexGrid = sns.FacetGrid(tips, col='smoker', hue="sex", palette="Set1", size=4)
SexGrid.map(sns.distplot, "tip")
# Out:
# //anaconda/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %% [markdown]
# FacetGrid() offers three ways to split data: hue, column and row.  The .map() method specifies the plot type and the x,y axes.

# %% [markdown]
# Facet can be used to differentiate multiple factors as well.

# %%
tipsGrid = sns.FacetGrid(tips, row='sex', col='smoker',\
                               hue='time', palette="Set2")
tipsGrid.map(sns.regplot, 'total_bill', 'tip')
tipsGrid.add_legend()

# %% [markdown]
# ### Exercise 5
# Use FacetGrid to compare the distribution of imdb score for different poster color.

# %%
#### Your code here
g = sns.FacetGrid(data=df, col='color', hue='color', palette='Set1', size=4)
g.map(sns.distplot, 'imdb_score')
# Out:
# //anaconda/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %% [markdown]
# FacetGrid helps explore specific variables and the relationships between pairs of variables, while segmenting the data set across multiple categorical features.
#
# PairGrid explores the relationships between whole sets of numerical features.

# %%
tipGrid = sns.PairGrid(tips)
tipGrid.map(plt.scatter)

# %% [markdown]
# Switching to the iris data:

# %%
iris = sns.load_dataset("iris")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
g = sns.PairGrid(iris)
g.map_diag(plt.hist)
g.map_offdiag(plt.scatter)

# %% [markdown]
# Some examples with different type of plot and colors.

# %%
g = sns.PairGrid(iris, hue = 'species', palette='Set2',\
           hue_kws={'cmap':['Greens','Oranges','Blues']})

g.map_diag(plt.hist)
g.map_upper(plt.scatter)
g.map_lower(sns.kdeplot)
g.add_legend()

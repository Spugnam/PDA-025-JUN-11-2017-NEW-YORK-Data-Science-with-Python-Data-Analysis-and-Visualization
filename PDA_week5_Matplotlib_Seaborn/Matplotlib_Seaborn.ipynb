# %% [markdown]
# # Matplotlib & Seaborn

# %% [markdown]
# ## Overview
#
# matplotlib is a python 2D plotting library built on the top of the basic Python language and Numpy.
# More about matplotlib can be found in its [documentation](http://matplotlib.org/contents.html).
#
# Seaborn is a Python visualization library based on matplotlib. It provides a high-level interface for drawing attractive statistical graphics. Here is the [documentation](http://seaborn.pydata.org/index.html).

# %% [markdown]
# To display the graph inside IPython notebook, run the following code.

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# Begin by making a simple plot matplotlib.  Create a set of x-coordinates and y-coordinates.  Then plot them, as follows:

# %%
x=[7,8,9,11]
y=[9,4,6,7]
plt.plot(x,y)

# %%
#for information on plot function
# ?plt.plot

# %% [markdown]
# The style of the plot can be set in several ways.  The line style, color, marker size, line width and opacity may be set using additional parameters.  Multiple series can also be plotted in the the same graph.

# %%
plt.plot(x,y,'.-',color='green',markersize=20,alpha=0.4)
y2=[1,8,3,5]
plt.plot(x,y2,'.--',color='red',markersize=10,alpha=0.7)
y3=[2,5,7,9]
plt.plot(x, y3, 'o--',color='blue',markersize=30,alpha=0.1)

# %% [markdown]
# The plot can also be given a legend, title and labels on the x and y axis.  The range and tick marks can also be set for the axes.  Text can be added to the plot as well.  These are all sown in the following graph.

# %%
plt.plot(x,y,'.-',color='green',markersize=20,
         linewidth=4,alpha=0.4,label='data1')
plt.plot(x,y2,'.--',color='red',markersize=10,alpha=0.7,
         linewidth=0.3,label='data2')
plt.legend(loc=1)
plt.title('Example Plot $x^2\lambda$')
plt.xlabel('horizontal axis')
plt.ylabel('vertical axis')
plt.xlim(6,12)
plt.ylim(0,10)
plt.xticks([6,9,12])
plt.yticks([0,4,8])
plt.text(10,2,'random text',color='blue',size=14)

# %%
del plt.xticks

# %%
plt.plot(x, y3, 'o--',color='blue',markersize=10,alpha=0.1,label='data3')
plt.legend(loc=4)
plt.title('Example Plot $e^{x^3} = -1, log \lambda$')
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.xlim(6,12)
plt.ylim(1, 9)
plt.xticks([7, 8, 9, 11])
plt.yticks([2,5,9])
plt.text(9,5,'New plot test',color='blue',size=14)

# %% [markdown]
# One-dimensional numpy arrays may also be used as data series.  Below a sin function is plotted.
#
# The resulting plot may be saved as an image.

# %%
X=np.linspace(0,4*3.14,101)
Y=np.sin(X)
plt.plot(X,Y,'.')

### save file
plt.savefig('myplot.png')

# %%
X
# Out:
# array([  0.    ,   0.1256,   0.2512,   0.3768,   0.5024,   0.628 ,
#          0.7536,   0.8792,   1.0048,   1.1304,   1.256 ,   1.3816,
#          1.5072,   1.6328,   1.7584,   1.884 ,   2.0096,   2.1352,
#          2.2608,   2.3864,   2.512 ,   2.6376,   2.7632,   2.8888,
#          3.0144,   3.14  ,   3.2656,   3.3912,   3.5168,   3.6424,
#          3.768 ,   3.8936,   4.0192,   4.1448,   4.2704,   4.396 ,
#          4.5216,   4.6472,   4.7728,   4.8984,   5.024 ,   5.1496,
#          5.2752,   5.4008,   5.5264,   5.652 ,   5.7776,   5.9032,
#          6.0288,   6.1544,   6.28  ,   6.4056,   6.5312,   6.6568,
#          6.7824,   6.908 ,   7.0336,   7.1592,   7.2848,   7.4104,
#          7.536 ,   7.6616,   7.7872,   7.9128,   8.0384,   8.164 ,
#          8.2896,   8.4152,   8.5408,   8.6664,   8.792 ,   8.9176,
#          9.0432,   9.1688,   9.2944,   9.42  ,   9.5456,   9.6712,
#          9.7968,   9.9224,  10.048 ,  10.1736,  10.2992,  10.4248,
#         10.5504,  10.676 ,  10.8016,  10.9272,  11.0528,  11.1784,
#         11.304 ,  11.4296,  11.5552,  11.6808,  11.8064,  11.932 ,
#         12.0576,  12.1832,  12.3088,  12.4344,  12.56  ])

# %%
#the resulting image
from IPython.display import Image
Image('myplot.png')

# %% [markdown]
# Bar plots are another type of graph which can be redered.

# %%
t=np.linspace(0,5*3.14,51)
s=(9*np.sin(t)/((t+1)))+0.5*t+3*(np.random.randn(51)/(2+t/2.5))**2
plt.bar(t,s,edgecolor='black', width=0.2)
# Out:
# <Container object of 51 artists>

# %%
#horizontal bar plot
plt.barh(t[:10],s[:10], height=0.3)
# Out:
# <Container object of 10 artists>

# %% [markdown]
# Scatter plots are also useful.
#
# Below are four 2-D standard normal distributions centered at (2,2),(2,-2),(-2,2),(-2,-2)

# %%
N=400
D=2

X=np.random.randn(N,D)

X[:200,:] = X[:200,:] - 2*np.ones((200,D))
X[200:,:] = X[200:,:] + 2*np.ones((200,D))
X[100:300,0]=-X[100:300,0]

#note how colors are assigned with a list
T=np.array([0]*100 + [1]*100 + [2]*100 + [3]*100)
 
plt.scatter(X[:,0],X[:,1],c=T,s=100, alpha=0.5)

# %% [markdown]
# **Exercise 0**
#
# The code below creates a pandas data frame from the file 'gold_hist.txt'.  It contains historical gold prices (end of year) from 1792 to 2015.
#
# - Plot the data with time on the horizontal axis and gold price on the vertical.  Provide a title and labels for the horizontal and vertical axes.
# - Plot the the data again using a log vertical scale.
# Use `plt.yscale('log')`
#
# - The US dollar was removed from a gold standard in 1973.  Plot the data again, on a linear scale (normal scale), from 1972 and after.  Label the point representing peak price.

# %%
f = open('gold_hist.txt', 'r')
lines = f.readlines()
f.close()
lines=list(map(lambda x: x.strip() ,lines))
prices=[[int(lines[2*i]),float(lines[2*i+1][1:].replace(',',''))]\
        for i in range(int(len(lines)/2)) ]
prices.sort()
gold=pd.DataFrame(prices,columns=['year','price'])
gold.head(2)
# Out:
#    year  price
# 0  1792  19.39
# 1  1793  19.39

# %%
#your code here
plt.plot(gold.year, gold.price)
plt.xlabel('year')
plt.ylabel('Gold price ($/ounce)')
plt.title('Gold historical price')
plt.yscale('log')

# %%
plt.plot(gold.year, gold.price)
plt.xlabel('year')
plt.ylabel('Gold price ($/ounce)')
plt.xlim(1973, gold.iloc[-1,0])
plt.title('Gold historical price')
plt.text(gold.loc[gold.price.idxmax(),'year'], gold.loc[gold.price.idxmax(),'price'], ' Historical maximum: '+str(int(gold.loc[gold.price.idxmax(),'price'])))

# %%
max(gold.price)
# Out:
# 1664.0

# %%
gold.price.idxmax()
# Out:
# 218

# %%
gold.iloc[218,:]
# Out:
# year     2012.0
# price    1664.0
# Name: 218, dtype: float64

# %%
print(gold.iloc[218,:].price, gold.iloc[218,:].year, 'Historical max')
# Out:
# 1664.0 2012.0 Historical max

# %%
' Historical maximum: '+str(gold.loc[gold.price.idxmax(),'price'])
# Out:
# ' Historical maximum1664.0'

# %% [markdown]
# # Case Study

# %% [markdown]
# For this case study use the IMDB dataset.  It was scraped and uploaded to Kaggle by Sun Chuan (graduate of Bootcamp 6). Check it out [here](https://www.kaggle.com/deepmatrix/imdb-5000-movie-dataset).
#
# Load the data first.

# %%
df = pd.read_csv('movie_metadata.csv')

# %%
df.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# 1                 40000.0  309404152.0         Action|Adventure|Fantasy
# 2                 11000.0  200074175.0        Action|Adventure|Thriller
# 3                 27000.0  448130642.0                  Action|Thriller
# 4                   131.0          NaN                      Documentary
#
#           ...          num_user_for_reviews language  country  content_rating  \
# 0         ...                        3054.0  English      USA           PG-13
# 1         ...                        1238.0  English      USA           PG-13
# 2         ...                         994.0  English       UK           PG-13
# 3         ...                        2701.0  English      USA           PG-13
# 4         ...                           NaN      NaN      NaN             NaN
#
#         budget  title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 0  237000000.0      2009.0                  936.0        7.9          1.78
# 1  300000000.0      2007.0                 5000.0        7.1          2.35
# 2  245000000.0      2015.0                  393.0        6.8          2.35
# 3  250000000.0      2012.0                23000.0        8.5          2.35
# 4          NaN         NaN                   12.0        7.1           NaN
#
#   movie_facebook_likes
# 0                33000
# 1                    0
# 2                85000
# 3               164000
# 4                    0
#
# [5 rows x 28 columns]

# %% [markdown]
# To display the full data frame set the maximum number of columns shown, as follows:

# %%
pd.set_option('display.max_columns', df.shape[1])

# %%
df.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# 1                 40000.0  309404152.0         Action|Adventure|Fantasy
# 2                 11000.0  200074175.0        Action|Adventure|Thriller
# 3                 27000.0  448130642.0                  Action|Thriller
# 4                   131.0          NaN                      Documentary
#
#       actor_1_name                                        movie_title  \
# 0      CCH Pounder                                            Avatar
# 1      Johnny Depp          Pirates of the Caribbean: At World's End
# 2  Christoph Waltz                                           Spectre
# 3        Tom Hardy                             The Dark Knight Rises
# 4      Doug Walker  Star Wars: Episode VII - The Force Awakens    ...
#
#    num_voted_users  cast_total_facebook_likes          actor_3_name  \
# 0           886204                       4834             Wes Studi
# 1           471220                      48350        Jack Davenport
# 2           275868                      11700      Stephanie Sigman
# 3          1144337                     106759  Joseph Gordon-Levitt
# 4                8                        143                   NaN
#
#    facenumber_in_poster                                      plot_keywords  \
# 0                   0.0             avatar|future|marine|native|paraplegic
# 1                   0.0  goddess|marriage ceremony|marriage proposal|pi...
# 2                   1.0                bomb|espionage|sequel|spy|terrorist
# 3                   0.0  deception|imprisonment|lawlessness|police offi...
# 4                   0.0                                                NaN
#
#                                      movie_imdb_link  num_user_for_reviews  \
# 0  http://www.imdb.com/title/tt0499549/?ref_=fn_t...                3054.0
# 1  http://www.imdb.com/title/tt0449088/?ref_=fn_t...                1238.0
# 2  http://www.imdb.com/title/tt2379713/?ref_=fn_t...                 994.0
# 3  http://www.imdb.com/title/tt1345836/?ref_=fn_t...                2701.0
# 4  http://www.imdb.com/title/tt5289954/?ref_=fn_t...                   NaN
#
#   language country content_rating       budget  title_year  \
# 0  English     USA          PG-13  237000000.0      2009.0
# 1  English     USA          PG-13  300000000.0      2007.0
# 2  English      UK          PG-13  245000000.0      2015.0
# 3  English     USA          PG-13  250000000.0      2012.0
# 4      NaN     NaN            NaN          NaN         NaN
#
#    actor_2_facebook_likes  imdb_score  aspect_ratio  movie_facebook_likes
# 0                   936.0         7.9          1.78                 33000
# 1                  5000.0         7.1          2.35                     0
# 2                   393.0         6.8          2.35                 85000
# 3                 23000.0         8.5          2.35                164000
# 4                    12.0         7.1           NaN                     0

# %% [markdown]
# Describe will exclude the missing value by default.

# %%
#df.describe()
df.dropna().describe()
# Out:
#        num_critic_for_reviews     duration  director_facebook_likes  \
# count             3756.000000  3756.000000              3756.000000
# mean               167.378328   110.257987               807.336528
# std                123.452040    22.646717              3068.171683
# min                  2.000000    37.000000                 0.000000
# 25%                 77.000000    96.000000                11.000000
# 50%                138.500000   106.000000                64.000000
# 75%                224.000000   120.000000               235.000000
# max                813.000000   330.000000             23000.000000
#
#        actor_3_facebook_likes  actor_1_facebook_likes         gross  \
# count             3756.000000             3756.000000  3.756000e+03
# mean               771.279553             7751.338658  5.261282e+07
# std               1894.249869            15519.339621  7.031787e+07
# min                  0.000000                0.000000  1.620000e+02
# 25%                194.000000              745.000000  8.270233e+06
# 50%                436.000000             1000.000000  3.009311e+07
# 75%                691.000000            13000.000000  6.688194e+07
# max              23000.000000           640000.000000  7.605058e+08
#
#        num_voted_users  cast_total_facebook_likes  facenumber_in_poster  \
# count     3.756000e+03                3756.000000           3756.000000
# mean      1.058267e+05               11527.101970              1.377263
# std       1.520354e+05               19122.176905              2.041541
# min       9.100000e+01                   0.000000              0.000000
# 25%       1.966700e+04                1919.750000              0.000000
# 50%       5.397350e+04                4059.500000              1.000000
# 75%       1.286020e+05               16240.000000              2.000000
# max       1.689764e+06              656730.000000             43.000000
#
#        num_user_for_reviews        budget   title_year  \
# count           3756.000000  3.756000e+03  3756.000000
# mean             336.843184  4.623685e+07  2002.976571
# std              411.227368  2.260103e+08     9.888108
# min                4.000000  2.180000e+02  1927.000000
# 25%              110.000000  1.000000e+07  1999.000000
# 50%              210.000000  2.500000e+07  2004.000000
# 75%              398.250000  5.000000e+07  2010.000000
# max             5060.000000  1.221550e+10  2016.000000
#
#        actor_2_facebook_likes   imdb_score  aspect_ratio  movie_facebook_likes
# count             3756.000000  3756.000000   3756.000000           3756.000000
# mean              2021.775825     6.465282      2.111014           9353.829340
# std               4544.908236     1.056247      0.353068          21462.889123
# min                  0.000000     1.600000      1.180000              0.000000
# 25%                384.750000     5.900000      1.850000              0.000000
# 50%                685.500000     6.600000      2.350000            227.000000
# 75%                976.000000     7.200000      2.350000          11000.000000
# max             137000.000000     9.300000     16.000000         349000.000000

# %% [markdown]
# `value_counts()` will freturn a frequency count for every value in a column.

# %%
df['language'].value_counts()
# Out:
# English       4704
# French          73
# Spanish         40
# Hindi           28
# Mandarin        26
# German          19
# Japanese        18
# Italian         11
# Russian         11
# Cantonese       11
# Korean           8
# Portuguese       8
# Arabic           5
# Danish           5
# Swedish          5
# Hebrew           5
# Dutch            4
# Persian          4
# Polish           4
# Norwegian        4
# Chinese          3
# Thai             3
# Zulu             2
# Icelandic        2
# None             2
# Aboriginal       2
# Indonesian       2
# Romanian         2
# Dari             2
# Kazakh           1
# Kannada          1
# Urdu             1
# Vietnamese       1
# Hungarian        1
# Filipino         1
# Maya             1
# Slovenian        1
# Panjabi          1
# Mongolian        1
# Czech            1
# Swahili          1
# Telugu           1
# Dzongkha         1
# Greek            1
# Aramaic          1
# Bosnian          1
# Tamil            1
# Name: language, dtype: int64

# %%
df['director_name'].value_counts()
# Out:
# Steven Spielberg        26
# Woody Allen             22
# Clint Eastwood          20
# Martin Scorsese         20
# Ridley Scott            17
# Steven Soderbergh       16
# Spike Lee               16
# Tim Burton              16
# Renny Harlin            15
# Oliver Stone            14
# Ron Howard              13
# Robert Rodriguez        13
# Barry Levinson          13
# Sam Raimi               13
# Robert Zemeckis         13
# John Carpenter          13
# Michael Bay             13
# Joel Schumacher         13
# Peter Jackson           12
# Richard Donner          12
# Brian De Palma          12
# Shawn Levy              12
# Kevin Smith             12
# Tony Scott              12
# Wes Craven              12
# Stephen Frears          11
# Rob Reiner              11
# Richard Linklater       11
# Chris Columbus          11
# Rob Cohen               11
#                         ..
# Danny Steinmann          1
# Mathieu Amalric          1
# Patrick Ryan Sims        1
# Tom Sanchez              1
# François Girard          1
# Richard E. Grant         1
# Ethan Maniquis           1
# Mark Tonderai            1
# Sam Martin               1
# Henry Hathaway           1
# Patrick Meaney           1
# William Wyler            1
# Neal Brennan             1
# William Cottrell         1
# Deb Hagan                1
# Steve Hickner            1
# Bill Plympton            1
# Reinhard Klooss          1
# Jason Eisener            1
# Giuliano Montaldo        1
# Nick Hurran              1
# Joshua Michael Stern     1
# Kiyoshi Kurosawa         1
# Hitoshi Matsumoto        1
# Anthony Mann             1
# Jason Trost              1
# Herb Freed               1
# Adam Marcus              1
# Justin Paul Miller       1
# John Gray                1
# Name: director_name, Length: 2398, dtype: int64

# %% [markdown]
# # Histogram

# %%
plt.hist(df['imdb_score'],edgecolor='k', color="#0061ba")
# Out:
# (array([   16.,    38.,   102.,   222.,   579.,  1158.,  1515.,  1085.,
#           307.,    21.]),
#  array([ 1.6 ,  2.39,  3.18,  3.97,  4.76,  5.55,  6.34,  7.13,  7.92,
#          8.71,  9.5 ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# Explore some of the available parameters by placing the cursor inside the function parentheses and pressing **shift+tab**
#
# It is possible to set the color and the number of bins. For color, type `"blue"` or `"b"` for short. Color accepts hex color code, pick a color from this [website](http://www.color-hex.com/) and paste the hexadecimal code.

# %%
import seaborn as sns
sns.distplot(df['imdb_score'])

# %%
plt.hist(df['imdb_score'], bins=20, color="#666699", orientation="horizontal")
# Out:
# (array([   5.,   11.,   12.,   26.,   51.,   51.,   95.,  127.,  217.,
#          362.,  497.,  661.,  795.,  720.,  666.,  419.,  226.,   81.,
#           18.,    3.]),
#  array([ 1.6  ,  1.995,  2.39 ,  2.785,  3.18 ,  3.575,  3.97 ,  4.365,
#          4.76 ,  5.155,  5.55 ,  5.945,  6.34 ,  6.735,  7.13 ,  7.525,
#          7.92 ,  8.315,  8.71 ,  9.105,  9.5  ]),
#  <a list of 20 Patch objects>)

# %% [markdown]
# ### Exercise 1
#
# - Create a histogram of the budget column. Does Python raise an error? Fix it by following this [Stack Overflow Link](http://stackoverflow.com/q/20656663)
#
# - How does the graph look? Is there anyway to improve this? What does the x-axis stand for?
# - All the code in the same cell will contribute to the same plot.
# - Type `plt.` and press tab to get a hint.

# %%
#### Your code here
sns.distplot(df.dropna()['budget'])

# %%
plt.hist(df.dropna()['budget'],bins=50, edgecolor='k', color="#0061ba")
plt.yscale('log')

# %% [markdown]
# - Pandas dataframe also provides plotting function. It is calling the matplotlib library behind the scenes.
# - Check all the available plots from the documenation [here](http://pandas.pydata.org/pandas-docs/version/0.19.2/visualization.html#visualization)

# %%
np.log(df['budget']).plot.hist(bins=25)
plt.xlabel('log of budget')
plt.ylabel('count')
plt.title('Histogram of budget', fontsize=20)

# %% [markdown]
# # Scatterplot
# Scatterplots are useful for bivariate analysis. We can check the relationship between two columns.
# Suppose we want to figure out whether there is a relationship between the gross income and the budget.

# %%
plt.scatter(df['budget'], df['gross'])
plt.xlabel('Budget')
plt.ylabel('Gross Income')

# %%
plt.scatter(df['budget'], df['gross'])
plt.xlabel('Budget')
plt.ylabel('Gross Income')
plt.xlim(0,.1e10) #not sure why points not shown in graph below
# Out:
# (0, 1000000000.0)

# %%
#another way
plt.plot(df['budget'], df['gross'],'.')
plt.xlabel('Budget')
plt.ylabel('Gross Income')

# %%
#another way
plt.plot(df['budget'], df['gross'],'.')
plt.xlabel('Budget')
plt.ylabel('Gross Income')
plt.xlim(0, 0.3e9)
# Out:
# (0, 300000000.0)

# %% [markdown]
# Here is a way to plot it using the plotting function from pandas.

# %%
df.plot(x='budget', y='gross',kind='scatter')
plt.xlabel('Budget')
plt.ylabel('Gross Income')

# %%
#another way
df.plot.scatter(x='budget', y='gross')
plt.xlabel('Budget')
plt.ylabel('Gross Income')

# %% [markdown]
# There are some outliers which make the graph less useful. Remove them from the dataframe using the apply function.

# %%
scatter_df = df[['gross', 'budget']]
scatter_df = scatter_df[scatter_df.apply(lambda x: np.abs(x - x.mean()) / x.std() < 3).all(axis=1)]

# %%
plt.scatter(scatter_df['budget'], scatter_df['gross'],alpha=0.1)

# %% [markdown]
# Now take a look at those outliers. In the previous example the ouliers were removed. Use the **~** symbol to invert the boolean mask.

# %%
~pd.DataFrame([[True]])
# Out:
#        0
# 0  False

# %%
~pd.DataFrame([[False]])
# Out:
#       0
# 0  True

# %% [markdown]
# Merge the outlier dataframe with the original other features.  Sort by budget in descending order.

# %%
outliers = df[['gross', 'budget']].dropna()
outliers = outliers[~outliers.apply(lambda x: np.abs(x - x.mean()) / x.std() < 3).all(axis=1)]
outliers.merge(df)[['gross', 'budget', 'movie_title']].sort_values(by='budget', ascending=False)
# Out:
#            gross        budget  \
# 98     2201412.0  1.221550e+10
# 103     211667.0  4.200000e+09
# 99      195888.0  2.500000e+09
# 95     2298191.0  2.400000e+09
# 96      410388.0  2.127520e+09
# 102     439162.0  1.100000e+09
# 104   10037390.0  1.000000e+09
# 1    309404152.0  3.000000e+08
# 6    336530303.0  2.580000e+08
# 5    336530303.0  2.580000e+08
# 4    336530303.0  2.580000e+08
# 3    336530303.0  2.580000e+08
# 18   407197282.0  2.500000e+08
# 9    330249062.0  2.500000e+08
# 7    458991599.0  2.500000e+08
# 2    448130642.0  2.500000e+08
# 8    301956980.0  2.500000e+08
# 0    760505847.0  2.370000e+08
# 16   262030663.0  2.300000e+08
# 11   291021565.0  2.250000e+08
# 10   423032628.0  2.250000e+08
# 12   623279547.0  2.200000e+08
# 13   623279547.0  2.200000e+08
# 14   623279547.0  2.200000e+08
# 15   623279547.0  2.200000e+08
# 17   658672302.0  2.000000e+08
# 29   334185206.0  2.000000e+08
# 31   402076689.0  2.000000e+08
# 30   268488329.0  2.000000e+08
# 32   414984497.0  2.000000e+08
# ..           ...           ...
# 68   474544677.0  1.150000e+08
# 65   380262555.0  1.130000e+08
# 69   274084951.0  1.000000e+08
# 71   261970615.0  1.000000e+08
# 72   380838870.0  9.400000e+07
# 73   377019252.0  9.400000e+07
# 74   340478898.0  9.400000e+07
# 70   313837577.0  9.300000e+07
# 75   261437578.0  9.200000e+07
# 85   279167575.0  8.000000e+07
# 76   407999255.0  7.800000e+07
# 79   368049635.0  7.600000e+07
# 78   323505540.0  7.500000e+07
# 80   306124059.0  7.500000e+07
# 81   336029560.0  7.400000e+07
# 83   300523113.0  6.800000e+07
# 84   356784000.0  6.300000e+07
# 90   267652016.0  6.000000e+07
# 87   350123553.0  5.880000e+07
# 86   363024263.0  5.800000e+07
# 88   329691196.0  5.500000e+07
# 89   296623634.0  5.000000e+07
# 77   422783777.0  4.500000e+07
# 91   293501675.0  4.000000e+07
# 92   277313371.0  3.500000e+07
# 93   309125409.0  3.250000e+07
# 97   285761243.0  1.800000e+07
# 94   290158751.0  1.800000e+07
# 100  460935665.0  1.100000e+07
# 101  434949459.0  1.050000e+07
#
#                                            movie_title
# 98                                           The Host
# 103                                    Lady Vengeance
# 99                                           Fateless
# 95                                  Princess Mononoke
# 96                                           Steamboy
# 102                                             Akira
# 104                                     Godzilla 2000
# 1            Pirates of the Caribbean: At World's End
# 6                                        Spider-Man 3
# 5                                        Spider-Man 3
# 4                                        Spider-Man 3
# 3                                        Spider-Man 3
# 18                         Captain America: Civil War
# 9                  Batman v Superman: Dawn of Justice
# 7                             Avengers: Age of Ultron
# 2                               The Dark Knight Rises
# 8              Harry Potter and the Half-Blood Prince
# 0                                              Avatar
# 16                             The Amazing Spider-Man
# 11                                       Man of Steel
# 10         Pirates of the Caribbean: Dead Man's Chest
# 12                                       The Avengers
# 13                                       The Avengers
# 14                                       The Avengers
# 15                                       The Avengers
# 17                                            Titanic
# 29                                Alice in Wonderland
# 31                Transformers: Revenge of the Fallen
# 30                                Monsters University
# 32                                        Toy Story 3
# ..                                                 ...
# 68          Star Wars: Episode I - The Phantom Menace
# 65       Star Wars: Episode III - Revenge of the Sith
# 69                                            Gravity
# 71            Harry Potter and the Chamber of Secrets
# 72                                       Finding Nemo
# 73      The Lord of the Rings: The Return of the King
# 74              The Lord of the Rings: The Two Towers
# 70   The Lord of the Rings: The Fellowship of the R...
# 75                                    The Incredibles
# 85                                   Meet the Fockers
# 76                                   The Hunger Games
# 79                                    Despicable Me 2
# 78                            The Secret Life of Pets
# 80                                   Independence Day
# 81                                            Minions
# 83                         The Twilight Saga: Eclipse
# 84                                      Jurassic Park
# 90                                              Shrek
# 87                                    American Sniper
# 86                                           Deadpool
# 88                                       Forrest Gump
# 89                        The Twilight Saga: New Moon
# 77                                      The Lion King
# 91                                    The Sixth Sense
# 92                                       The Hangover
# 93         Star Wars: Episode VI - Return of the Jedi
# 97                                         Home Alone
# 94     Star Wars: Episode V - The Empire Strikes Back
# 100                Star Wars: Episode IV - A New Hope
# 101                        E.T. the Extra-Terrestrial
#
# [105 rows x 3 columns]

# %% [markdown]
# Examine the relationship between imdb_score and gross income.

# %%
score_df = df[['gross', 'imdb_score']].dropna()
#score_df = score_df[score_df.apply(lambda x: np.abs(x - x.mean()) / x.std() < 3).all(axis=1)]

# %%
score_df.plot.scatter('gross', 'imdb_score',alpha=0.3)

# %% [markdown]
# ### Exercise 2
# - How is gross income related to director Facebook likes?
# - How is the imdb_score related to num_critic_for_reviews?

# %%
df.head(2)
# Out:
#    color   director_name  num_critic_for_reviews  duration  \
# 0  Color   James Cameron                   723.0     178.0
# 1  Color  Gore Verbinski                   302.0     169.0
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# 1                 40000.0  309404152.0         Action|Adventure|Fantasy
#
#   actor_1_name                                movie_title  num_voted_users  \
# 0  CCH Pounder                                    Avatar            886204
# 1  Johnny Depp  Pirates of the Caribbean: At World's End            471220
#
#    cast_total_facebook_likes    actor_3_name  facenumber_in_poster  \
# 0                       4834       Wes Studi                   0.0
# 1                      48350  Jack Davenport                   0.0
#
#                                        plot_keywords  \
# 0             avatar|future|marine|native|paraplegic
# 1  goddess|marriage ceremony|marriage proposal|pi...
#
#                                      movie_imdb_link  num_user_for_reviews  \
# 0  http://www.imdb.com/title/tt0499549/?ref_=fn_t...                3054.0
# 1  http://www.imdb.com/title/tt0449088/?ref_=fn_t...                1238.0
#
#   language country content_rating       budget  title_year  \
# 0  English     USA          PG-13  237000000.0      2009.0
# 1  English     USA          PG-13  300000000.0      2007.0
#
#    actor_2_facebook_likes  imdb_score  aspect_ratio  movie_facebook_likes
# 0                   936.0         7.9          1.78                 33000
# 1                  5000.0         7.1          2.35                     0

# %%
#### Your code here
score_df = df[['gross', 'director_facebook_likes']].dropna()
plt.scatter(df['director_facebook_likes'], df['gross'],alpha=0.3)
plt.xlabel('Director Facebook Likes')
plt.ylabel('Gross income')

# %% [markdown]
# # Barplot
#
# Barplot is often used to visualize the amount of each class in a categorical feature. It shows the difference between factors.
#
# Below is a bar graph showing the median imdb score for different countries.  The results are shown in descending values.  What is the story this graph tells?

# %%
plt.figure(figsize=(12,6))
df.groupby('country')['imdb_score'].median().sort_values(ascending=False).plot.bar()

# %% [markdown]
# Here are the top seven countries.

# %%
plt.figure(figsize=(12,6))
df.groupby('country')['imdb_score'].median().sort_values(ascending=False).head(7).plot.bar()

# %% [markdown]
# The next data frame examines the mean budget of movies over the last ten years.  What story does this graph tell?

# %%
df_clean = df.dropna()
bar_df = df_clean.groupby('title_year')[['budget']].mean().tail(10)
bar_df
# Out:
#                   budget
# title_year
# 2007.0      4.104793e+07
# 2008.0      4.503644e+07
# 2009.0      4.169074e+07
# 2010.0      4.873580e+07
# 2011.0      4.471375e+07
# 2012.0      4.885083e+07
# 2013.0      5.095347e+07
# 2014.0      5.228738e+07
# 2015.0      5.697574e+07
# 2016.0      7.609153e+07

# %%
bar_df.index = bar_df.index.astype(np.int16)
bar_df.plot.bar()

# %% [markdown]
# ### Genre
# - Check how column features vary across different genres. This is tricky since there are many films with multiple genres separated by the `|` symbol. One solution is to duplicate each film with multiple genres into multiple rows, each with one genre.
# - Then look at the imdb distribution over all the genres.

# %%
df_clean = df[['genres', 'budget', 'gross', 'title_year', 'imdb_score','movie_title']].dropna()
df_genre = pd.DataFrame(columns = ['genre', 'budget', 'gross', 'year', 'imdb_score','movie_title'])

def genreRemap(row):
    global df_genre
    d = {}
    genres = row['genres'].split('|')
    n = len(genres)
    d['genre'] = genres
    d['movie_title'] = [row['movie_title']] * n
    d['budget'] = [row['budget']] * n
    d['gross'] = [row['gross']] * n
    d['year'] = [row['title_year']] * n
    d['imdb_score'] = [row['imdb_score']] * n

    df_genre = df_genre.append(pd.DataFrame(d), ignore_index = True)

df_clean.apply(genreRemap, axis = 1)
df_genre['year'] = df_genre['year'].astype(np.int16)

# %%
df_genre
# Out:
#             budget        genre        gross  imdb_score  \
# 0      237000000.0       Action  760505847.0         7.9
# 1      237000000.0    Adventure  760505847.0         7.9
# 2      237000000.0      Fantasy  760505847.0         7.9
# 3      237000000.0       Sci-Fi  760505847.0         7.9
# 4      300000000.0       Action  309404152.0         7.1
# 5      300000000.0    Adventure  309404152.0         7.1
# 6      300000000.0      Fantasy  309404152.0         7.1
# 7      245000000.0       Action  200074175.0         6.8
# 8      245000000.0    Adventure  200074175.0         6.8
# 9      245000000.0     Thriller  200074175.0         6.8
# 10     250000000.0       Action  448130642.0         8.5
# 11     250000000.0     Thriller  448130642.0         8.5
# 12     263700000.0       Action   73058679.0         6.6
# 13     263700000.0    Adventure   73058679.0         6.6
# 14     263700000.0       Sci-Fi   73058679.0         6.6
# 15     258000000.0       Action  336530303.0         6.2
# 16     258000000.0    Adventure  336530303.0         6.2
# 17     258000000.0      Romance  336530303.0         6.2
# 18     260000000.0    Adventure  200807262.0         7.8
# 19     260000000.0    Animation  200807262.0         7.8
# 20     260000000.0       Comedy  200807262.0         7.8
# 21     260000000.0       Family  200807262.0         7.8
# 22     260000000.0      Fantasy  200807262.0         7.8
# 23     260000000.0      Musical  200807262.0         7.8
# 24     260000000.0      Romance  200807262.0         7.8
# 25     250000000.0       Action  458991599.0         7.5
# 26     250000000.0    Adventure  458991599.0         7.5
# 27     250000000.0       Sci-Fi  458991599.0         7.5
# 28     250000000.0    Adventure  301956980.0         7.5
# 29     250000000.0       Family  301956980.0         7.5
# ...            ...          ...          ...         ...
# 11512   35000000.0     Thriller   10499968.0         5.7
# 11513      23000.0       Comedy    1227508.0         7.1
# 11514      23000.0        Drama    1227508.0         7.1
# 11515      15000.0       Comedy     192467.0         6.6
# 11516      15000.0        Drama     192467.0         6.6
# 11517      15000.0      Romance     192467.0         6.6
# 11518      15000.0      Romance      76382.0         6.2
# 11519      10000.0       Comedy     180483.0         6.1
# 11520      10000.0        Crime     180483.0         6.1
# 11521      10000.0       Horror     180483.0         6.1
# 11522       4500.0        Drama     136007.0         6.9
# 11523       4500.0        Music     136007.0         6.9
# 11524       4500.0      Romance     136007.0         6.9
# 11525      10000.0        Drama     673780.0         7.5
# 11526    1000000.0        Crime      94596.0         7.4
# 11527    1000000.0       Horror      94596.0         7.4
# 11528    1000000.0      Mystery      94596.0         7.4
# 11529    1000000.0     Thriller      94596.0         7.4
# 11530       7000.0        Drama     424760.0         7.0
# 11531       7000.0       Sci-Fi     424760.0         7.0
# 11532       7000.0     Thriller     424760.0         7.0
# 11533       7000.0     Thriller      70071.0         6.3
# 11534       7000.0       Action    2040920.0         6.9
# 11535       7000.0        Crime    2040920.0         6.9
# 11536       7000.0        Drama    2040920.0         6.9
# 11537       7000.0      Romance    2040920.0         6.9
# 11538       7000.0     Thriller    2040920.0         6.9
# 11539       9000.0       Comedy       4584.0         6.4
# 11540       9000.0        Drama       4584.0         6.4
# 11541       1100.0  Documentary      85222.0         6.6
#
#                                      movie_title  year
# 0                                        Avatar   2009
# 1                                        Avatar   2009
# 2                                        Avatar   2009
# 3                                        Avatar   2009
# 4      Pirates of the Caribbean: At World's End   2007
# 5      Pirates of the Caribbean: At World's End   2007
# 6      Pirates of the Caribbean: At World's End   2007
# 7                                       Spectre   2015
# 8                                       Spectre   2015
# 9                                       Spectre   2015
# 10                        The Dark Knight Rises   2012
# 11                        The Dark Knight Rises   2012
# 12                                  John Carter   2012
# 13                                  John Carter   2012
# 14                                  John Carter   2012
# 15                                 Spider-Man 3   2007
# 16                                 Spider-Man 3   2007
# 17                                 Spider-Man 3   2007
# 18                                      Tangled   2010
# 19                                      Tangled   2010
# 20                                      Tangled   2010
# 21                                      Tangled   2010
# 22                                      Tangled   2010
# 23                                      Tangled   2010
# 24                                      Tangled   2010
# 25                      Avengers: Age of Ultron   2015
# 26                      Avengers: Age of Ultron   2015
# 27                      Avengers: Age of Ultron   2015
# 28       Harry Potter and the Half-Blood Prince   2009
# 29       Harry Potter and the Half-Blood Prince   2009
# ...                                          ...   ...
# 11512                                  Sabotage   2014
# 11513                                   Slacker   1991
# 11514                                   Slacker   1991
# 11515                           The Puffy Chair   2005
# 11516                           The Puffy Chair   2005
# 11517                           The Puffy Chair   2005
# 11518                          Breaking Upwards   2009
# 11519                            Pink Flamingos   1972
# 11520                            Pink Flamingos   1972
# 11521                            Pink Flamingos   1972
# 11522                                     Clean   2004
# 11523                                     Clean   2004
# 11524                                     Clean   2004
# 11525                                The Circle   2000
# 11526                                  The Cure   1997
# 11527                                  The Cure   1997
# 11528                                  The Cure   1997
# 11529                                  The Cure   1997
# 11530                                    Primer   2004
# 11531                                    Primer   2004
# 11532                                    Primer   2004
# 11533                                    Cavite   2005
# 11534                               El Mariachi   1992
# 11535                               El Mariachi   1992
# 11536                               El Mariachi   1992
# 11537                               El Mariachi   1992
# 11538                               El Mariachi   1992
# 11539                                 Newlyweds   2011
# 11540                                 Newlyweds   2011
# 11541                         My Date with Drew   2004
#
# [11542 rows x 6 columns]

# %% [markdown]
# Next we can group by the genre column.  Then look at the imdb score across different genres.

# %%
df_genre.groupby('genre')[['imdb_score']].mean().sort_values('imdb_score').plot.bar()
plt.ylabel('Average Imdb Score')

# %% [markdown]
# ### Exercise 3
# - Which genre has the highest mean budget?
# - When the number of bars becomes larger try to a horizontal plot.

# %%
#### Your code here
df_genre.groupby('genre')[['budget']].mean().sort_values('budget', ascending=False).plot.bar()

# %%
df_genre.head(2)
# Out:
#         budget      genre        gross  imdb_score movie_title  year
# 0  237000000.0     Action  760505847.0         7.9     Avatar   2009
# 1  237000000.0  Adventure  760505847.0         7.9     Avatar   2009

# %%
df_genre.groupby('genre').describe().head(2)
# Out:
#           budget                                                    \
#            count          mean           std       min         25%
# genre
# Action     970.0  7.181674e+07  1.004745e+08    7000.0  26000000.0
# Adventure  795.0  8.627100e+07  1.322741e+08  150000.0  25000000.0
#
#                                                   gross                \
#                   50%          75%           max  count          mean
# genre
# Action     50000000.0   92000000.0  2.127520e+09  970.0  7.714287e+07
# Adventure  60000000.0  125000000.0  2.400000e+09  795.0  9.979846e+07
#
#                                                            ...   imdb_score  \
#                     std     min          25%         50%   ...          std
# genre                                                      ...
# Action     9.144670e+07   162.0  18826787.75  46500000.0   ...     1.038021
# Adventure  1.067465e+08  4091.0  24005442.50  61355436.0   ...     1.109452
#
#                                       year                                  \
#            min  25%   50%  75%  max  count         mean        std     min
# genre
# Action     2.1  5.7  6.35  6.9  9.0  970.0  2003.257732   9.723821  1954.0
# Adventure  2.3  5.8  6.60  7.2  8.9  795.0  2002.732075  11.092349  1939.0
#
#
#               25%     50%     75%     max
# genre
# Action     1998.0  2005.0  2011.0  2016.0
# Adventure  1998.0  2005.0  2011.0  2016.0
#
# [2 rows x 32 columns]

# %%
grouped=df_genre.groupby('genre')

for key, item in grouped:
    print(grouped.get_group(key), "\n\n")
# Out:
#              budget   genre        gross  imdb_score  \
# 0      2.370000e+08  Action  760505847.0         7.9
# 4      3.000000e+08  Action  309404152.0         7.1
# 7      2.450000e+08  Action  200074175.0         6.8
# 10     2.500000e+08  Action  448130642.0         8.5
# 12     2.637000e+08  Action   73058679.0         6.6
# 15     2.580000e+08  Action  336530303.0         6.2
# 25     2.500000e+08  Action  458991599.0         7.5
# 32     2.500000e+08  Action  330249062.0         6.9
# 35     2.090000e+08  Action  200069408.0         6.1
# 38     2.000000e+08  Action  168368427.0         6.7
# 40     2.250000e+08  Action  423032628.0         7.3
# 43     2.150000e+08  Action   89289910.0         6.5
# 46     2.250000e+08  Action  291021565.0         7.2
# 50     2.250000e+08  Action  141614023.0         6.6
# 54     2.200000e+08  Action  623279547.0         8.1
# 57     2.500000e+08  Action  241063875.0         6.7
# 60     2.250000e+08  Action  179020854.0         6.8
# 68     2.300000e+08  Action  262030663.0         7.0
# 71     2.000000e+08  Action  105219735.0         6.7
# 80     2.070000e+08  Action  218051260.0         7.2
# 86     2.500000e+08  Action  407197282.0         8.2
# 89     2.090000e+08  Action   65173160.0         5.9
# 93     1.500000e+08  Action  652177271.0         7.0
# 97     2.000000e+08  Action  304360277.0         7.8
# 100    2.000000e+08  Action  373377893.0         7.3
# 104    2.000000e+08  Action  408992272.0         7.2
# 110    2.100000e+08  Action  234360014.0         6.8
# 120    2.000000e+08  Action  402076689.0         6.0
# 123    2.100000e+08  Action  245428137.0         5.7
# 129    2.000000e+08  Action  202853933.0         6.7
# ...             ...     ...          ...         ...
# 10662  2.000000e+06  Action   24800000.0         7.5
# 10665  2.300000e+06  Action     792966.0         5.1
# 10671  2.000000e+06  Action    9003011.0         7.6
# 10675  2.000000e+06  Action   11546543.0         7.6
# 10704  2.000000e+06  Action    3335839.0         7.0
# 10739  2.000000e+06  Action     124494.0         6.7
# 10754  2.000000e+06  Action       4958.0         7.8
# 10828  2.600000e+07  Action   58885635.0         7.4
# 10834  1.100000e+06  Action   11806119.0         6.8
# 10887  6.000000e+07  Action   80033643.0         7.0
# 10908  6.000000e+07  Action   32940507.0         6.1
# 10967  1.100000e+06  Action    1400000.0         5.9
# 10976  1.100000e+06  Action    4105123.0         7.6
# 10987  1.100000e+06  Action   16067035.0         7.3
# 11001  1.000000e+09  Action   10037390.0         6.0
# 11088  1.000000e+06  Action      96734.0         5.6
# 11097  1.000000e+06  Action      12996.0         6.0
# 11109  1.000000e+06  Action        721.0         4.1
# 11136  1.500000e+07  Action   42919096.0         6.5
# 11159  7.800000e+05  Action    1310270.0         6.8
# 11166  7.500000e+05  Action    5518918.0         6.9
# 11194  2.070000e+08  Action  218051260.0         7.2
# 11209  6.000000e+05  Action     171988.0         5.6
# 11260  2.000000e+06  Action     269061.0         8.7
# 11287  5.000000e+05  Action      21199.0         6.8
# 11343  3.500000e+05  Action    4000000.0         4.7
# 11349  8.000000e+06  Action   16115878.0         6.6
# 11420  2.000000e+05  Action    3500000.0         8.0
# 11509  3.500000e+07  Action   10499968.0         5.7
# 11534  7.000000e+03  Action    2040920.0         6.9
#
#                                              movie_title  year
# 0                                                Avatar   2009
# 4              Pirates of the Caribbean: At World's End   2007
# 7                                               Spectre   2015
# 10                                The Dark Knight Rises   2012
# 12                                          John Carter   2012
# 15                                         Spider-Man 3   2007
# 25                              Avengers: Age of Ultron   2015
# 32                   Batman v Superman: Dawn of Justice   2016
# 35                                     Superman Returns   2006
# 38                                    Quantum of Solace   2008
# 40           Pirates of the Caribbean: Dead Man's Chest   2006
# 43                                      The Lone Ranger   2013
# 46                                         Man of Steel   2013
# 50             The Chronicles of Narnia: Prince Caspian   2008
# 54                                         The Avengers   2012
# 57          Pirates of the Caribbean: On Stranger Tides   2011
# 60                                       Men in Black 3   2012
# 68                               The Amazing Spider-Man   2012
# 71                                           Robin Hood   2010
# 80                                            King Kong   2005
# 86                           Captain America: Civil War   2016
# 89                                           Battleship   2012
# 93                                       Jurassic World   2015
# 97                                              Skyfall   2012
# 100                                        Spider-Man 2   2004
# 104                                          Iron Man 3   2013
# 110                               X-Men: The Last Stand   2006
# 120                 Transformers: Revenge of the Fallen   2009
# 123                     Transformers: Age of Extinction   2014
# 129                            The Amazing Spider-Man 2   2014
# ...                                                  ...   ...
# 10662                             From Russia with Love   1963
# 10665                         The Toxic Avenger Part II   1989
# 10671                       Mad Max 2: The Road Warrior   1981
# 10675                      The Legend of Drunken Master   1994
# 10704                                       Harsh Times   2005
# 10739                                Six-String Samurai   1998
# 10754                   Gangster's Paradise: Jerusalema   2008
# 10828                                  Dawn of the Dead   2004
# 10834                                        Bloodsport   1988
# 10887                                      Jack Reacher   2012
# 10908                                    Mercury Rising   1998
# 10967                        From a Whisper to a Scream   1987
# 10976                              The Raid: Redemption   2011
# 10987                                            Dr. No   1962
# 11001                                     Godzilla 2000   1999
# 11088                                          Hardflip   2012
# 11097                                      The Specials   2000
# 11109                               In Her Line of Fire   2006
# 11136                                            Snitch   2013
# 11159                               Saints and Soldiers   2003
# 11166  Aqua Teen Hunger Force Colon Movie Film for Th...  2007
# 11194                                         King Kong   2005
# 11209                                     Mercy Streets   2000
# 11260                                     Seven Samurai   1954
# 11287          Born to Fly: Elizabeth Streb vs. Gravity   2014
# 11343               American Ninja 2: The Confrontation   1987
# 11349                                      The Prophecy   1995
# 11420                              A Fistful of Dollars   1964
# 11509                                          Sabotage   2014
# 11534                                       El Mariachi   1992
#
# [970 rows x 6 columns]
#
#
#              budget      genre        gross  imdb_score  \
# 1      2.370000e+08  Adventure  760505847.0         7.9
# 5      3.000000e+08  Adventure  309404152.0         7.1
# 8      2.450000e+08  Adventure  200074175.0         6.8
# 13     2.637000e+08  Adventure   73058679.0         6.6
# 16     2.580000e+08  Adventure  336530303.0         6.2
# 18     2.600000e+08  Adventure  200807262.0         7.8
# 26     2.500000e+08  Adventure  458991599.0         7.5
# 28     2.500000e+08  Adventure  301956980.0         7.5
# 33     2.500000e+08  Adventure  330249062.0         6.9
# 36     2.090000e+08  Adventure  200069408.0         6.1
# 39     2.000000e+08  Adventure  168368427.0         6.7
# 41     2.250000e+08  Adventure  423032628.0         7.3
# 44     2.150000e+08  Adventure   89289910.0         6.5
# 47     2.250000e+08  Adventure  291021565.0         7.2
# 51     2.250000e+08  Adventure  141614023.0         6.6
# 55     2.200000e+08  Adventure  623279547.0         8.1
# 58     2.500000e+08  Adventure  241063875.0         6.7
# 61     2.250000e+08  Adventure  179020854.0         6.8
# 66     2.500000e+08  Adventure  255108370.0         7.5
# 69     2.300000e+08  Adventure  262030663.0         7.0
# 72     2.000000e+08  Adventure  105219735.0         6.7
# 75     2.250000e+08  Adventure  258355354.0         7.9
# 77     1.800000e+08  Adventure   70083519.0         6.1
# 81     2.070000e+08  Adventure  218051260.0         7.2
# 87     2.500000e+08  Adventure  407197282.0         8.2
# 90     2.090000e+08  Adventure   65173160.0         5.9
# 94     1.500000e+08  Adventure  652177271.0         7.0
# 98     2.000000e+08  Adventure  304360277.0         7.8
# 101    2.000000e+08  Adventure  373377893.0         7.3
# 105    2.000000e+08  Adventure  408992272.0         7.2
# ...             ...        ...          ...         ...
# 10371  3.000000e+06  Adventure    3293258.0         5.2
# 10421  3.000000e+06  Adventure   51100000.0         7.8
# 10449  3.000000e+06  Adventure   27200000.0         8.2
# 10452  3.000000e+06  Adventure   15369573.0         5.3
# 10536  2.000000e+08  Adventure  334185206.0         6.5
# 10556  2.800000e+06  Adventure   22202612.0         8.1
# 10663  2.000000e+06  Adventure   24800000.0         7.5
# 10672  2.000000e+06  Adventure    9003011.0         7.6
# 10726  2.000000e+06  Adventure    1098224.0         3.3
# 10740  2.000000e+06  Adventure     124494.0         6.7
# 10795  1.800000e+06  Adventure     505295.0         7.5
# 10896  1.400000e+06  Adventure      36830.0         6.6
# 10960  2.600000e+06  Adventure    2850263.0         6.2
# 10988  1.100000e+06  Adventure   16067035.0         7.3
# 11002  1.000000e+09  Adventure   10037390.0         6.0
# 11008  1.000000e+06  Adventure    9013113.0         7.4
# 11015  6.000000e+06  Adventure    7186670.0         5.4
# 11044  5.800000e+07  Adventure   80021740.0         6.4
# 11083  1.000000e+06  Adventure     287761.0         7.6
# 11160  7.800000e+05  Adventure    1310270.0         6.8
# 11167  7.500000e+05  Adventure    5518918.0         6.9
# 11195  2.070000e+08  Adventure  218051260.0         7.2
# 11220  5.000000e+05  Adventure   39552600.0         6.1
# 11223  5.000000e+05  Adventure   30500882.0         5.7
# 11261  2.000000e+06  Adventure     269061.0         8.7
# 11269  1.350000e+08  Adventure  177343675.0         6.7
# 11291  2.150000e+08  Adventure  234903076.0         6.4
# 11320  2.295750e+05  Adventure    1229197.0         8.3
# 11415  2.100000e+05  Adventure    5000000.0         6.7
# 11458  1.500000e+05  Adventure       4914.0         7.0
#
#                                              movie_title  year
# 1                                                Avatar   2009
# 5              Pirates of the Caribbean: At World's End   2007
# 8                                               Spectre   2015
# 13                                          John Carter   2012
# 16                                         Spider-Man 3   2007
# 18                                              Tangled   2010
# 26                              Avengers: Age of Ultron   2015
# 28               Harry Potter and the Half-Blood Prince   2009
# 33                   Batman v Superman: Dawn of Justice   2016
# 36                                     Superman Returns   2006
# 39                                    Quantum of Solace   2008
# 41           Pirates of the Caribbean: Dead Man's Chest   2006
# 44                                      The Lone Ranger   2013
# 47                                         Man of Steel   2013
# 51             The Chronicles of Narnia: Prince Caspian   2008
# 55                                         The Avengers   2012
# 58          Pirates of the Caribbean: On Stranger Tides   2011
# 61                                       Men in Black 3   2012
# 66            The Hobbit: The Battle of the Five Armies   2014
# 69                               The Amazing Spider-Man   2012
# 72                                           Robin Hood   2010
# 75                  The Hobbit: The Desolation of Smaug   2013
# 77                                   The Golden Compass   2007
# 81                                            King Kong   2005
# 87                           Captain America: Civil War   2016
# 90                                           Battleship   2012
# 94                                       Jurassic World   2015
# 98                                              Skyfall   2012
# 101                                        Spider-Man 2   2004
# 105                                          Iron Man 3   2013
# ...                                                  ...   ...
# 10371                                       Pootie Tang   2001
# 10421                                        Goldfinger   1964
# 10449                      The Bridge on the River Kwai   1957
# 10452                                   Spaced Invaders   1990
# 10536                               Alice in Wonderland   2010
# 10556                                  The Wizard of Oz   1939
# 10663                             From Russia with Love   1963
# 10672                       Mad Max 2: The Road Warrior   1981
# 10726   The Book of Mormon Movie, Volume 1: The Journey   2003
# 10740                                Six-String Samurai   1998
# 10795                           Travelers and Magicians   2003
# 10896                             Incident at Loch Ness   2004
# 10960                                          Airborne   1993
# 10988                                            Dr. No   1962
# 11002                                     Godzilla 2000   1999
# 11008                                      Transamerica   2005
# 11015                                 The Green Inferno   2013
# 11044                                        Goosebumps   2015
# 11083                         Antarctica: A Year on Ice   2013
# 11160                               Saints and Soldiers   2003
# 11167  Aqua Teen Hunger Force Colon Movie Film for Th...  2007
# 11195                                         King Kong   2005
# 11220                                             Benji   1974
# 11223                                        Open Water   2003
# 11261                                     Seven Samurai   1954
# 11269                                              Home   2015
# 11291                         Oz the Great and Powerful   2013
# 11320                   Monty Python and the Holy Grail   1975
# 11415                     The Beast from 20,000 Fathoms   1953
# 11458                         Antarctic Edge: 70° South   2015
#
# [795 rows x 6 columns]
#
#
#              budget      genre        gross  imdb_score  \
# 19     2.600000e+08  Animation  200807262.0         7.8
# 116    2.000000e+08  Animation  268488329.0         7.3
# 137    2.000000e+08  Animation  191450875.0         6.3
# 145    2.000000e+08  Animation  414984497.0         8.3
# 186    1.850000e+08  Animation  237282182.0         7.2
# 195    1.800000e+08  Animation  223806889.0         8.4
# 205    2.000000e+08  Animation  137850096.0         6.8
# 227    1.750000e+08  Animation  292979556.0         8.3
# 232    1.750000e+08  Animation  198332128.0         6.5
# 271    1.750000e+08  Animation  356454367.0         8.3
# 304    1.650000e+08  Animation  238371987.0         6.4
# 315    1.650000e+08  Animation  222487711.0         7.9
# 321    1.650000e+08  Animation  189412677.0         7.8
# 326    1.650000e+08  Animation     665426.0         6.6
# 333    1.650000e+08  Animation  217387997.0         8.2
# 373    1.600000e+08  Animation  320706665.0         6.1
# 418    1.500000e+08  Animation  206435493.0         8.0
# 426    1.500000e+08  Animation  179982968.0         6.7
# 441    1.500000e+08  Animation  400736600.0         7.6
# 461    1.500000e+08  Animation  114053579.0         6.9
# 467    1.500000e+08  Animation  119420252.0         5.1
# 490    1.500000e+08  Animation  126597121.0         6.2
# 495    1.500000e+08  Animation  165230261.0         7.3
# 510    1.500000e+08  Animation   21379315.0         5.4
# 515    1.490000e+08  Animation   64459316.0         6.7
# 522    1.450000e+08  Animation  111505642.0         6.9
# 528    1.450000e+08  Animation  216366733.0         6.9
# 551    1.500000e+08  Animation   82161969.0         6.3
# 555    1.450000e+08  Animation  143523463.0         7.2
# 562    1.450000e+08  Animation  103400692.0         7.3
# ...             ...        ...          ...         ...
# 6862   2.000000e+07  Animation   18081626.0         6.4
# 6985   2.000000e+07  Animation    7382993.0         2.8
# 7014   8.700000e+06  Animation    5480996.0         7.1
# 7052   2.400000e+09  Animation    2298191.0         8.4
# 7089   2.127520e+09  Animation     410388.0         6.9
# 7164   1.900000e+07  Animation   10049886.0         8.6
# 7390   1.400000e+07  Animation      63260.0         6.7
# 7399   1.750000e+07  Animation   51053787.0         6.5
# 7907   1.500000e+07  Animation   12701880.0         5.7
# 8104   1.400000e+07  Animation   25571351.0         6.6
# 8410   1.250000e+07  Animation   48092846.0         7.3
# 8424   9.600000e+06  Animation      71442.0         7.9
# 8458   1.200000e+07  Animation   63071133.0         6.8
# 8632   1.350000e+08  Animation  177343675.0         6.7
# 8817   2.300000e+07  Animation   36696761.0         6.5
# 8920   3.000000e+06  Animation   13684949.0         5.9
# 8973   1.000000e+07  Animation    6491350.0         5.8
# 9348   8.000000e+06  Animation    3442820.0         7.3
# 9378   6.500000e+06  Animation     686383.0         7.7
# 9414   1.100000e+09  Animation     439162.0         8.1
# 9467   7.300000e+06  Animation    4443403.0         8.0
# 9980   5.000000e+06  Animation   19421271.0         5.0
# 10044  5.000000e+06  Animation    9628751.0         5.9
# 10644  2.280000e+06  Animation   76400000.0         7.8
# 10688  9.500000e+06  Animation    7002255.0         7.8
# 10720  1.500000e+06  Animation    2283276.0         8.0
# 10891  2.000000e+06  Animation  184925485.0         7.7
# 11168  7.500000e+05  Animation    5518918.0         6.9
# 11270  1.350000e+08  Animation  177343675.0         6.7
# 11398  2.500000e+05  Animation     203134.0         7.0
#
#                                              movie_title  year
# 19                                              Tangled   2010
# 116                                 Monsters University   2013
# 137                                              Cars 2   2011
# 145                                         Toy Story 3   2010
# 186                                               Brave   2012
# 195                                              WALL·E   2008
# 205                                   A Christmas Carol   2009
# 227                                                  Up   2009
# 232                                 Monsters vs. Aliens   2009
# 271                                          Inside Out   2015
# 304                                 Shrek Forever After   2010
# 315                                          Big Hero 6   2014
# 321                                      Wreck-It Ralph   2012
# 326                                   The Polar Express   2004
# 333                            How to Train Your Dragon   2010
# 373                                     Shrek the Third   2007
# 418                                         Ratatouille   2007
# 426                         Madagascar: Escape 2 Africa   2008
# 441                                              Frozen   2013
# 461                                                Bolt   2008
# 467                                             G-Force   2009
# 490                                           Bee Movie   2007
# 495                                     Kung Fu Panda 2   2011
# 510                                     Mars Needs Moms   2011
# 515                                        Flushed Away   2006
# 522                               Mr. Peabody & Sherman   2014
# 528                  Madagascar 3: Europe's Most Wanted   2012
# 551                                             Beowulf   2007
# 555                                     Kung Fu Panda 3   2016
# 562                               Rise of the Guardians   2012
# ...                                                  ...   ...
# 6862                             Pooh's Heffalump Movie   2005
# 6985                                             Doogal   2006
# 7014                                   A Scanner Darkly   2006
# 7052                                  Princess Mononoke   1997
# 7089                                           Steamboy   2004
# 7164                                      Spirited Away   2001
# 7390                                        Renaissance   2006
# 7399                                        Hoodwinked!   2005
# 7907   The Pirates Who Don't Do Anything: A VeggieTal...  2008
# 8104                         Jonah: A VeggieTales Movie   2002
# 8410                               The Land Before Time   1988
# 8424                                 Ernest & Celestine   2012
# 8458                    Beavis and Butt-Head Do America   1996
# 8632                                               Home   2015
# 8817                               Recess: School's Out   2001
# 8920                              Hey Arnold! The Movie   2002
# 8973                                      Teacher's Pet   2004
# 9348                                          Anomalisa   2015
# 9378                                The Secret of Kells   2009
# 9414                                              Akira   1988
# 9467                                         Persepolis   2007
# 9980                                   Doug's 1st Movie   1999
# 10044                                Digimon: The Movie   2000
# 10644                                          Fantasia   1940
# 10688                        The Triplets of Belleville   2003
# 10720                                 Waltz with Bashir   2008
# 10891                   Snow White and the Seven Dwarfs   1937
# 11168  Aqua Teen Hunger Force Colon Movie Film for Th...  2007
# 11270                                              Home   2015
# 11398                       I Married a Strange Person!   1997
#
# [199 rows x 6 columns]
#
#
#             budget      genre        gross  imdb_score  \
# 396    155000000.0  Biography   34293771.0         5.5
# 917    110000000.0  Biography  102608827.0         7.5
# 972    107000000.0  Biography   58183966.0         6.8
# 1030   100000000.0  Biography   97030725.0         7.0
# 1035   100000000.0  Biography  130127620.0         7.8
# 1098   100000000.0  Biography  116866727.0         8.2
# 1141   100000000.0  Biography   24985612.0         7.0
# 1405    88000000.0  Biography   61644321.0         8.0
# 1791    58000000.0  Biography  170708996.0         8.2
# 1899    75000000.0  Biography   66636385.0         7.1
# 2012    72000000.0  Biography   75600000.0         8.4
# 2136    70000000.0  Biography   37901509.0         7.0
# 2239    68000000.0  Biography   28965197.0         7.9
# 2278    65000000.0  Biography  182204440.0         7.4
# 2307    65000000.0  Biography  115603980.0         7.2
# 2397    55000000.0  Biography   43247140.0         7.1
# 2417    63000000.0  Biography   25052000.0         6.6
# 2491    70000000.0  Biography  101217900.0         7.0
# 2615    60000000.0  Biography   56443482.0         6.6
# 2659    60000000.0  Biography   37479778.0         7.4
# 2704    60000000.0  Biography   31670931.0         6.7
# 2805    58800000.0  Biography  350123553.0         7.3
# 2900    55000000.0  Biography  107100855.0         7.9
# 2920    55000000.0  Biography  162586036.0         8.0
# 2963    55000000.0  Biography   49994804.0         6.3
# 3011    55000000.0  Biography   16264475.0         6.9
# 3085    53000000.0  Biography   62563543.0         7.0
# 3103    52000000.0  Biography  164435221.0         8.0
# 3125    52000000.0  Biography   34580635.0         7.4
# 3128    52000000.0  Biography   42438300.0         8.2
# ...            ...        ...          ...         ...
# 9882     5500000.0  Biography   35811509.0         7.7
# 9891     5500000.0  Biography    1292119.0         7.1
# 9955     4500000.0  Biography   34468224.0         7.3
# 9962     5000000.0  Biography   27296514.0         8.0
# 10072    5000000.0  Biography    3049135.0         7.4
# 10089    5000000.0  Biography    2445646.0         7.0
# 10095    5000000.0  Biography     296665.0         6.3
# 10308    4000000.0  Biography      12836.0         5.8
# 10319    4000000.0  Biography     143653.0         6.0
# 10324    3768785.0  Biography    8000000.0         7.0
# 10361    3500000.0  Biography    6390032.0         7.5
# 10391    3500000.0  Biography     123777.0         4.7
# 10398    3500000.0  Biography    5354039.0         7.1
# 10440    3000000.0  Biography   19184015.0         5.4
# 10492    3300000.0  Biography    2961991.0         6.9
# 10677    2000000.0  Biography   11533945.0         7.6
# 10721    1500000.0  Biography    2283276.0         8.0
# 10733    2000000.0  Biography     653621.0         6.8
# 10778    1000000.0  Biography    2957978.0         7.8
# 10835    1100000.0  Biography   11806119.0         6.8
# 11017    1000000.0  Biography    5997134.0         7.2
# 11074    1000000.0  Biography     484221.0         8.2
# 11084    1000000.0  Biography     287761.0         7.6
# 11127     900000.0  Biography   16097842.0         7.5
# 11224     500000.0  Biography   30500882.0         5.7
# 11233     500000.0  Biography    2047570.0         7.6
# 11288     500000.0  Biography      21199.0         6.8
# 11328        218.0  Biography     592014.0         7.2
# 11372     270000.0  Biography     318622.0         6.4
# 11485      60000.0  Biography     536767.0         5.3
#
#                                      movie_title  year
# 396                                   Alexander   2004
# 917                                 The Aviator   2004
# 972                                         Ali   2001
# 1030                             Public Enemies   2009
# 1035                          American Gangster   2007
# 1098                    The Wolf of Wall Street   2013
# 1141                    In the Heart of the Sea   2015
# 1405                             Cinderella Man   2005
# 1791                           A Beautiful Mind   2001
# 1899                       Charlie Wilson's War   2007
# 2012                                 Braveheart   1995
# 2136                       Seven Years in Tibet   1997
# 2239                                The Insider   1999
# 2278                                    Lincoln   2012
# 2307                                   Unbroken   2014
# 2397                                    Everest   2015
# 2417                                 Wyatt Earp   1994
# 2491                        The Prince of Egypt   1998
# 2615                                        Joy   2015
# 2659                                   Invictus   2009
# 2704                                The Soloist   2009
# 2805                            American Sniper   2014
# 2900                           Captain Phillips   2013
# 2920                   The Pursuit of Happyness   2006
# 2963                                      Evita   1996
# 3011                  Elizabeth: The Golden Age   2007
# 3085                                 Black Mass   2015
# 3103                        Catch Me If You Can   2002
# 3125                            Man on the Moon   1999
# 3128                                     Casino   1995
# ...                                          ...   ...
# 9882                                      Shine   1996
# 9891                                       Iris   2001
# 9955                                    Monster   2003
# 9962                         Dallas Buyers Club   2013
# 10072                        Heavenly Creatures   1994
# 10089                        Kill the Messenger   2014
# 10095                             Party Monster   2003
# 10308         The Last Time I Committed Suicide   1997
# 10319                             Desert Dancer   2014
# 10324                        Annie Get Your Gun   1950
# 10361                         Gods and Monsters   1998
# 10391                          The Masked Saint   2016
# 10398                               Margin Call   2011
# 10440           Martin Lawrence Live: Runteldat   2002
# 10492                                  Basquiat   1996
# 10677                            Boys Don't Cry   1999
# 10721                         Waltz with Bashir   2008
# 10733                        Inside Deep Throat   2005
# 10778                               Man on Wire   2008
# 10835                                Bloodsport   1988
# 11017                              The Sessions   2012
# 11074                        The Act of Killing   2012
# 11084                 Antarctica: A Year on Ice   2013
# 11127                         Fruitvale Station   2013
# 11224                                Open Water   2003
# 11233                            Beyond the Mat   1999
# 11288  Born to Fly: Elizabeth Streb vs. Gravity   2014
# 11328                                 Tarnation   2003
# 11372                                Compliance   2012
# 11485                                  20 Dates   1998
#
# [244 rows x 6 columns]
#
#
#             budget   genre        gross  imdb_score  \
# 20     260000000.0  Comedy  200807262.0         7.8
# 62     225000000.0  Comedy  179020854.0         6.8
# 117    200000000.0  Comedy  268488329.0         7.3
# 138    200000000.0  Comedy  191450875.0         6.3
# 146    200000000.0  Comedy  414984497.0         8.3
# 187    185000000.0  Comedy  237282182.0         7.2
# 199    140000000.0  Comedy  140080850.0         6.2
# 228    175000000.0  Comedy  292979556.0         8.3
# 233    175000000.0  Comedy  198332128.0         6.5
# 244    170000000.0  Comedy  113745408.0         4.8
# 254    175000000.0  Comedy  161087183.0         6.9
# 256    175000000.0  Comedy  100289690.0         5.4
# 272    175000000.0  Comedy  356454367.0         8.3
# 305    165000000.0  Comedy  238371987.0         6.4
# 316    165000000.0  Comedy  222487711.0         7.9
# 322    165000000.0  Comedy  189412677.0         7.8
# 374    160000000.0  Comedy  320706665.0         6.1
# 415    150000000.0  Comedy  206456431.0         6.7
# 419    150000000.0  Comedy  206435493.0         8.0
# 427    150000000.0  Comedy  179982968.0         6.7
# 430    150000000.0  Comedy  177243721.0         5.9
# 442    150000000.0  Comedy  400736600.0         7.6
# 462    150000000.0  Comedy  114053579.0         6.9
# 468    150000000.0  Comedy  119420252.0         5.1
# 475    100000000.0  Comedy   79711678.0         6.2
# 491    150000000.0  Comedy  126597121.0         6.2
# 496    150000000.0  Comedy  165230261.0         7.3
# 511    150000000.0  Comedy   21379315.0         5.4
# 516    149000000.0  Comedy   64459316.0         6.7
# 523    145000000.0  Comedy  111505642.0         6.9
# ...            ...     ...          ...         ...
# 11356     300000.0  Comedy    2360184.0         7.1
# 11376     250000.0  Comedy   12006514.0         7.3
# 11379     250000.0  Comedy    4186931.0         6.9
# 11385     250000.0  Comedy    1977544.0         6.5
# 11388     250000.0  Comedy    1050600.0         6.6
# 11390     250000.0  Comedy     902835.0         6.7
# 11396     250000.0  Comedy     212285.0         6.4
# 11399     250000.0  Comedy     203134.0         7.0
# 11408     250000.0  Comedy     177840.0         6.1
# 11418     200000.0  Comedy    4505922.0         7.4
# 11440     175000.0  Comedy    7137502.0         6.5
# 11448     150000.0  Comedy    2882062.0         6.3
# 11454    1200000.0  Comedy     110720.0         7.3
# 11462     125000.0  Comedy    1573712.0         6.7
# 11470     100000.0  Comedy    5228617.0         7.0
# 11471      40000.0  Comedy     110536.0         7.0
# 11474     200000.0  Comedy      59379.0         6.8
# 11486      60000.0  Comedy     536767.0         5.3
# 11488      65000.0  Comedy   11529368.0         7.3
# 11491      60000.0  Comedy      40557.0         5.6
# 11492      70000.0  Comedy      30084.0         5.6
# 11494      25000.0  Comedy   10246600.0         6.6
# 11497      65000.0  Comedy     389804.0         6.3
# 11501      40000.0  Comedy     277233.0         7.6
# 11504     230000.0  Comedy    3151130.0         7.8
# 11507      25000.0  Comedy    2856622.0         7.3
# 11513      23000.0  Comedy    1227508.0         7.1
# 11515      15000.0  Comedy     192467.0         6.6
# 11519      10000.0  Comedy     180483.0         6.1
# 11539       9000.0  Comedy       4584.0         6.4
#
#                                              movie_title  year
# 20                                              Tangled   2010
# 62                                       Men in Black 3   2012
# 117                                 Monsters University   2013
# 138                                              Cars 2   2011
# 146                                         Toy Story 3   2010
# 187                                               Brave   2012
# 199                                         Rush Hour 3   2007
# 228                                                  Up   2009
# 233                                 Monsters vs. Aliens   2009
# 244                                      Wild Wild West   1999
# 254                                       Suicide Squad   2016
# 256                                       Evan Almighty   2007
# 272                                          Inside Out   2015
# 305                                 Shrek Forever After   2010
# 316                                          Big Hero 6   2014
# 322                                      Wreck-It Ralph   2012
# 374                                     Shrek the Third   2007
# 415                   Charlie and the Chocolate Factory   2005
# 419                                         Ratatouille   2007
# 427                         Madagascar: Escape 2 Africa   2008
# 430      Night at the Museum: Battle of the Smithsonian   2009
# 442                                              Frozen   2013
# 462                                                Bolt   2008
# 468                                             G-Force   2009
# 475                                        Dark Shadows   2012
# 491                                           Bee Movie   2007
# 496                                     Kung Fu Panda 2   2011
# 511                                     Mars Needs Moms   2011
# 516                                        Flushed Away   2006
# 523                               Mr. Peabody & Sherman   2014
# ...                                                  ...   ...
# 11356                                   Pieces of April   2003
# 11376                                       Chasing Amy   1997
# 11379                                  Lovely & Amazing   2001
# 11385  The Incredibly True Adventure of Two Girls in ...  1995
# 11388                                      Chuck & Buck   2000
# 11390                                     American Desi   2001
# 11396                       Love and Other Catastrophes   1996
# 11399                       I Married a Strange Person!   1997
# 11408                                        Sugar Town   1999
# 11418                                          Swingers   1996
# 11440                               She's Gotta Have It   1986
# 11448                                           Tadpole   2000
# 11454                                  The Woman Chaser   1999
# 11462                              Your Sister's Sister   2011
# 11470                                 Hollywood Shuffle   1987
# 11471                      The Lost Skeleton of Cadavra   2001
# 11474                                     Cheap Thrills   2013
# 11486                                          20 Dates   1998
# 11488                                     Super Size Me   2004
# 11491                                            The FP   2011
# 11492                                   Happy Christmas   2014
# 11494                             The Brothers McMullen   1995
# 11497                                    Tiny Furniture   2010
# 11501                       Smiling Fish & Goat on Fire   1999
# 11504                                            Clerks   1994
# 11507                             In the Company of Men   1997
# 11513                                           Slacker   1991
# 11515                                   The Puffy Chair   2005
# 11519                                    Pink Flamingos   1972
# 11539                                         Newlyweds   2011
#
# [1511 rows x 6 columns]
#
#
#             budget  genre        gross  imdb_score  \
# 153    190000000.0  Crime  350034110.0         7.2
# 200    140000000.0  Crime  140080850.0         6.2
# 223    185000000.0  Crime  533316061.0         9.0
# 351     38000000.0  Crime  144512310.0         6.7
# 566    100000000.0  Crime  110332737.0         6.1
# 599    140000000.0  Crime  129734803.0         6.6
# 690    130000000.0  Crime  138396624.0         6.6
# 699    110000000.0  Crime  118311368.0         6.4
# 758    125000000.0  Crime  209805005.0         7.3
# 762    125000000.0  Crime  186830669.0         7.5
# 806    120000000.0  Crime  100685880.0         4.8
# 824    100000000.0  Crime   58607007.0         6.2
# 907    110000000.0  Crime  125531634.0         6.4
# 911    120000000.0  Crime  186336103.0         6.5
# 925    120000000.0  Crime   98780042.0         5.8
# 957    160000000.0  Crime   48068396.0         3.7
# 1008    90000000.0  Crime  101643008.0         6.5
# 1031   100000000.0  Crime   97030725.0         7.0
# 1036   100000000.0  Crime  130127620.0         7.8
# 1042   100000000.0  Crime   65452312.0         6.4
# 1048   100000000.0  Crime  119219978.0         6.7
# 1100   100000000.0  Crime  116866727.0         8.2
# 1116   100000000.0  Crime   40198710.0         3.3
# 1133   105000000.0  Crime   28772222.0         5.3
# 1163   100000000.0  Crime   77679638.0         7.5
# 1267    90000000.0  Crime  226138454.0         6.6
# 1291    92000000.0  Crime  125305545.0         5.5
# 1293    90000000.0  Crime  132373442.0         8.5
# 1304    90000000.0  Crime  102515793.0         7.8
# 1313    90000000.0  Crime  209019489.0         7.6
# ...            ...    ...          ...         ...
# 11075    1000000.0  Crime     484221.0         8.2
# 11078    1000000.0  Crime     274661.0         7.7
# 11093     500000.0  Crime      48430.0         6.8
# 11096    1000000.0  Crime      21210.0         6.1
# 11101    1000000.0  Crime      10018.0         6.1
# 11113   20000000.0  Crime    2319187.0         7.0
# 11117     910000.0  Crime    9600000.0         8.2
# 11122     950000.0  Crime    1007962.0         7.1
# 11175     500000.0  Crime      26297.0         6.3
# 11185     900000.0  Crime      18378.0         5.2
# 11192     700000.0  Crime    1141829.0         7.2
# 11210     600000.0  Crime     171988.0         5.6
# 11244     500000.0  Crime    1111615.0         6.0
# 11247     500000.0  Crime     603943.0         7.3
# 11249     500000.0  Crime     334041.0         6.5
# 11254     500000.0  Crime     243347.0         5.3
# 11294     450000.0  Crime    2712293.0         5.9
# 11316    1066167.0  Crime     258113.0         7.1
# 11373     270000.0  Crime     318622.0         6.4
# 11382     250000.0  Crime    3799339.0         7.2
# 11431   30000000.0  Crime   32154410.0         7.1
# 11434     200000.0  Crime       1111.0         7.7
# 11445     500000.0  Crime   15180000.0         5.5
# 11468     100000.0  Crime    3000000.0         4.8
# 11475     200000.0  Crime      59379.0         6.8
# 11479   15000000.0  Crime   32721635.0         6.6
# 11510   35000000.0  Crime   10499968.0         5.7
# 11520      10000.0  Crime     180483.0         6.1
# 11526    1000000.0  Crime      94596.0         7.4
# 11535       7000.0  Crime    2040920.0         6.9
#
#                                movie_title  year
# 153                             Furious 7   2015
# 200                           Rush Hour 3   2007
# 223                       The Dark Knight   2008
# 351              The Fast and the Furious   2001
# 566                Fun with Dick and Jane   2005
# 599                       Lethal Weapon 4   1998
# 690                           Bad Boys II   2003
# 699                                  Salt   2010
# 758                             Fast Five   2011
# 762    Sherlock Holmes: A Game of Shadows   2011
# 806       Charlie's Angels: Full Throttle   2003
# 824                               RoboCop   2014
# 907                        Ocean's Twelve   2004
# 911                      Mr. & Mrs. Smith   2005
# 925                      The Green Hornet   2011
# 957               Speed 2: Cruise Control   1997
# 1008                Gone in Sixty Seconds   2000
# 1031                       Public Enemies   2009
# 1036                    American Gangster   2007
# 1042           The Taking of Pelham 1 2 3   2009
# 1048                       The Other Guys   2010
# 1100              The Wolf of Wall Street   2013
# 1116                             Catwoman   2004
# 1133                          Point Break   2015
# 1163                    Gangs of New York   2002
# 1267                          Rush Hour 2   2001
# 1291                     Charlie's Angels   2000
# 1293                         The Departed   2006
# 1304      The Girl with the Dragon Tattoo   2011
# 1313                      Sherlock Holmes   2009
# ...                                    ...   ...
# 11075                  The Act of Killing   2012
# 11078               Taxi to the Dark Side   2007
# 11093                    The Perfect Host   2010
# 11096                            Safe Men   1998
# 11101                      Alone with Her   2006
# 11113                              Trance   2013
# 11117                   On the Waterfront   1954
# 11122                          Hard Candy   2005
# 11175                           Kill List   2011
# 11185                        Donkey Punch   2008
# 11192                              L.I.E.   2001
# 11210                       Mercy Streets   2000
# 11244                            The R.M.   2003
# 11247                          Mean Creek   2004
# 11249                   Hurricane Streets   1997
# 11254                         Civil Brand   2002
# 11294            Straight Out of Brooklyn   1991
# 11316                           Blue Ruin   2013
# 11373                          Compliance   2012
# 11382                Better Luck Tomorrow   2002
# 11431                        Side Effects   2013
# 11434           The Trials of Darryl Hunt   2006
# 11445   Sweet Sweetback's Baadasssss Song   1971
# 11468      Over the Hill to the Poorhouse   1920
# 11475                       Cheap Thrills   2013
# 11479          The Last House on the Left   2009
# 11510                            Sabotage   2014
# 11520                      Pink Flamingos   1972
# 11526                            The Cure   1997
# 11535                         El Mariachi   1992
#
# [720 rows x 6 columns]
#
#
#             budget        genre        gross  imdb_score  \
# 1779    40000000.0  Documentary   19406406.0         7.8
# 2558    60000000.0  Documentary   71844424.0         7.3
# 5608   160000000.0  Documentary   10762178.0         8.0
# 6612    20000000.0  Documentary  117224271.0         7.1
# 8213    13000000.0  Documentary   73000942.0         1.6
# 8500    12000000.0  Documentary   25240988.0         5.9
# 8917    10000000.0  Documentary   28873374.0         4.1
# 9163     9000000.0  Documentary   24530513.0         8.0
# 9201     9000000.0  Documentary   11860839.0         5.4
# 9716     6000000.0  Documentary  119078393.0         7.5
# 9786     6000000.0  Documentary    7518876.0         6.5
# 9935     5000000.0  Documentary   64267897.0         6.6
# 10067    5000000.0  Documentary    4074023.0         6.9
# 10263    8000000.0  Documentary    3713002.0         2.7
# 10275    4000000.0  Documentary    2601847.0         8.5
# 10396    3500000.0  Documentary      29233.0         7.0
# 10397    8000000.0  Documentary   77413017.0         7.6
# 10425    3000000.0  Documentary   38168022.0         6.6
# 10429    4000000.0  Documentary   21244913.0         8.0
# 10442    3000000.0  Documentary   19184015.0         5.4
# 10459    3000000.0  Documentary   11694528.0         7.2
# 10499    3000000.0  Documentary    2223990.0         6.6
# 10547    3000000.0  Documentary     100675.0         6.4
# 10580    2500000.0  Documentary   33349949.0         5.1
# 10589    2500000.0  Documentary   32230907.0         6.7
# 10612    2500000.0  Documentary   12995673.0         7.7
# 10614    2500000.0  Documentary     173783.0         7.6
# 10621    2500000.0  Documentary      99851.0         7.1
# 10722    1500000.0  Documentary    2283276.0         8.0
# 10727    2000000.0  Documentary    1430185.0         8.3
# ...            ...          ...          ...         ...
# 11039    1000000.0  Documentary    1677838.0         7.7
# 11076    1000000.0  Documentary     484221.0         8.2
# 11079    1000000.0  Documentary     274661.0         7.7
# 11081    1000000.0  Documentary     144431.0         7.3
# 11085    1000000.0  Documentary     287761.0         7.6
# 11087    1000000.0  Documentary     100240.0         6.8
# 11189     700000.0  Documentary    7830611.0         8.3
# 11206     600000.0  Documentary   13300000.0         8.1
# 11217     560000.0  Documentary       2245.0         7.2
# 11234     500000.0  Documentary    2047570.0         7.6
# 11240     500000.0  Documentary     906666.0         6.8
# 11259     500000.0  Documentary     151389.0         7.1
# 11263     500000.0  Documentary     133778.0         8.4
# 11289     500000.0  Documentary      21199.0         6.8
# 11329        218.0  Documentary     592014.0         7.2
# 11330     400000.0  Documentary     425899.0         5.1
# 11334     375000.0  Documentary     617172.0         7.0
# 11339     450000.0  Documentary      34151.0         7.2
# 11341    1750211.0  Documentary    1523883.0         7.8
# 11360     300000.0  Documentary      16892.0         7.6
# 11413     225000.0  Documentary     111300.0         7.5
# 11423     200000.0  Documentary     381225.0         7.2
# 11428     200000.0  Documentary     215185.0         7.5
# 11435     200000.0  Documentary       1111.0         7.7
# 11455     160000.0  Documentary     155984.0         7.4
# 11459     150000.0  Documentary       4914.0         7.0
# 11460     150000.0  Documentary       5858.0         7.1
# 11461     160000.0  Documentary    6706368.0         7.5
# 11489      65000.0  Documentary   11529368.0         7.3
# 11541       1100.0  Documentary      85222.0         6.6
#
#                                              movie_title  year
# 1779                                             Oceans   2009
# ...
# 11318                              Blue Ruin   2013
# 11338                                 Maniac   2012
# 11346                              Halloween   1978
# 11353                           The Prophecy   1995
# 11371                              Locker 13   2014
# 11375                             Compliance   2012
# 11395                                   Cube   1997
# 11405                               November   2004
# 11411                            The Canyons   2013
# 11433                           Side Effects   2013
# 11447      Sweet Sweetback's Baadasssss Song   1971
# 11457           The Texas Chain Saw Massacre   1974
# 11467                            The Gallows   2015
# 11478                          Cheap Thrills   2013
# 11481             The Last House on the Left   2009
# 11484                                     Pi   1998
# 11512                               Sabotage   2014
# 11529                               The Cure   1997
# 11532                                 Primer   2004
# 11533                                 Cavite   2005
# 11538                            El Mariachi   1992
#
# [1130 rows x 6 columns]
#
#
#             budget genre        gross  imdb_score  \
# 390    140000000.0   War  198539855.0         6.1
# 400    155000000.0   War   34293771.0         5.5
# 570    140000000.0   War  111110575.0         7.7
# 627    150000000.0   War   93926386.0         7.4
# 716    130000000.0   War   49551662.0         6.6
# 868    115000000.0   War   40911830.0         6.0
# 906    110000000.0   War  113330342.0         7.1
# 931    110000000.0   War  106369117.0         6.2
# 987    130000000.0   War   47396698.0         7.2
# 1107   105000000.0   War   54700065.0         7.2
# 1151   100000000.0   War   35024475.0         6.9
# 1168    94000000.0   War       9213.0         7.6
# 1178    92000000.0   War  108638745.0         7.7
# 1241   107000000.0   War   22406362.0         6.0
# 1301    90000000.0   War  120618403.0         7.5
# 1331    75000000.0   War   83077470.0         7.1
# 1399   100000000.0   War   35168677.0         6.7
# 1483    68000000.0   War   51396781.0         7.6
# 1638    79000000.0   War   95632614.0         7.2
# 1672    68000000.0   War   85707116.0         7.6
# 1919    70000000.0   War   43426961.0         6.6
# 2015    72000000.0   War   75600000.0         8.4
# 2018    70000000.0   War   62647540.0         7.1
# 2065    75000000.0   War  120523073.0         8.3
# 2099    75000000.0   War   78120196.0         7.1
# 2116    66000000.0   War   79883359.0         7.2
# 2118    70000000.0   War   78031620.0         6.1
# 2128    70000000.0   War   55942830.0         6.3
# 2139    70000000.0   War   37901509.0         7.0
# 2162    60000000.0   War   19076815.0         6.3
# ...            ...   ...          ...         ...
# 8770    10818775.0   War    5669081.0         6.6
# 8776    10000000.0   War   85300000.0         6.9
# 8996    10000000.0   War    5484375.0         7.3
# 9094    10000000.0   War     169379.0         6.2
# 9131     6000000.0   War    2600000.0         7.5
# 9185     9000000.0   War   10161099.0         7.7
# 9207   400000000.0   War     454255.0         6.6
# 9216    45000000.0   War     145109.0         7.3
# 9470     7300000.0   War    4443403.0         8.0
# 9615     9000000.0   War    1000000.0         6.3
# 9641    15000000.0   War     927107.0         7.3
# 9651     6800000.0   War    6857096.0         8.2
# 9699     6500000.0   War      66637.0         7.2
# 9715     6000000.0   War  137963328.0         8.1
# 9718     6000000.0   War  119078393.0         7.5
# 9859     4000000.0   War     542860.0         7.1
# 10119    5000000.0   War      65087.0         6.2
# 10129   84450000.0   War     617228.0         7.4
# 10318    3977000.0   War  198655278.0         8.2
# 10322    3800000.0   War      14873.0         6.8
# 10451    3000000.0   War   27200000.0         8.2
# 10528    3000000.0   War      73678.0         5.9
# 10613    2500000.0   War   12995673.0         7.7
# 10657    2100000.0   War   23650000.0         8.1
# 10725    1500000.0   War    2283276.0         8.0
# 10728    2000000.0   War    1430185.0         8.3
# 10879    1700000.0   War     183490.0         5.8
# 11080    1000000.0   War     274661.0         7.7
# 11162     780000.0   War    1310270.0         6.8
# 11298    2000000.0   War     768045.0         7.7
#
#                                             movie_title  year
# 390                                       Pearl Harbor   2001
# 400                                          Alexander   2004
# 570                                   The Last Samurai   2003
# 627    Master and Commander: The Far Side of the World   2003
# 716                                          Australia   2008
# 868                                        Windtalkers   2002
# 906                                        The Patriot   2000
# 931                             300: Rise of an Empire   2014
# 987                                  Kingdom of Heaven   2005
# 1107                                 Starship Troopers   1997
# 1151                                        Green Zone   2010
# 1168                                The Flowers of War   2011
# 1178                                   Black Hawk Down   2001
# 1241                                         The Alamo   2004
# 1301                                             Mulan   1998
# 1331                                          Valkyrie   2008
# 1399                              K-19: The Widowmaker   2002
# 1483                                Enemy at the Gates   2001
# 1638                                     Cold Mountain   2003
# 1672                                              Fury   2014
# 1919                                  Tears of the Sun   2003
# 2015                                        Braveheart   1995
# 2018                                           Jarhead   2005
# 2065                              Inglourious Basterds   2009
# 2099                                  We Were Soldiers   2002
# 2116                                         War Horse   2011
# 2118                                 The Monuments Men   2014
# 2128                                    Dracula Untold   2014
# 2139                              Seven Years in Tibet   1997
# 2162                                        Hart's War   2002
# ...                                                 ...   ...
# 8770    For Greater Glory: The True Story of Cristiada   2012
# 8776                                           Stripes   1981
# 8996                                       Rescue Dawn   2006
# 9094                         Cinco de Mayo, La Batalla   2013
# 9131                                       Richard III   1995
# 9185                                           Henry V   1989
# 9207                          The Legend of Suriyothai   2001
# 9216                                  Flame and Citron   2008
# 9470                                        Persepolis   2007
# 9615                                      March or Die   1977
# 9641                                    Aimee & Jaguar   1999
# 9651                                         Incendies   2010
# 9699                                     The Messenger   2009
# 9715                                           Platoon   1986
# 9718                                   Fahrenheit 9/11   2004
# 9859                                 Winter in Wartime   2008
# 10119                                         Redacted   2007
# 10129                     I Served the King of England   2006
# 10318                               Gone with the Wind   1939
# 10322                                     Major Dundee   1965
# 10451                     The Bridge on the River Kwai   1957
# 10528                                       Fort McCoy   2011
# 10613                                       Religulous   2008
# 10657                      The Best Years of Our Lives   1946
# 10725                                Waltz with Bashir   2008
# 10728                                  No End in Sight   2007
# 10879                                            Amigo   2010
# 11080                            Taxi to the Dark Side   2007
# 11162                              Saints and Soldiers   2003
# 11298                                    Bloody Sunday   2002
#
# [162 rows x 6 columns]
#
#
#             budget    genre        gross  imdb_score  \
# 45     215000000.0  Western   89289910.0         6.5
# 246    170000000.0  Western  113745408.0         4.8
# 645    135000000.0  Western  183635922.0         8.1
# 655    135000000.0  Western  123207194.0         7.2
# 941    110000000.0  Western   50026353.0         5.4
# 1054   100000000.0  Western  162804648.0         8.5
# 1242   107000000.0  Western   22406362.0         6.0
# 1684    80000000.0  Western   73215310.0         7.0
# 1718    75000000.0  Western   45356386.0         5.9
# 1814   100000000.0  Western   67286731.0         6.7
# 2304    65000000.0  Western   93771072.0         6.7
# 2420    63000000.0  Western   25052000.0         6.6
# 2447    44000000.0  Western   54116191.0         7.9
# 2540    60000000.0  Western   75370763.0         6.5
# 2946    55000000.0  Western   56932305.0         6.6
# 3530    55000000.0  Western   53574088.0         7.8
# 3577    47000000.0  Western   10539414.0         4.7
# 3758    57000000.0  Western   15527125.0         5.8
# 3817    44000000.0  Western    1500000.0         6.8
# 3913    45000000.0  Western    5664251.0         6.3
# 3984    40000000.0  Western   87666629.0         7.4
# 4166    40000000.0  Western   42615685.0         6.1
# 4457    38000000.0  Western     623374.0         5.2
# 4586    38000000.0  Western  171031347.0         7.7
# 4806    35000000.0  Western   13264986.0         6.0
# 4859    35000000.0  Western     630779.0         6.8
# 5006    32000000.0  Western   18636537.0         6.4
# 5153    30000000.0  Western   66528842.0         7.5
# 5472    30000000.0  Western    3904982.0         7.5
# 5710    27000000.0  Western   10297897.0         6.0
# ...            ...      ...          ...         ...
# 5920    25000000.0  Western   56505065.0         7.8
# 6251    25000000.0  Western    1512815.0         5.8
# 6387    23000000.0  Western    7434726.0         6.0
# 6812    20000000.0  Western   21413105.0         6.8
# 7065     2000000.0  Western    1900725.0         7.4
# 7128    22000000.0  Western  184208848.0         8.0
# 7324    18000000.0  Western    8000000.0         5.0
# 7388    11350000.0  Western     229311.0         6.2
# 7669    16000000.0  Western    2428883.0         6.6
# 7987    15000000.0  Western    5023275.0         7.5
# 8061    14400000.0  Western  101157447.0         8.3
# 8236    13000000.0  Western   44726644.0         6.8
# 8346    20000000.0  Western     403932.0         6.5
# 8547   107000000.0  Western   22406362.0         6.0
# 8767    11000000.0  Western    1066555.0         5.8
# 9115    10000000.0  Western     128486.0         7.3
# 9528    20000000.0  Western     403932.0         6.5
# 9636     6900000.0  Western   41400000.0         7.3
# 9691     6500000.0  Western    2024854.0         6.6
# 9722     6000000.0  Western  102308900.0         8.1
# 9757     8000000.0  Western   20400000.0         6.9
# 9798     6000000.0  Western    5895238.0         5.5
# 10028    5000000.0  Western   12200000.0         6.3
# 10323    3800000.0  Western      14873.0         6.8
# 10328    3768785.0  Western    8000000.0         7.0
# 10515    3000000.0  Western     252726.0         7.2
# 10564    2600000.0  Western  119500000.0         7.8
# 10948    1200000.0  Western    6100000.0         8.9
# 11422     200000.0  Western    3500000.0         8.0
# 11503      30000.0  Western     243768.0         4.1
#
#                                              movie_title  year
# 45                                      The Lone Ranger   2013
# 246                                      Wild Wild West   1999
# 645                                        The Revenant   2015
# 655                                               Rango   2011
# 941                                   Home on the Range   2004
# 1054                                   Django Unchained   2012
# 1242                                          The Alamo   2004
# 1684                   Spirit: Stallion of the Cimarron   2002
# 1718                                The Legend of Zorro   2005
# 1814                                            Hidalgo   2004
# 2304                                  The Mask of Zorro   1998
# 2420                                         Wyatt Earp   1994
# 2447                                  The Hateful Eight   2015
# 2540                                The Horse Whisperer   1998
# 2946                                      Shanghai Noon   2000
# 3530                                       3:10 to Yuma   2007
# 3577                                          Jonah Hex   2010
# 3758                              All the Pretty Horses   2000
# 3817                                      Heaven's Gate   1980
# 3913                                  The Warrior's Way   2010
# 3984                        Back to the Future Part III   1990
# 4166                  A Million Ways to Die in the West   2014
# 4457                                      Texas Rangers   2001
# 4586                                          True Grit   2010
# 4806                                   American Outlaws   2001
# 4859                                Ride with the Devil   1999
# 5006                             The Quick and the Dead   1995
# 5153                                Legends of the Fall   1994
# 5472   The Assassination of Jesse James by the Coward...  2007
# 5710                                    The Newton Boys   1998
# ...                                                  ...   ...
# 5920                                          Tombstone   1993
# 6251                                     Jane Got a Gun   2016
# 6387               Harley Davidson and the Marlboro Man   1991
# 6812                                 Quigley Down Under   1990
# 7065                                    The Proposition   2005
# 7128                                 Dances with Wolves   1990
# 7324                      The Legend of the Lone Ranger   1981
# 7388                                     One Man's Hero   1999
# 7669                                       The Homesman   2014
# 7987                                      Three Burials   2005
# 8061                                         Unforgiven   1992
# 8236                                         Young Guns   1988
# 8346                                          The Claim   2000
# 8547                                          The Alamo   2004
# 8767                                     September Dawn   2007
# 9115                       The Good, the Bad, the Weird   2008
# 9528                                          The Claim   2000
# 9636                                         Pale Rider   1985
# 9691           The Work and the Glory II: American Zion   2005
# 9722                 Butch Cassidy and the Sundance Kid   1969
# 9757                                    Duel in the Sun   1946
# 9798                                   Casa de mi Padre   2012
# 10028                                 Lone Wolf McQuade   1983
# 10323                                      Major Dundee   1965
# 10328                                Annie Get Your Gun   1950
# 10515                                Love's Abiding Joy   2006
# 10564                                   Blazing Saddles   1974
# 10948                    The Good, the Bad and the Ugly   1966
# 11422                              A Fistful of Dollars   1964
# 11503                           The Legend of God's Gun   2007
#
# [62 rows x 6 columns]

# %% [markdown]
# # Boxplot
# - A boxplot is another way to visualize the distribution of a numeric feature. Let Q1, Q2 and Q3 represent the 25%, 50% and 75% quantile, respectively.
# - A Boxplot is made of five quantiles: Q1−1.5(Q3−Q1), Q1, Q2, Q3, and Q3+1. 5(Q3−Q1). It can be made by function boxplot.

# %%
df_score = df[['color', 'imdb_score']].dropna()
df_score.boxplot(by='color', column='imdb_score')
plt.ylabel('Imdb Score')

# %% [markdown]
# ### Exercise 4
# What is the duration distribution for different kinds of posters?

# %%
#### Your code here
df.head(5)
df_duration = df[['duration', 'facenumber_in_poster']].dropna()
df_duration.boxplot(by='facenumber_in_poster', column='duration')
plt.ylabel('duration')
plt.ylim([25, 175])
# Out:
# (25, 175)

# %% [markdown]
# # Seaborn

# %%
import seaborn as sns

# %% [markdown]
# Seaborn provides functionality to infer a distribution from the sample data.  This is known as kernel density estimation.

# %%
sns.kdeplot(df['imdb_score'], shade=True, label='Estimated PDF of imdb score')

# %% [markdown]
# It is possible to combine histogram and the distribution estimate plot:

# %%
sns.distplot(df['imdb_score'])

# %% [markdown]
# The joinplot() function combines histogram and scatter plot.

# %%
sns.jointplot(df['num_critic_for_reviews'], df['imdb_score'])

# %% [markdown]
# The "pearsonr=0.31" indicates the pearson correlation of these two variables. The p value is pretty small, indicating that there is a significant linear relation between the two variables.

# %% [markdown]
# Visualize the distribution of multiple features by using boxplot:

# %%
sns.boxplot(x='color', y='imdb_score', data=df)

# %% [markdown]
# ### Advanced plots
# Seaborn also provides another famous sample dataset named "tips":

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# This is a famous dataset record the information of people of different sex, being a smoker or not, visiting at different day or for different meal, the size of parties they joined, and the tip and the total bill they pay.
#
# To visualize the relation between total_bill and tip, use scatter plot. Seaborn performs linear fitting as well.

# %%
sns.lmplot("total_bill", "tip", tips)

# %%
sns.jointplot("total_bill", "tip", tips,kind='reg')

# %% [markdown]
# Visualize "Male" and "Female" data points, represented by hue.

# %%
sns.lmplot("total_bill", "tip", tips, hue="sex", palette="Set2")

# %% [markdown]
# Pass a dictionary to the palette argument, specifying the color of each level in the hue variable.

# %%
sns.lmplot("total_bill", "tip", tips, hue="sex", palette={"Male": "b", "Female": "r"})

# %% [markdown]
# Here:
# - hue indicates the column categorical feature used to split the data
# - palette specifies the color used in the graphic

# %% [markdown]
# To compare the same kind of plot for different features, faceting is useful.

# %%
SexGrid = sns.FacetGrid(tips, col='sex', hue="sex", palette="Set1", size=4)
SexGrid.map(sns.distplot, "tip")

# %% [markdown]
# Above the column and hue are mapped to the same categorical feature.  Below column and hue are mapped to different categorical features.

# %%
SexGrid = sns.FacetGrid(tips, col='smoker', hue="sex", palette="Set1", size=4)
SexGrid.map(sns.distplot, "tip")

# %% [markdown]
# FacetGrid() offers three ways to split data: hue, column and row.  The .map() method specifies the plot type and the x,y axes.

# %% [markdown]
# Facet can be used to differentiate multiple factors as well.

# %%
tipsGrid = sns.FacetGrid(tips, row='sex', col='smoker',\
                               hue='time', palette="Set2")
tipsGrid.map(sns.regplot, 'total_bill', 'tip')
tipsGrid.add_legend()

# %% [markdown]
# ### Exercise 5
# Use FacetGrid to compare the distribution of imdb score for different poster color.

# %%
#### Your code here
g = sns.FacetGrid(df, col='color', hue='color', palette='Set1', size=4)
g.map(sns.distplot, 'imdb_score')

# %%
print(g)
# Out:
# <seaborn.axisgrid.FacetGrid object at 0x11eba0400>

# %% [markdown]
# FacetGrid helps explore specific variables and the relationships between pairs of variables, while segmenting the data set across multiple categorical features.
#
# PairGrid explores the relationships between whole sets of numerical features.

# %%
tipGrid = sns.PairGrid(tips)
tipGrid.map(plt.scatter)

# %% [markdown]
# Switching to the iris data:

# %%
iris = sns.load_dataset("iris")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
g = sns.PairGrid(iris)
g.map_diag(plt.hist)
g.map_offdiag(plt.scatter)

# %% [markdown]
# Some examples with different type of plot and colors.

# %%
g = sns.PairGrid(iris, hue = 'species', palette='Set2',\
           hue_kws={'cmap':['Greens','Oranges','Blues']})

g.map_diag(plt.hist)
g.map_upper(plt.scatter)
g.map_lower(sns.kdeplot)
g.add_legend()
